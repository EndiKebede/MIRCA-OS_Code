# %%
import os
import numpy as np
import rasterio
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from contextlib import contextmanager
import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning) 
import glob
import sys

# %%
# Load the DataFrame from your CSV file
df_area =pd.read_excel("D:\\PhD_Udel\\MICRA_2015\\DOwnscaling\\India\\FInal_Downscaling\\CCC\\2000\\3\\2005_ir.xlsx")

# Define the type_order
type_order = {'Perennial': 1, 'Other Perennial': 2, 'Fodder': 3, 'Annual': 4, 'Other Annual': 5}

# Define a custom ranking function for a single state (unit_code)
def custom_rank(sub_df):
    sub_df = sub_df.copy()  # Create a copy to avoid SettingWithCopyWarning
    
    # Redirect standard error to suppress warnings
    sys.stderr = open('nul', 'w')
    
    sub_df['Type_Rank'] = sub_df['Type'].map(type_order)
    sub_df = sub_df.sort_values(by=['Type_Rank', 'Growing_area'], ascending=[True, False])
    sub_df['rank'] = range(1, len(sub_df) + 1)
    
    # Reset standard error
    sys.stderr = sys.__stderr__
    
    return sub_df

# Initialize an empty DataFrame to store the ranked results
ranked_df = pd.DataFrame()

# Iterate over unique unit_codes (states) and rank crops for each state
for unit_code in df_area['unit_code'].unique():
    state_subset = df_area[df_area['unit_code'] == unit_code]
    ranked_subset = custom_rank(state_subset)
    ranked_df = ranked_df.append(ranked_subset, ignore_index=True)

# Sort the final DataFrame by 'unit_code' and 'Crop_Rank'
ranked_df = ranked_df.sort_values(by=['unit_code', 'rank']).reset_index(drop=True)

# Display the final DataFrame
ranked_df
# Out:
#      Country          State        District  unit_code              Crop  \
# 0      India  Uttar Pradesh            Agra    3560539        Sugar cane
# 1      India  Uttar Pradesh            Agra    3560539             Cocoa
# 2      India  Uttar Pradesh            Agra    3560539            Coffee
# 3      India  Uttar Pradesh            Agra    3560539          Oil palm
# 4      India  Uttar Pradesh            Agra    3560539  Others perennial
# ...      ...            ...             ...        ...               ...
# 2673   India    West Bengal  Uttar Dinajpur    3560641        Sugar beet
# 2674   India    West Bengal  Uttar Dinajpur    3560641            Wheat2
# 2675   India    West Bengal  Uttar Dinajpur    3560641    Others annual1
# 2676   India    West Bengal  Uttar Dinajpur    3560641    Others annual2
# 2677   India    West Bengal  Uttar Dinajpur    3560641    Others annual3
#
#       Growing_area  Subcrop             Type  Planting_Month  Maturity_Month  \
# 0              245        1        Perennial               1              12
# 1                0        1        Perennial               1              12
# 2                0        1        Perennial               1              12
# 3                0        1        Perennial               1              12
# 4             7073        1  Other Perennial               1              12
# ...            ...      ...              ...             ...             ...
# 2673             0        1           Annual               5              10
# 2674             0        1           Annual              11               3
# 2675             0        1     Other Annual              11               3
# 2676             0        1     Other Annual               3               6
# 2677             0        1     Other Annual               6               9
#
#       Type_Rank  rank
# 0             1     1
# 1             1     2
# 2             1     3
# 3             1     4
# 4             2     5
# ...         ...   ...
# 2673          4    22
# 2674          4    23
# 2675          5    24
# 2676          5    25
# 2677          5    26
#
# [2678 rows x 12 columns]

# %%
# Load the DataFrame from your CSV file
df_rainfed =  pd.read_excel("D:\\PhD_Udel\\MICRA_2015\\DOwnscaling\\India\\FInal_Downscaling\\CCC\\2000\\3\\2005_rf.xlsx")
# Define the type_order
type_order = {'Perennial': 1, 'Other Perennial': 2, 'Fodder': 3, 'Annual': 4, 'Other Annual': 5}

# Define a custom ranking function for a single state (unit_code)
def custom_rank(sub_df):
    sub_df = sub_df.copy()  # Create a copy to avoid SettingWithCopyWarning
    
    # Redirect standard error to suppress warnings
    sys.stderr = open('nul', 'w')
    
    sub_df['Type_Rank'] = sub_df['Type'].map(type_order)
    sub_df = sub_df.sort_values(by=['Type_Rank', 'Growing_area'], ascending=[True, False])
    sub_df['rank'] = range(1, len(sub_df) + 1)
    
    # Reset standard error
    sys.stderr = sys.__stderr__
    
    return sub_df

# Initialize an empty DataFrame to store the ranked results
ranked_df_rf = pd.DataFrame()

# Iterate over unique unit_codes (states) and rank crops for each state
for unit_code in df_rainfed['unit_code'].unique():
#     print(unit_code)
    state_subset_rf = df_rainfed[df_rainfed['unit_code'] == unit_code]
    ranked_subset_rf = custom_rank(state_subset_rf)
    ranked_df_rf = ranked_df_rf.append(ranked_subset_rf, ignore_index=True)

# Sort the final DataFrame by 'unit_code' and 'Crop_Rank'
ranked_df_rf = ranked_df_rf.sort_values(by=['unit_code', 'rank']).reset_index(drop=True)
# ranked_df_rf = ranked_df_rf.sort_values(by=['unit_code', 'rank']).reset_index(drop=True)

ranked_df_rf
# Out:
#      Country          State        District  unit_code              Crop  \
# 0      India  Uttar Pradesh            Agra    3560539        Sugar cane
# 1      India  Uttar Pradesh            Agra    3560539             Cocoa
# 2      India  Uttar Pradesh            Agra    3560539            Coffee
# 3      India  Uttar Pradesh            Agra    3560539          Oil palm
# 4      India  Uttar Pradesh            Agra    3560539  Others perennial
# ...      ...            ...             ...        ...               ...
# 2673   India    West Bengal  Uttar Dinajpur    3560641         Sunflower
# 2674   India    West Bengal  Uttar Dinajpur    3560641            Wheat2
# 2675   India    West Bengal  Uttar Dinajpur    3560641    Others annual1
# 2676   India    West Bengal  Uttar Dinajpur    3560641    others annual3
# 2677   India    West Bengal  Uttar Dinajpur    3560641    others annual2
#
#       Growing_area  Subcrop             Type  Planting_Month  Maturity_Month  \
# 0               10        1        Perennial               1              12
# 1                0        1        Perennial               1              12
# 2                0        1        Perennial               1              12
# 3                0        1        Perennial               7              11
# 4             3089        1  Other Perennial               1              12
# ...            ...      ...              ...             ...             ...
# 2673             0        1           Annual               6              10
# 2674             0        1           Annual              11               3
# 2675         30274        1     Other Annual               6               9
# 2676          1737        1     Other Annual               2               5
# 2677          1070        1     Other Annual              10               1
#
#       Type_Rank  rank
# 0             1     1
# 1             1     2
# 2             1     3
# 3             1     4
# 4             2     5
# ...         ...   ...
# 2673          4    22
# 2674          4    23
# 2675          5    24
# 2676          5    25
# 2677          5    26
#
# [2678 rows x 12 columns]

# %%
# Define Annual and Pernnial crops
Annual=("Barley","Cassava","Groundnuts","Maize","Millet","Potatoes","Pulses","Rapeseed","Rice1","Rice2", "Sorghum","Soybeans","Sunflower","Wheat1","Wheat2","Cotton", "Fodder", "Others annual", "Rye", "Sugar beet")
Perennial=("Sugarcane", "Citrus", "Grape",  "Cocoa", "Coffee","Oil palm", "Date palm", "Others perennial")

# %%
@contextmanager
def open_tiff_file(filepath):
    with rasterio.open(filepath) as src:
        array = src.read(1)
        no_data_value = src.nodata
        if no_data_value is not None:
            array = np.where(array == no_data_value, 0, array)
        yield array
def get_unit_codes(root_folder):
    unit_codes = []
    for subfolder in os.listdir(root_folder):
        subfolder_path = os.path.join(root_folder, subfolder)
        if os.path.isdir(subfolder_path):
            for tiff_file in os.listdir(subfolder_path):
                if tiff_file.endswith('.tif'):
                    unit_codes.append(int(tiff_file[:-4]))
                    
                
    return sorted(unit_codes)
def read_tiff_file(subfolder_path, unit_code):
    tiff_file = f"{unit_code}.tif"
    tiff_file_path = os.path.join(subfolder_path, tiff_file)
    if os.path.exists(tiff_file_path):
        with open_tiff_file(tiff_file_path) as array:
            array = np.where(np.logical_or(np.isnan(array), np.isinf(array)), 0, array)
            return array
    else:
        return None

root_folder =r"D:\PhD_Udel\MICRA_2015\DOwnscaling\India\FInal_Downscaling\CCC\State\2005\3"
def createList(r1, r2):
    return np.arange(r1, r2+1)
def getListcom(p, m):
    if np.any(p < m):
        return createList(p, m)
    else:
        return np.concatenate((createList(p, 12), createList(1, m)))
import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning) 

sub_dirs = [x[0] for x in os.walk(root_folder)]
tiff_files = sorted(glob.glob(os.path.join(root_folder, "*/*.tif")))
dist_array_aei = None
dist_array_area = None
dist_array_cle = None
dist_array_bar = None
dist_array_cas = None
# dist_array_cit = None
dist_array_coc = None
dist_array_cof = None
dist_array_cot = None
# dist_array_dat = None
dist_array_for = None
# dist_array_gra = None
dist_array_gro = None
dist_array_maz = None
dist_array_mil = None
dist_array_oil = None
dist_array_pot = None
dist_array_otha = None
dist_array_othp = None
dist_array_pul = None
dist_array_rap = None
dist_array_ric1 = None
dist_array_ric2 = None
dist_array_rye = None
dist_array_sor = None
dist_array_soy = None
dist_array_sun = None
dist_array_sugc = None
dist_array_sugb = None
dist_array_whe = None
irri_totals = {}
aei_free = {}
cle_free = {}
area = {}
tot_st1 = []
tot_st2 = []
tot_st3 = []
tot_st4 = []
tot_st5 = []
tot_st6 = []
tot_st7 = []

for unit_code in ranked_df['unit_code'].unique():
    TAD_14_dict = {}
    df_cumulative_st1 = pd.DataFrame()
    df_cumulative_st2 = pd.DataFrame()
    df_cumulative_st3 = pd.DataFrame()
    df_cumulative_st4 = pd.DataFrame()
    df_cumulative_st5 = pd.DataFrame()
    df_cumulative_st6 = pd.DataFrame()
    df_cumulative_st7 = pd.DataFrame()
# if ranked_df['unit_code'] ==3560031:
    for j in range(1, int(np.max(ranked_df['rank'])+1)):
        rows_ir = ranked_df.loc[(ranked_df['unit_code'] == unit_code) & (ranked_df['rank'] == j)]
        for i, row in rows_ir.iterrows():
#             if ranked_df.Growing_area[i]>0:
            p = ranked_df.Planting_Month[i]
            m = ranked_df.Maturity_Month[i]
            listcom = getListcom(p, m)
#                         print(unit_code)
              # Filter and extract TIFF files that correspond to the selected unit_code

            for tiff_file in tiff_files:
#                 print(tiff_file)
                for subfolder_path in sub_dirs[1:]:
                    subfolder_name = os.path.basename(subfolder_path)
#                     print(subfolder_name)
#                     print(os.path.basename(tiff_file)[:-4])
                    if os.path.basename(tiff_file)[:-4] == str(unit_code):
                        array = read_tiff_file(subfolder_path, unit_code)
                        array = np.nan_to_num(array)
                        array =  np.where(np.logical_or(np.isnan(array), np.isinf(array)), 0, array)
                        c_s = len(array[0])
                        r_s = len(array)

#                             return arr
                        if subfolder_name == "AEI_05":
                            tiff_ir=tiff_file

                            dist_array_aei = array
                            dist_array_aei = np.where(np.logical_or(np.isnan(dist_array_aei), np.isinf(dist_array_aei)), 0, dist_array_aei)
                        elif subfolder_name == "Ara_05":
                            dist_array_area = array
                            dist_array_area = np.where(np.logical_or(np.isnan(dist_array_area), np.isinf(dist_array_area)), 0, dist_array_area)
                        elif subfolder_name == "CLE_05":
                            dist_array_cle = array
                            dist_array_cle = np.where(np.logical_or(np.isnan(dist_array_cle), np.isinf(dist_array_cle)), 0, dist_array_cle)

                        else:
                            # Extract array data for crop type and assign to corresponding variable in crop_dict
                            crop_name = ranked_df.Crop[i]
                            if crop_name:
                                crop_array = read_tiff_file(subfolder_path, unit_code)
                                if isinstance(crop_array, np.ndarray):
                                    crop_array = np.where(np.logical_or(np.isnan(crop_array), np.isinf(crop_array)), 0, crop_array)
#                                     
                                else:
                                    print(f"Warning: crop_array for {crop_name} is not a numpy array.")
                                n=ranked_df.Subcrop[i]

                                if crop_name == 'Barley' and subfolder_name == "Bar_05":
                                    dist_array_bar = crop_array
                                    AH_array=dist_array_bar
                                    AD_step1 = np.where(dist_array_area > 0, ((AH_array * dist_array_aei) / dist_array_area), 0)
                                elif crop_name == 'Cassava'and subfolder_name == "Cas_05":
                                    dist_array_coc = crop_array
                                    AH_array=dist_array_coc
                                    AD_step1 = np.where(dist_array_area > 0, ((AH_array * dist_array_aei) / dist_array_area), 0)
                                elif crop_name == 'Cotton'and subfolder_name == "Cot_05":
                                    dist_array_cot = crop_array
                                    AH_array=dist_array_cot
                                    AD_step1 = np.where(dist_array_area > 0, ((AH_array * dist_array_aei) / dist_array_area), 0)
                                elif crop_name == 'Cocoa'and subfolder_name == "Stm_05":
                                    dist_array_cof = crop_array
                                    AH_array=dist_array_cof
                                    AD_step1 = np.where(dist_array_area > 0, ((AH_array * dist_array_aei) / dist_array_area), 0)
                                elif crop_name == 'Coffee'and subfolder_name == "Stm_05":
                                    dist_array_cof = crop_array
                                    AH_array=dist_array_cof
                                    AD_step1 = np.where(dist_array_area > 0, ((AH_array * dist_array_aei) / dist_array_area), 0)
                                elif crop_name == 'Fodder'and subfolder_name == "Fod_05":
                                    dist_array_for = crop_array
                                    AH_array=dist_array_for
                                    AD_step1 = np.where(dist_array_area > 0, ((AH_array * dist_array_aei) / dist_array_area), 0)
                                elif crop_name == 'Groundnuts'and subfolder_name == "Gro_05":
                                    dist_array_gro = crop_array
                                    AH_array=dist_array_gro
                                    AD_step1 = np.where(dist_array_area > 0, ((AH_array * dist_array_aei) / dist_array_area), 0)
                                elif crop_name == 'Maize'and subfolder_name == "Maz_05":
                                    dist_array_maz = crop_array
                                    AH_array=dist_array_maz
                                    AD_step1 = np.where(dist_array_area > 0, ((AH_array * dist_array_aei) / dist_array_area), 0)
                                elif crop_name == 'Millet'and subfolder_name == "Mil_05":
                                    dist_array_mil = crop_array
                                    AH_array=dist_array_mil
                                    AD_step1 = np.where(dist_array_area > 0, ((AH_array * dist_array_aei) / dist_array_area), 0)
                                elif crop_name == 'Oil palm'and subfolder_name == "Olp_05":
                                    dist_array_oil = crop_array
                                    AH_array=dist_array_oil
                                    AD_step1 = np.where(dist_array_area > 0, ((AH_array * dist_array_aei) / dist_array_area), 0)
                                elif crop_name == 'Others perennial'and subfolder_name == "Othp_05":
                                    dist_array_othp = crop_array
                                    AH_array=dist_array_othp
                                    AD_step1 = np.where(dist_array_area > 0, ((AH_array * dist_array_aei) / dist_array_area), 0)
                                elif crop_name == 'Others annual1'and subfolder_name == "Otha_05":
                                    dist_array_otha1 = crop_array
                                    AH_array=dist_array_otha1
                                    AD_step1 = np.where(dist_array_area > 0,(((AH_array/n)* dist_array_aei) / dist_array_area),0)
                                elif crop_name == 'Others annual2'and subfolder_name == "Otha_05":
                                    dist_array_otha2 = crop_array
                                    AH_array=dist_array_otha2
                                    AD_step1 = np.where(dist_array_area > 0,(((AH_array/n)* dist_array_aei) / dist_array_area),0)
                                elif crop_name == 'Others annual3'and subfolder_name == "Otha_05":
                                    dist_array_otha3 = crop_array
                                    AH_array=dist_array_otha3
                                    AD_step1 = np.where(dist_array_area > 0,(((AH_array/n)* dist_array_aei) / dist_array_area),0)
                                elif crop_name == 'Others annual4'and subfolder_name == "Otha_05":
                                    dist_array_otha4 = crop_array
                                    AH_array=dist_array_otha4
                                    AD_step1 = np.where(dist_array_area > 0,(((AH_array/n)* dist_array_aei) / dist_array_area),0)
                                elif crop_name == 'Potatoes'and subfolder_name == "Pot_05":
                                    dist_array_pot = crop_array
                                    AH_array=dist_array_pot
                                    AD_step1 = np.where(dist_array_area > 0, ((AH_array * dist_array_aei) / dist_array_area), 0)
                                elif crop_name == 'Pulses'and subfolder_name == "Pul_05":
                                    dist_array_pul = crop_array
                                    AH_array=dist_array_pul
                                    AD_step1 = np.where(dist_array_area > 0, ((AH_array * dist_array_aei) / dist_array_area), 0)
                                elif crop_name == 'Rapeseed'and subfolder_name == "Rap_05":
                                    dist_array_rap = crop_array
                                    AH_array=dist_array_rap
                                    AD_step1 = np.where(dist_array_area > 0, ((AH_array * dist_array_aei) / dist_array_area), 0)
                                elif crop_name == 'Rice1'and subfolder_name == "Ric_05":
                                    dist_array_ric1 = crop_array
                                    AH_array=dist_array_ric1
                                    AD_step1 = np.where(dist_array_area > 0,(((AH_array/n)* dist_array_aei) / dist_array_area),0)

                                elif crop_name == 'Rice2'and subfolder_name == "Ric_05":
                                    dist_array_ric2 = crop_array
                                    AH_array=dist_array_ric2
                                    AD_step1 = np.where(dist_array_area > 0,(((AH_array/n)* dist_array_aei) / dist_array_area),0)
                                elif crop_name == 'Rye'and subfolder_name == "Rye_05":
                                    dist_array_rye = crop_array
                                    AH_array=dist_array_rye
                                    AD_step1 = np.where(dist_array_area > 0, ((AH_array * dist_array_aei) / dist_array_area), 0)
                    
                                elif crop_name == 'Sorghum'and subfolder_name == "Sor_05":
                                    dist_array_sor = crop_array
                                    AH_array=dist_array_sor
                                    AD_step1 = np.where(dist_array_area > 0, ((AH_array * dist_array_aei) / dist_array_area), 0)
                                elif crop_name == 'Soybeans'and subfolder_name == "Soy_05":
                                    dist_array_soy = crop_array
                                    AH_array=dist_array_soy
                                    AD_step1 = np.where(dist_array_area > 0, ((AH_array * dist_array_aei) / dist_array_area), 0)
                                elif crop_name == 'Sugar beet'and subfolder_name == "Sub_05":
                                    dist_array_sugb = crop_array
                                    AH_array=dist_array_sugb
                                    AD_step1 = np.where(dist_array_area > 0, ((AH_array * dist_array_aei) / dist_array_area), 0)
                                elif crop_name == 'Sugar cane'and subfolder_name == "Sug_05":
                                    dist_array_sugc = crop_array
                                    AH_array=dist_array_sugc
                                    AD_step1 = np.where(dist_array_area > 0, ((AH_array * dist_array_aei) / dist_array_area), 0)
                                elif crop_name == 'Sunflower'and subfolder_name == "Sun_05":
                                    dist_array_sun = crop_array
                                    AH_array=dist_array_sun
                                    AD_step1 = np.where(dist_array_area > 0, ((AH_array * dist_array_aei) / dist_array_area), 0)
                                elif crop_name == 'Wheat1'and subfolder_name == "Whe_05":
                                    dist_array_whe1= crop_array
                                    AH_array=dist_array_whe1
                                    AD_step1 = np.where(dist_array_area > 0,(((AH_array/n)* dist_array_aei) / dist_array_area),0)
                                elif crop_name == 'Wheat2'and subfolder_name == "Whe_05":
                                    dist_array_whe2= crop_array
                                    AH_array=dist_array_whe2
                                    AD_step1 = np.where(dist_array_area > 0,(((AH_array/n)* dist_array_aei) / dist_array_area),0)
                                        
# for row in range(AD_step1.shape[0]):
#                 for col in range(AD_step1.shape[1]):
#                     if AD_step1[row, col] <= dist_array_area[row, col]:
#                         AD_step1[row, col] = AD_step1[row, col]
#                     else:
#                         ratio = dist_array_area[row, col] / AD_step1[row, col]
#                         AD_step1[row, col] *= ratio
            print(ranked_df.unit_code[i])
            print("Step1")
            print("Crop:", ranked_df.Crop[i])
            if round(np.sum(AD_step1),2) < (ranked_df.Growing_area[i]):
                ATS_2= (ranked_df.Growing_area[i])-round(np.sum(AD_step1),2)
                AD_area1=AD_step1
                print("Iteration continues")
                print("Area distributed after step1:", round(np.sum(AD_step1),2))
                print("Area to be distributed in next step:", ATS_2)
            elif round(np.sum(AD_step1),2)==(ranked_df.Growing_area[i]):
                ATS_2= (ranked_df.Growing_area[i])-round(np.sum(AD_step1),2)
                AD_area1=AD_step1
                print("Iteration completed ")
                print("Area distributed after step1:", round(np.sum(AD_step1),2))
            else:
                
                if ranked_df.Growing_area[i] >0:
                    print("Error check your code!")
                    print("More area available than the growing area")
                    ratio=ranked_df.Growing_area[i]/np.sum(AD_step1)
    #                             print(ratio)
                    AD_area1=AD_step1*ratio
                    ATS_2= 0
                    print("Iteration completed")
                    print("Area distributed in step1:",round( np.sum(AD_area1),2))
                if ranked_df.Growing_area[i]== 0:
                    AD_area1=AD_step1*0
                    ATS_2= 0
                    print("No area will be distributed in step1 (Zero harvested area)")
#             AD_area1 = np.minimum(AD_area1, dist_array_aei)
            # Assign the area to be distributed in this step for each month according to crop calendar
            df_list = []
            # Call the array to be distributed in step1 and convert it to dataframe
            array_name = "Array_" + ranked_df.Crop[i][:3] + ranked_df.Crop[i][-1] + "1"
            # Call the array (area) to be distributed monthly
            arr1 = AD_area1
            arr1_re = np.repeat(arr1, 12)
            c_s = len(arr1[0])
            r_s = len(arr1)
            # Create a new dataframe in which we will iterate each cell value for each month according to the crop calendar
#             crop_sum = 0
            df_month = pd.DataFrame(np.arange(1, 13), columns=['Month'])
            df_mon = pd.concat([df_month] * c_s * r_s, ignore_index=True)
            # Change the array to dataframe
            df_1 = pd.DataFrame(arr1_re, index=np.arange(len(df_mon)), columns=[array_name])
            # Merge the month and array dataframe
            df_area1 = pd.concat([df_mon, df_1], axis=1)
            # Filter the month in which the crop grows according to the crop calendar
            crop_1 = df_area1[(df_area1["Month"].isin(listcom))]
            # Filter the month in which the crop didn't grow according to the crop calendar
            crop_not = df_area1[(~df_area1["Month"].isin(listcom))]
            # Set the value of the array to 0 for months when the crop doesn't grow
            crop_not[array_name].values[:] = 0
            # Merge the two dataframes and sort it based on index
            df_name = ranked_df.Crop[i][:3] + ranked_df.Crop[i][-1] + "_step1"
            df_name = pd.concat([crop_1, crop_not])
            df_name = df_name.sort_index()
#             df_name = np.minimum(df_name, dist_array_aei)
            df_list.append(df_name[array_name])

            Step_1 = pd.concat(df_list, axis=1).sum(axis=1)
    
            if 'df_cumulative_st1' not in locals() or df_cumulative_st1.empty:
   
                 df_cumulative_st1 = pd.Series(np.zeros(len(Step_1)), index=Step_1.index)
#             if 'df_cumulative_st1' not in locals() or df_cumulative_st1.empty:
#                 df_cumulative_st1 = Step_1.copy()  
#             else:
            df_cumulative_st1 += Step_1
            
            df_tot_st1 = pd.concat([df_mon, df_cumulative_st1], axis=1)
            df_tot_st1.columns = ['Month', 'Total_st1']
            


#           Step2
                # Filter the total dataframe for a month in which crop grow
            df_max_filt = df_tot_st1[df_tot_st1["Month"].isin(listcom)]

            # Group the cell values
            n = len(df_max_filt) // (r_s * c_s)

            # Select the maximum total area assigned for the month in which this crop grow
            df_max = df_max_filt.groupby(np.arange(len(df_max_filt)) // n).max()

            # Change it to array
            max_step2 = np.array(df_max["Total_st1"]).reshape(r_s, c_s)
#             print("Max:", np.max(max_step2))
#             print(np.shape(max_step2))
#             print(np.shape(dist_array_aei))
#            Determine the free AEI cell
            AEI_fr_ce_2 = np.where(dist_array_aei > max_step2, (dist_array_aei-max_step2), 0)
            

            # Determine the AH_free_cell
            AH_fr_ce_2 = np.maximum(AH_array - AD_area1, 0)

            # Potential area to be distributed in this step
            Pot_ATS2 = np.minimum(AEI_fr_ce_2, AH_fr_ce_2)

            # Determine the distribution ratio as the ratio of ATS and Pot_ATS
            with np.errstate(divide='ignore'):
                AD_ra2 = np.where(ATS_2<np.sum(Pot_ATS2),(ATS_2/np.sum(Pot_ATS2)), 1)

    #                 Exact area to be distributed at this step
            if ATS_2>0:
                AD_area2=Pot_ATS2*AD_ra2
                #Area to be distributed in step 1 and 2
                
            else:
                AD_area2=Pot_ATS2*0
                #Area to be distributed in step 1 and 2
#                 TAD_12=AD_area1
            TAD_12=AD_area1 + AD_area2
            
#             for row in range(TAD_12.shape[0]):
#                 for col in range(TAD_12.shape[1]):
#                     if TAD_12[row, col] <= dist_array_area[row, col]:
#                         TAD_12[row, col] = TAD_12[row, col]
#                     else:
#                         ratio = dist_array_area[row, col] / TAD_12[row, col]
#                         TAD_12[row, col] *= ratio
            print("Step2")
#             print("Crop:", ranked_df.Crop[i])
            if round(np.sum(TAD_12),2) < (ranked_df.Growing_area[i]):
                ATS_3= (ranked_df.Growing_area[i])-round(np.sum(TAD_12),2)
                AD_step2=TAD_12
                print("Iteration continues")
                print("Area distributed after step2:", round(np.sum(TAD_12),2))
                print("Area to be distributed in next step:", ATS_3)
            elif round(np.sum(TAD_12),2)==(ranked_df.Growing_area[i]):
                ATS_3= (ranked_df.Growing_area[i])-round(np.sum(TAD_12),2)  
                AD_step2=TAD_12
                print("Iteration completed ")
                print("Area distributed after step2:", round(np.sum(TAD_12),2)) 
            # Create a list to store arrays
            else:
                
                if ranked_df.Growing_area[i] >0:
                    print("Error check your code!")
                    print("More area available than the growing area (Scaling is needed)")
                    ratio=ranked_df.Growing_area[i]/np.sum(TAD_12)
    #                             print(ratio)
                    AD_step2=TAD_12*ratio
                    ATS_3= 0
                    print("Iteration completed")
                    print("Area distributed in step1:", round(np.sum(AD_step2),2))
                if ranked_df.Growing_area[i]== 0:
                    AD_step2=TAD_12*0
                    ATS_3= 0
                    print("No area will be distributed in step2 (Zero harvested area)")

            df_list = []

            # Create array for step 2
            
            array_name2 = "Array_" + ranked_df.Crop[i][:3] + ranked_df.Crop[i][-1] + "2"
            arr2 = TAD_12

            # Repeat array for 12 months
            arr2_re = np.repeat(arr2, 12)

            # Convert array to dataframe
            df_2 = pd.DataFrame(arr2_re, index=np.arange(len(df_mon)), columns=[array_name2])

            # Merge month and array dataframes
            df_area2 = pd.concat([df_mon, df_2], axis=1)

            # Filter the months when the crop grows
            crop_1 = df_area2[(df_area2["Month"].isin(listcom))]

            # Filter the months when the crop doesn't grow
            crop_not = df_area2[(~df_area2["Month"].isin(listcom))]

            # Set the value of the array to 0 for months when the crop doesn't grow
            crop_not[array_name2].values[:] = 0

            # Concatenate the two dataframes and sort by index
            df_name2 = ranked_df.Crop[i][:3] + ranked_df.Crop[i][-1] + "_step2"
            df_name2 = pd.concat([crop_1, crop_not])
            df_name2 = df_name2.sort_index()
#             df_name2 = np.minimum(df_name2, dist_array_aei)
            # Add the dataframe to the list
            df_list.append(df_name2[array_name2])

            # Concatenate all the dataframes in the list into a single array
            Step_2 = pd.concat(df_list, axis=1).sum(axis=1)
           
            if 'df_cumulative_st2' not in locals() or df_cumulative_st2.empty:
   
                 df_cumulative_st2 = pd.Series(np.zeros(len(Step_2)), index=Step_2.index)
#             if 'df_cumulative_st1' not in locals() or df_cumulative_st1.empty:
#                 df_cumulative_st1 = Step_1.copy()  
#             else:
            df_cumulative_st2 += Step_2
            df_tot_st2 = pd.concat([df_mon, df_cumulative_st2], axis=1)
            df_tot_st2.columns = ['Month', 'Total_st2']
#             print("Total Step2:", df_tot_st2.head(24))


#            #Step3
    #        Select the total dataframe for a month in which crop grow
            df_max_filt3 = df_tot_st2[df_tot_st2["Month"].isin(listcom)]
            #group the cell values
            n = len(df_max_filt3) // (r_s * c_s)
            #Select the maximum total area assigned for the month in which this crop grow
            df_max3 = df_max_filt3.groupby(np.arange(len(df_max_filt3)) // n).max()
            max_step3 = np.array(df_max3["Total_st2"]).reshape(r_s, c_s)
    #                                     Detrmine the free AEI cell
            AEI_fr_ce_3 = np.where(dist_array_aei > max_step3, (dist_array_aei-max_step3), 0)
#             AEI_fr_ce_3 = np.maximum(dist_array_aei - max_step3, 0)
            Pot_ATS3 = np.where(dist_array_cle>0,(AEI_fr_ce_3), 0)
            with np.errstate(divide='ignore'):
                AD_ra3 = np.where((ATS_3<np.sum(Pot_ATS3)),(ATS_3/np.sum(Pot_ATS3)), 1)
            if ATS_3>0:
                AD_area3=Pot_ATS3*AD_ra3
                
            else:
                AD_area3=Pot_ATS3*0
#                 TAD_13=AD_area1+AD_area2
            TAD_13=AD_area1+AD_area2+AD_area3
            
            print("Step3")
#             print("Crop:", ranked_df.Crop[i])
            if round (np.sum(TAD_13),2) < (ranked_df.Growing_area[i]):
                AD_step3=TAD_13
                ATS_4=ranked_df.Growing_area[i]-round(np.sum(TAD_13),2)
                print("Iteration continues")
                print("Area distributed after step3:", round (np.sum(TAD_13),2))
                print("Area to be distributed in next step:", ATS_4)
            elif round(np.sum(TAD_13),2)==(ranked_df.Growing_area[i]):
                AD_step3=TAD_13
                ATS_4=ranked_df.Growing_area[i]-round(np.sum(TAD_13),2)
                print("Iteration completed ")
                print("Area distributed after step3", round (np.sum(TAD_13),2))
            else:
                
                if ranked_df.Growing_area[i] >0:
                    print("Error check your code!")
                    print("More area available than the growing area (Scaling is needed)")
                    ratio=ranked_df.Growing_area[i]/np.sum(TAD_13)
    #                             print(ratio)
                    AD_step3=TAD_13*ratio
                    ATS_4= 0
                    print("Iteration completed")
                    print("Area distributed in step1:",round(np.sum(AD_step3),2))
                if ranked_df.Growing_area[i]== 0:
                    AD_step3=TAD_13*0
                    ATS_4= 0
                    print("No area will be distributed in step3 (Zero harvested area)")
#             for row in range(TAD_13.shape[0]):
#                 for col in range(TAD_13.shape[1]):
#                     if TAD_13[row, col] <= dist_array_area[row, col]:
#                         TAD_13[row, col] = TAD_13[row, col]
#                     else:
#                         ratio = dist_array_area[row, col] / TAD_13[row, col]
#                         TAD_13[row, col] *= ratio
            # Call the array to be distributed in step1 and convert it to dataframe

            df_list = []
            array_name3 = "Array_" + ranked_df.Crop[i][:3] + ranked_df.Crop[i][-1] + "3"
            arr3 = TAD_13
            # repeat it for every twelve months
            arr_re3 = np.repeat(arr3, 12)
            # Change the array to dataframe
            df_3 = pd.DataFrame(arr_re3, index=np.arange(len(df_mon)), columns=[array_name3])
            # Merge the month and array dataframe
            df_area3 = pd.concat([df_mon, df_3], axis=1)
            # Filter the month in which the crop grows according to the crop calendar
            crop_1 = df_area3[(df_area3["Month"].isin(listcom))]
            # Filter the month in which the crop didn't grow according to the crop calendar
            crop_not = df_area3[(~df_area3["Month"].isin(listcom))]
            crop_not[array_name3].values[:] = 0
            # Merge the two dataframes and sort it based on index
            df_name3 = ranked_df.Crop[i][:3] + ranked_df.Crop[i][-1] + "_step3"
            df_name3 = pd.concat([crop_1, crop_not])
            df_name3 = df_name3.sort_index()

            # Add the dataframe to the list
            df_list.append(df_name3[array_name3])

            # Concatenate all the dataframes in the list into a single array
            Step_3 = pd.concat(df_list, axis=1).sum(axis=1)

            # Create a dataframe from the final array

            if 'df_cumulative_st3' not in locals() or df_cumulative_st3.empty:
   
                 df_cumulative_st3 = pd.Series(np.zeros(len(Step_3)), index=Step_3.index)

            df_cumulative_st3 += Step_3
            df_tot_st3 = pd.concat([df_mon, df_cumulative_st3], axis=1)
            df_tot_st3.columns = ['Month', 'Total_st3']
#             print("Total Step3:", df_tot_st3.tail(24))


            



            #Step4
            # #             #Select the total dataframe for a month in which crop grow
            df_max_filt4 = df_tot_st3[df_tot_st3["Month"].isin(listcom)]

            #group the cell values
            n = len(df_max_filt4)//(r_s*c_s)

            #Select the maximum total area assigned for the month in which this crop grow
            df_max4 = df_max_filt4.groupby(np.arange(len(df_max_filt4))//n).max()

            #Change it to array
            max_step4 = np.array(df_max4["Total_st3"]).reshape(r_s, c_s)

            #Determine the free AEI cell
            AEI_fr_ce_4 = np.where(dist_array_aei > max_step4, (dist_array_aei-max_step4), 0)
#             AEI_fr_ce_4 = np.maximum(dist_array_aei - max_step4, 0)
            print(np.sum(AEI_fr_ce_4))

            Pot_ATS4 = np.where(dist_array_cle == 0, AEI_fr_ce_4, 0)
            with np.errstate(divide='ignore'):
                AD_ra4 =np.where((ATS_4<np.sum(Pot_ATS4)),(ATS_4/np.sum(Pot_ATS4)), 1)
              

            if ATS_4>0:
                AD_area4=Pot_ATS4*AD_ra4
                
            else:
                AD_area4=Pot_ATS4*0
#                 TAD_14=AD_area1+AD_area2+AD_area3
            TAD_14=AD_area1+AD_area2+AD_area3+AD_area4
            
#             for row in range(TAD_14.shape[0]):
#                 for col in range(TAD_14.shape[1]):
#                     if TAD_14[row, col] <= dist_array_area[row, col]:
#                         TAD_14[row, col] = TAD_14[row, col]
#                     else:
#                         ratio = dist_array_area[row, col] / TAD_14[row, col]
#                         TAD_14[row, col] *= ratio


            # Create a list of dataframes to store the result for each crop
            df_list = []

            # Call the array to be distributed in step4 and convert it to dataframe
            array_name4 = "Array_" + ranked_df.Crop[i][:3] + ranked_df.Crop[i][-1] + "4"

            arr = TAD_14
            TAD_14_dict[unit_code] = TAD_14
#             print(arr)
            # Repeat it for every twelve months
            arr_re = np.repeat(arr, 12)
            # Change the array to dataframe
            df = pd.DataFrame(arr_re, index=np.arange(len(df_mon)), columns=[array_name4])
            # Merge the month and array dataframe
            df_area4 = pd.concat([df_mon, df], axis=1)
            # Filter the month in which the crop grows according to the crop calendar
            crop_1 = df_area4[(df_area4["Month"].isin(listcom))]
            # Filter the month in which the crop didn't grow according to the crop calendar
            crop_not = df_area4[(~df_area4["Month"].isin(listcom))]
            crop_not[array_name4].values[:] = 0
            # Merge the two dataframes and sort it based on index
            df_name4 = ranked_df.Crop[i][:3] + ranked_df.Crop[i][-1] + "_step4"
            df_name4 = pd.concat([crop_1, crop_not])
            df_name4 = df_name4.sort_index()

#             # Add the dataframe to the list
            df_list.append(df_name4[array_name4])
#             print(df_list)

            # Concatenate all the dataframes in the list into a single array
            Step_4 = pd.concat(df_list, axis=1).sum(axis=1)

#             for crop_ir in ranked_df['Crop'].unique():
#                 df_crop_ir = ranked_df[ranked_df['Crop'] == crop_ir]
            
            if 'df_cumulative_st4' not in locals() or df_cumulative_st4.empty:
   
                 df_cumulative_st4 = pd.Series(np.zeros(len(Step_4)), index=Step_4.index)

            df_cumulative_st4 += Step_4
            df_irrigaed=pd.concat([df_mon, Step_4], axis=1)
            df_irrigaed.columns = ['Month', 'Total_st4']
#             print(ranked_df["Crop"][i])
#             print(ranked_df["unit_code"][i])
#             print("Sum of Step_4:", df_irrigaed.max())

            df_tot_st4 = pd.concat([df_mon, df_cumulative_st4], axis=1)
            df_tot_st4.columns = ['Month', 'Total_st4']
          
#             print(ranked_df["Crop"][i])
#             print(ranked_df["unit_code"][i])
#             first_month_data = df_tot_st4[df_tot_st4['Month'] == 3]
#             first_month_sum = first_month_data['Total_st4'].sum()
#             print("First month cumulative sum across all crops:", first_month_sum)
            df_max_filt5 = df_tot_st4[df_tot_st4["Month"].isin(listcom)]
            n = len(df_max_filt5) // (r_s * c_s)
            df_max5 = df_max_filt5.groupby(np.arange(len(df_max_filt5)) // n).max()
            max_step5 = np.array(df_max5["Total_st4"]).reshape(r_s, c_s)
            
            aei_free[unit_code] = dist_array_aei
            cle_free[unit_code] = np.where(dist_array_cle > max_step5, (dist_array_cle - max_step5), 0)
            area[unit_code] = dist_array_area
            print("Step4")
            if round(np.sum(TAD_14)) < (ranked_df.Growing_area[i]):
                print("Error Check Your Code! (full area not assigned)")
                print("Area distributed after step4:", round(np.sum(TAD_14)))
            elif round(np.sum(TAD_14))==(ranked_df.Growing_area[i]):
                print("Iteration completed ")
                print("Area distributed after step4:", round(np.sum(TAD_14)))
            else:
                if (round(np.sum(TAD_14)) - (ranked_df_rf.Growing_area[i]))<1:
                    print("Iteration completed ")
                    print("Area distributed after step4", round(np.sum(TAD_14)))
            if ranked_df.Growing_area[i] > 0:
                with rasterio.open(tiff_ir) as src:
                    xmin, ymin, xmax, ymax = src.bounds
                    xres, yres = src.res
                    pixel_width, pixel_height = src.res
                    crs = src.crs

                    for k in listcom:
                        file_name = ranked_df.Crop[i][:3] + ranked_df.Crop[i][-1] + str(unit_code)+"_tot"
                        df_max_filt4 = df_irrigaed[(df_irrigaed["Month"] == int(k))]
                        arr_filenam = np.array(df_max_filt4["Total_st4"]).reshape(r_s, c_s)
                        mask = np.logical_or(np.isnan(arr_filenam), np.logical_or(np.isinf(arr_filenam), arr_filenam == np.NINF))
                        arr_filenam = np.where(mask, 0, arr_filenam)
                        arr_filenam = arr_filenam.astype(rasterio.float32)
                        Ras_filena = ranked_df.Crop[i][:3] + ranked_df.Crop[i][-1]+ "_"+ str(unit_code)+"_" +"ir" +"_"+str(k)
                        transform = rasterio.transform.from_origin(xmin, ymax, pixel_width, pixel_height)
                        profile = {
                            'driver': 'GTiff',
                            'dtype': arr_filenam.dtype,
                            'count': 1,
                            'height': arr_filenam.shape[0],
                            'width': arr_filenam.shape[1],
                            'transform': transform,
                            'crs': crs,
                            'nodata': 0
                        }
                        output_folder = r"D:\\PhD_Udel\\MICRA_2015\DOwnscaling\\All_maps\\Global maps\\Maps 2005\\District\\Irrigated"
                        with rasterio.open(os.path.join(output_folder, Ras_filena + '.tif'), 'w', **profile) as dst:
                            dst.write(arr_filenam, 1)
    for unit_code_rf in ranked_df_rf['unit_code'].unique():
#         for unit_code in ranked_df['unit_code'].unique():
        for k in range(1, int(np.max(ranked_df_rf['rank']) + 1)):
            rows = ranked_df_rf.loc[(ranked_df_rf['unit_code'] == unit_code_rf) & (ranked_df_rf['rank'] == k)]
            for i_rf, row in rows.iterrows():
                if unit_code_rf == unit_code:
                    # Use aei_free[unit_code] in the calculations
                    TAD_14_for_unit = TAD_14_dict.get(unit_code)
                    dist_array_area = area.get(unit_code)
                    dist_array_aei = aei_free.get(unit_code)
                    dist_array_cle = cle_free.get(unit_code)
                    if dist_array_area is not None and dist_array_aei is not None and dist_array_cle is not None:
                        p = ranked_df_rf.Planting_Month[i_rf]
                        m = ranked_df_rf.Maturity_Month[i_rf]
                        listcomrf = getListcom(p, m)
                        for tiff_file in tiff_files:
        #                     print(tiff_file)
                            for subfolder_path in sub_dirs[1:]:
                                subfolder_name = os.path.basename(subfolder_path)
            #                     print(subfolder_name)
            #                     print(os.path.basename(tiff_file)[:-4])
                                if os.path.basename(tiff_file)[:-4] == str(unit_code_rf):
                                    if subfolder_name == "AEI_05":
                                        tiff_rf=tiff_file     
            #                 Perform calculations using the retrieved aei_free[unit_code]

                        ATS_5 = ranked_df_rf.Growing_area[i_rf]
                        if ranked_df_rf.Crop[i_rf] in Annual:
                            Pot_ATS5 = dist_array_cle
                        else:
                            Pot_ATS5 = np.where(dist_array_cle > dist_array_aei, dist_array_cle, 0)
                        with np.errstate(divide='ignore'):
                            AD_ra5=np.where(ATS_5<np.sum(Pot_ATS5),(ATS_5/np.sum(Pot_ATS5)), 1)
                        AD_area5=Pot_ATS5*AD_ra5
                        TAD_5=AD_area5
#     #                         for row in range(TAD_5.shape[0]):
#     #                             for col in range(TAD_5.shape[1]):
#     #                                 if TAD_5[row, col] <= dist_array_area[row, col]:
#     #                                     TAD_5[row, col] = TAD_5[row, col]
#     #                                 else:
#     #                                     ratio = dist_array_area[row, col] / TAD_5[row, col]
#     #                                     TAD_5[row, col] *= ratio
#                                     #             print(TAD_5)
                        #Call the array to be distributed in step4 and convert it to dataframe
                        df_list = []
                        array_name5="Array_"+ranked_df_rf.Crop[i][:3]+ranked_df_rf.Crop[i][-1]+"5"
            #                         print(array_name)
                        arr=TAD_5
                        #repaeat it for every tweleve month
                        arr_re5=np.repeat(arr, 12)
                        #Change the array to dataframe
                        c_s = len(arr[0])
                        r_s = len(arr)
                        df_month = pd.DataFrame(np.arange(1, 13), columns=['Month'])
                        df_mon = pd.concat([df_month] * c_s * r_s, ignore_index=True)
                        # Change the array to dataframe
                        df_5 = pd.DataFrame(arr_re5, index=np.arange(len(df_mon)), columns=[array_name5])
                        # Merge the month and array dataframe
                        df_area5 = pd.concat([df_mon, df_5], axis=1)
                        #Filter the month in which the crop grows accporidng to the crop calendar
                        crop_1=df_area5[(df_area5["Month"].isin(listcomrf))]
                        #Filter the month in which the crop didn't grows accporidng to the crop calendar
                        crop_not=df_area5[(~df_area5["Month"].isin(listcomrf))]
                        for col in crop_not.columns:
                            crop_not[array_name5].values[:] = 0 
                        # Merge the two dataframes and sort it based on index
                        df_name5 = ranked_df_rf.Crop[i][:3] + ranked_df_rf.Crop[i][-1] + "_step5"
                        df_name5 = pd.concat([crop_1, crop_not])
                        df_name5 = df_name5.sort_index()
            #             d_tot=df_name4+df_name3=df_name2+df_name1
            #                         print(df_name5)
            #             # Add the dataframe to the list
                        df_list.append(df_name5[array_name5])
            #             print(df_list)

                        # Concatenate all the dataframes in the list into a single array
                        Step_5 = pd.concat(df_list, axis=1).sum(axis=1)
            #             print(Step_4)
                        # Create a dataframe from the final array
                        if 'df_cumulative_st5' not in locals() or df_cumulative_st5.empty:

                             df_cumulative_st5 = pd.Series(np.zeros(len(Step_5)), index=Step_5.index)

                        df_cumulative_st5 += Step_5
                        df_tot_st5 = pd.concat([df_mon, df_cumulative_st5], axis=1)
                        df_tot_st5.columns = ['Month', 'Total_st5']
            #                         print("step5:", np.shape(df_tot_st5))
            #             print("AEI:", np.shape(dist_array_aei))
                        print("unit code:", ranked_df_rf.unit_code[i_rf])
                        print("Step5")
                        print("Crop:", ranked_df_rf.Crop[i_rf])
                        if round(np.sum(TAD_5),2) < (ranked_df_rf.Growing_area[i_rf]):
                            print("Iteration continues")
                            AD_step5=AD_area5
                            ATS_6= (ranked_df_rf.Growing_area[i_rf])-np.sum(TAD_5)
                            print("Area distributed after step5:", round(np.sum(TAD_5),2))
                            print("Area to be distributed in next step:", ATS_6)
                        elif round(np.sum(TAD_5),2)==(ranked_df_rf.Growing_area[i_rf]):
                            print("Iteration completed ")
                            AD_step5=AD_area5
                            ATS_6= 0
                            print("Area distributed after step5:",round(np.sum(TAD_5),2))
                        else:
                            if ranked_df_rf.Growing_area[i_rf]== 0:
                                AD_step5=AD_area5*0
                                ATS_6= 0
                                print("No area will be distributed in step5 (zero harvested area)")
                            elif ranked_df_rf.Growing_area[i_rf] >0:
                                print("Error check your code!")
                                print("More area available than the growing area")
                                ratio=ranked_df_rf.Growing_area[i_rf]/np.sum(TAD_5)
                                AD_step5=AD_area5*ratio
                                ATS_6= 0
                                print("Iteration completed")
                                print("Area distributed after step5:", round(np.sum(AD_step5),2))


                        #Step6
                        #Select the total dataframe for a month in which crop grow
                        df_max_filt6=df_tot_st5[(df_tot_st5["Month"].isin(listcomrf))]
                        #group the cell values
                        n=len(df_max_filt6)/(r_s*c_s)
                        #Select the maximum total area assigned for the month in which this crop grow
                        df_max6= df_max_filt6.groupby(np.arange(len(df_max_filt6))//n).max()
                        #Change it to array
                        max_step6=np.array(df_max6["Total_st5"]).reshape(r_s, c_s)
                        ##Detrmine the free AEI cell
                        AEI_fr_ce_6 = np.where(dist_array_aei > max_step6, (dist_array_aei-max_step6), 0)
                        CLE_free_6=np.where(dist_array_cle > max_step6, (dist_array_cle-max_step6), 0)
                        area_95_=0.95*dist_array_area
                        free_area_95_6=np.where(area_95_> max_step6, (area_95_-max_step6), 0)
                        if ranked_df_rf.Crop[i_rf] in Annual:

                            Pot_ATS6=np.where(dist_array_cle>0,(AEI_fr_ce_6), 0)
                        else:

                            Pot_ATS6=np.where(dist_array_cle>dist_array_aei,(free_area_95_6), 0)
                        with np.errstate(divide='ignore'):
                            AD_ra6=np.where(ATS_6<np.sum(Pot_ATS6),(ATS_6/np.sum(Pot_ATS6)), 1)
                        if ATS_6>0:
                            AD_area6=Pot_ATS6*AD_ra6

                        else:
                            AD_area6=(Pot_ATS6*AD_ra6)*0
                        TAD_56=AD_area5+AD_area6

            #             print(TAD_5)
                        #Call the array to be distributed in step4 and convert it to dataframe
                        df_list = []
                        array_name6="Array_"+ranked_df_rf.Crop[i_rf][:3]+ranked_df_rf.Crop[i_rf][-1]+"6"
            #             print(array_name)
                        arr=TAD_56
                        #repaeat it for every tweleve month
                        arr_re6=np.repeat(arr, 12)
                        #Change the array to dataframe
                        df_6=pd.DataFrame(arr_re6,index=np.arange(len(df_mon)),columns = [array_name6])
                        #Merge the month and array datarame
                        df_area6 = pd.concat([df_mon, df_6], axis=1)
                        #Filter the month in which the crop grows accporidng to the crop calendar
                        crop_1=df_area6[(df_area6["Month"].isin(listcomrf))]
                        #Filter the month in which the crop didn't grows accporidng to the crop calendar
                        crop_not=df_area6[(~df_area6["Month"].isin(listcomrf))]
                        for col in crop_not.columns:
                            crop_not[array_name6].values[:] = 0
                        #Merge the two datafra'mes and sort it based on index
                        df_name6 = ranked_df_rf.Crop[i_rf][:3] + ranked_df_rf.Crop[i_rf][-1] + "_step6"
                        df_name6 = pd.concat([crop_1, crop_not])
                        df_name6 = df_name6.sort_index()
            #             d_tot=df_name4+df_name3=df_name2+df_name1
            #             print(Ric1_step4)
            #             # Add the dataframe to the list
                        df_list.append(df_name6[array_name6])
            #             print(df_list)

                        # Concatenate all the dataframes in the list into a single array
                        Step_6 = pd.concat(df_list, axis=1).sum(axis=1)
                        if 'df_cumulative_st6' not in locals() or df_cumulative_st6.empty:

                             df_cumulative_st6 = pd.Series(np.zeros(len(Step_6)), index=Step_6.index)

                        df_cumulative_st6 += Step_6
            #             print(Step_4)
                        # Create a dataframe from the final array
                        df_tot_st6 = pd.concat([df_mon, df_cumulative_st6], axis=1)
                        df_tot_st6.columns = ['Month', 'Total_st6']
                        print("Step6")
#                         print("Crop:", ranked_df_rf.Crop[i_rf])
                        if round(np.sum(TAD_56),2) < (ranked_df_rf.Growing_area[i_rf]):
                            print("Iteration continues")
                            AD_step6=TAD_56
                            ATS_7= (ranked_df_rf.Growing_area[i_rf])-np.sum(TAD_56)
                            print("Area distributed after step6:", round(np.sum(TAD_56),2))
                            print("Area to be distributed in next step:", ATS_7)
                        elif round(np.sum(TAD_56),2)==(ranked_df_rf.Growing_area[i_rf]):
                            print("Iteration completed ")
                            AD_step6=TAD_56
                            ATS_7= 0
                            print("Area distributed after step6:", round(np.sum(TAD_56),2))

                        else:
                            if ranked_df_rf.Growing_area[i_rf]== 0:
                                AD_step6=TAD_56*0
                                ATS_7= 0
                                print("No area will be distributed in step6 (zero harvested area)")
                            elif ranked_df_rf.Growing_area[i_rf] >0:
                                print("Error check your code!")
                                print("More area available than the growing area")
                                ratio=ranked_df_rf.Growing_area[i_rf]/np.sum(TAD_56)
                                AD_step6=TAD_56*ratio
                                ATS_7= 0
                                print("Iteration completed ")
                                print("Area distributed after step6:", round(np.sum(AD_step6),2)) 

                        #Step7
                        #Select the total dataframe for a month in which crop grow
                        df_list = []
                        df_max_filt7=df_tot_st6[(df_tot_st6["Month"].isin(listcomrf))]
                        #group the cell values
                        n=len(df_max_filt7)/(r_s*c_s)
                        #Select the maximum total area assigned for the month in which this crop grow
                        df_max7= df_max_filt7.groupby(np.arange(len(df_max_filt7))//n).max()
                        #Change it to array
                        max_step7=np.array(df_max7["Total_st6"]).reshape(r_s, c_s)
                        ##Detrmine the 95% of cell area
                        AEI_fr_ce_7 = np.where(dist_array_aei > max_step7, (dist_array_aei-max_step7), 0)
                        CLE_free_7=np.where(dist_array_cle > max_step7, (dist_array_cle-max_step7), 0)
                        area_95_=0.95*dist_array_area
                        free_area_95_7=np.where(area_95_> max_step7, (area_95_-max_step7), 0)

            #             print("ATS",ATS_3)
                        Pot_ATS7=np.where(((dist_array_cle>0)|(dist_array_aei>0)) ,(free_area_95_7), 0)
            #             print("POTS",Pot_ATS7)
                        with np.errstate(divide='ignore'):
                            AD_ra7=np.where(ATS_7<np.sum(Pot_ATS7),(ATS_7/np.sum(Pot_ATS7)), 1)
                        if ATS_7>0:
                            AD_area7=Pot_ATS7*AD_ra7

                        else:
                            AD_area7=(Pot_ATS7*AD_ra7)*0
#                             TAD_57=AD_area5+AD_area6
                        TAD_57=AD_area5+AD_area6+AD_area7

#                       
                        #Call the array to be distributed in step4 and convert it to dataframe
                        array_name7="Array_"+ranked_df_rf.Crop[i][:3]+ranked_df_rf.Crop[i][-1]+"7"
            #             print(array_name)
                        arr=TAD_57
                        #repaeat it for every tweleve month
                        arr_re7=np.repeat(arr, 12)
                        #Change the array to dataframe
                        df_7=pd.DataFrame(arr_re7,index=np.arange(len(df_mon)),columns = [array_name7])
                        #Merge the month and array datarame
                        df_area7 = pd.concat([df_mon, df_7], axis=1)
                        #Filter the month in which the crop grows accporidng to the crop calendar
                        crop_1=df_area7[(df_area7["Month"].isin(listcomrf))]
                        #Filter the month in which the crop didn't grows accporidng to the crop calendar
                        crop_not=df_area7[(~df_area7["Month"].isin(listcomrf))]
                        for col in crop_not.columns:
                            crop_not[array_name7].values[:] = 0
                        #Merge the two datafra'mes and sort it based on index
            #Merge the two datafra'mes and sort it based on index
                        #Merge the two datafra'mes and sort it based on index
                        df_name7 = ranked_df_rf.Crop[i_rf][:3] + ranked_df_rf.Crop[i_rf][-1] + "_step7"
                        df_name7 = pd.concat([crop_1, crop_not])
                        df_name7 = df_name7.sort_index()
            #             d_tot=df_name4+df_name3=df_name2+df_name1
            #             print(Ric1_step4)
            #             # Add the dataframe to the list
                        df_list.append(df_name7[array_name7])
            #             print(df_list)

                        # Concatenate all the dataframes in the list into a single array
                        Step_7 = pd.concat(df_list, axis=1).sum(axis=1)
                        if 'df_cumulative_st7' not in locals() or df_cumulative_st7.empty:

                             df_cumulative_st7 = pd.Series(np.zeros(len(Step_7)), index=Step_7.index)

                        df_cumulative_st7 += Step_7
            #             print(Step_4)
                        # Create a dataframe from the final array
                        df_rainfed=pd.concat([df_mon, Step_7], axis=1)
                        df_rainfed.columns = ['Month', 'Total_st7']
                        df_tot_st7 = pd.concat([df_mon, df_cumulative_st7], axis=1)
                        df_tot_st7.columns = ['Month', 'Total_st7']
            #                         print("Step 7 rainfed total:",df_tot_st7.head() )
            #                         Define the spatial extent and resolution of the output raster
                        print("Step7")
#                         print("Crop:", ranked_df_rf.Crop[i_rf])
                        if round(np.sum(TAD_57)) < (ranked_df_rf.Growing_area[i_rf]):
                            print("Error Check Your Code!")
                            print("Area distributed after step7:", round(np.sum(TAD_57)))
                        elif round(np.sum(TAD_57))==(ranked_df.Growing_area[i_rf]):
                            print("Iteration completed ")
                            print("Area distributed after step7", round(np.sum(TAD_57)))
                        else:
                            if (round(np.sum(TAD_57)) - (ranked_df_rf.Growing_area[i_rf]))<1:
                                print("Iteration completed ")
                                print("Area distributed after step7", round(np.sum(TAD_57)))

                        if ranked_df_rf.Growing_area[i_rf]>0:
                            with rasterio.open(tiff_rf) as src:
                                xmin, ymin, xmax, ymax = src.bounds
                                xres, yres = src.res
                                pixel_width, pixel_height = src.res
                                crs = src.crs

                                for k in listcomrf:
                                    file_name = ranked_df_rf.Crop[i_rf][:3] + ranked_df_rf.Crop[i_rf][-1] + str(unit_code)+"_tot"
                                    df_max_filt7 = df_rainfed[(df_rainfed["Month"] == int(k))]
                                    arr_filenam = np.array(df_max_filt7["Total_st7"]).reshape(r_s, c_s)
                                    mask = np.logical_or(np.isnan(arr_filenam), np.logical_or(np.isinf(arr_filenam), arr_filenam == np.NINF))
                                    arr_filenam = np.where(mask, 0, arr_filenam)
                                    arr_filenam = arr_filenam.astype(rasterio.float32)
                                    Ras_filena = ranked_df_rf.Crop[i_rf][:3] +ranked_df_rf.Crop[i_rf][-1]+ "_"+ str(unit_code)+"_" +"rf" +"_"+str(k)
                                    transform = rasterio.transform.from_origin(xmin, ymax, pixel_width, pixel_height)
                                    profile = {
                                        'driver': 'GTiff',
                                        'dtype': arr_filenam.dtype,
                                        'count': 1,
                                        'height': arr_filenam.shape[0],
                                        'width': arr_filenam.shape[1],
                                        'transform': transform,
                                        'crs': crs,
                                        'nodata': 0
                                    }
                                    output_folder =   r"D:\\PhD_Udel\\MICRA_2015\DOwnscaling\\All_maps\\Global maps\\Maps 2005\\District\\Rainfed"
                                    with rasterio.open(os.path.join(output_folder, Ras_filena + '.tif'), 'w', **profile) as dst:
                                        dst.write(arr_filenam, 1)
# Out:
# 3560539
# Step1
# Crop: Sugar cane
# Error check your code!
# More area available than the growing area
# Iteration completed
# Area distributed in step1: 245.0
# Step2
# Iteration completed
# Area distributed after step2: 245.0
# Step3
# Iteration completed
# Area distributed after step3 245.0
# 234746.09719873103
# Step4
# Iteration completed
# Area distributed after step4: 245
# 3560539
# Step1
# Crop: Cocoa
# Iteration completed
# Area distributed after step1: 0.0
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 234746.09719873103
# Step4
# Iteration completed
# Area distributed after step4: 0
# 3560539
# Step1
# Crop: Coffee
# Iteration completed
# Area distributed after step1: 0.0
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 234746.09719873103
# Step4
# Iteration completed
# Area distributed after step4: 0
# 3560539
# Step1
# Crop: Oil palm
# Iteration completed
# Area distributed after step1: 0.0
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 234746.09719873103
# Step4
# Iteration completed
# Area distributed after step4: 0
# 3560539
# Step1
# Crop: Others perennial
# Iteration continues
# Area distributed after step1: 4057.92
# Area to be distributed in next step: 3015.080078125
# Step2
# Iteration continues
# Area distributed after step2: 6525.01
# Area to be distributed in next step: 547.9899999999998
# Step3
# Iteration completed
# Area distributed after step3 7073.0
# 227673.10081206355
# Step4
# Iteration completed
# Area distributed after step4: 7073
# 3560539
# Step1
# Crop: Fodder
# Error check your code!
# More area available than the growing area
# Iteration completed
# Area distributed in step1: 5895.0
# Step2
# Iteration completed
# Area distributed after step2: 5895.0
# Step3
# Iteration completed
# Area distributed after step3 5895.0
# 221778.1010083938
# Step4
# Iteration completed
# Area distributed after step4: 5895
# 3560539
# Step1
# Crop: Wheat1
# Iteration continues
# Area distributed after step1: 76735.72
# Area to be distributed in next step: 1624.28125
# Step2
# Iteration completed
# Area distributed after step2: 78360.0
# Step3
# Iteration completed
# Area distributed after step3 78360.0
# 143418.09879431967
# Step4
# Iteration completed
# Area distributed after step4: 78360
# 3560539
# Step1
# Crop: Wheat2
# Iteration continues
# Area distributed after step1: 76735.72
# Area to be distributed in next step: 1624.28125
# Step2
# Iteration completed
# Area distributed after step2: 78360.0
# Step3
# Iteration completed
# Area distributed after step3 78360.0
# 143418.09879431967
# Step4
# Iteration completed
# Area distributed after step4: 78360
# 3560539
# Step1
# Crop: Rapeseed
# Iteration continues
# Area distributed after step1: 36688.04
# Area to be distributed in next step: 20566.9609375
# Step2
# Iteration completed
# Area distributed after step2: 57255.0
# Step3
# Iteration completed
# Area distributed after step3 57255.0
# 86163.09823642019
# Step4
# Iteration completed
# Area distributed after step4: 57255
# 3560539
# Step1
# Crop: Potatoes
# Iteration continues
# Area distributed after step1: 2189.0
# Area to be distributed in next step: 27342.0
# Step2
# Iteration continues
# Area distributed after step2: 3771.66
# Area to be distributed in next step: 25759.34
# Step3
# Iteration completed
# Area distributed after step3 29531.0
# 56663.39524627695
# Step4
# Iteration completed
# Area distributed after step4: 29531
# 3560539
# Step1
# Crop: Rice1
# Iteration continues
# Area distributed after step1: 2525.4
# Area to be distributed in next step: 5341.60009765625
# Step2
# Iteration continues
# Area distributed after step2: 7231.98
# Area to be distributed in next step: 635.0200000000004
# Step3
# Iteration completed
# Area distributed after step3 7867.0
# 49099.04099874482
# Step4
# Iteration completed
# Area distributed after step4: 7867
# 3560539
# Step1
# Crop: Rice2
# Iteration continues
# Area distributed after step1: 2525.4
# Area to be distributed in next step: 5341.60009765625
# Step2
# Iteration continues
# Area distributed after step2: 7231.98
# Area to be distributed in next step: 635.0200000000004
# Step3
# Iteration completed
# Area distributed after step3 7867.0
# 71019.23841018236
# Step4
# Iteration completed
# Area distributed after step4: 7867
# 3560539
# Step1
# Crop: Barley
# Error check your code!
# More area available than the growing area
# Iteration completed
# Area distributed in step1: 6422.0
# Step2
# Iteration completed
# Area distributed after step2: 6422.0
# Step3
# Iteration completed
# Area distributed after step3 6422.0
# 42701.69206743226
# Step4
# Iteration completed
# Area distributed after step4: 6422
# 3560539
# Step1
# Crop: Pulses
# Error check your code!
# More area available than the growing area
# Iteration completed
# Area distributed in step1: 2487.0
# Step2
# Iteration completed
# Area distributed after step2: 2487.0
# Step3
# Iteration completed
# Area distributed after step3 2487.0
# 68592.72371215379
# Step4
# Iteration completed
# Area distributed after step4: 2487
# 3560539
# Step1
# Crop: Maize
# Iteration continues
# Area distributed after step1: 1371.17
# Area to be distributed in next step: 848.8299560546875
# Step2
# Iteration continues
# Area distributed after step2: 2106.75
# Area to be distributed in next step: 113.25
# Step3
# Iteration completed
# Area distributed after step3 2220.0
# 97378.09656845997
# Step4
# Iteration completed
# Area distributed after step4: 2220
# 3560539
# Step1
# Crop: Millet
# Iteration continues
# Area distributed after step1: 0.0
# Area to be distributed in next step: 1698.0
# Step2
# Iteration continues
# Area distributed after step2: 0.0
# Area to be distributed in next step: 1698.0
# Step3
# Iteration completed
# Area distributed after step3 1698.0
# 40302.17325442093
# Step4
# Iteration completed
# Area distributed after step4: 1698
# 3560539
# Step1
# Crop: Cassava
# Iteration continues
# Area distributed after step1: 147.28
# Area to be distributed in next step: 326.7200012207031
# Step2
# Iteration continues
# Area distributed after step2: 337.32
# Area to be distributed in next step: 136.68
# Step3
# Iteration completed
# Area distributed after step3 474.0
# 68141.63740989997
# Step4
# Iteration completed
# Area distributed after step4: 474
# 3560539
# Step1
# Crop: Sorghum
# Error check your code!
# More area available than the growing area
# Iteration completed
# Area distributed in step1: 177.0
# Step2
# Iteration completed
# Area distributed after step2: 177.0
# Step3
# Iteration completed
# Area distributed after step3 177.0
# 40126.943482419425
# Step4
# Iteration completed
# Area distributed after step4: 177
# 3560539
# Step1
# Crop: Groundnuts
# Iteration continues
# Area distributed after step1: 1.69
# Area to be distributed in next step: 91.30999994277954
# Step2
# Iteration continues
# Area distributed after step2: 3.34
# Area to be distributed in next step: 89.66
# Step3
# Iteration completed
# Area distributed after step3 93.0
# 40033.94748322862
# Step4
# Iteration completed
# Area distributed after step4: 93
# 3560539
# Step1
# Crop: Cotton
# Iteration continues
# Area distributed after step1: 64.08
# Area to be distributed in next step: 2.9199981689453125
# Step2
# Iteration completed
# Area distributed after step2: 67.0
# Step3
# Iteration completed
# Area distributed after step3 67.0
# 39969.173683739704
# Step4
# Iteration completed
# Area distributed after step4: 67
# 3560539
# Step1
# Crop: Sunflower
# Iteration continues
# Area distributed after step1: 3.86
# Area to be distributed in next step: 35.140000104904175
# Step2
# Iteration continues
# Area distributed after step2: 6.71
# Area to be distributed in next step: 32.29
# Step3
# Iteration completed
# Area distributed after step3 39.0
# 39930.17140534382
# Step4
# Iteration completed
# Area distributed after step4: 39
# 3560539
# Step1
# Crop: Soybeans
# Error check your code!
# More area available than the growing area
# Iteration completed
# Area distributed in step1: 7.0
# Step2
# Iteration completed
# Area distributed after step2: 7.0
# Step3
# Iteration completed
# Area distributed after step3 7.0
# 39923.17452600984
# Step4
# Iteration completed
# Area distributed after step4: 7
# 3560539
# Step1
# Crop: Sugar beet
# Iteration completed
# Area distributed after step1: 0.0
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 39923.17452600984
# Step4
# Iteration completed
# Area distributed after step4: 0
# 3560539
# Step1
# Crop: Others annual1
# Iteration continues
# Area distributed after step1: 8705.18
# Area to be distributed in next step: 9592.8203125
# Step2
# Iteration continues
# Area distributed after step2: 16091.28
# Area to be distributed in next step: 2206.7199999999993
# Step3
# Iteration completed
# Area distributed after step3 18298.0
# 51092.81362836306
# Step4
# Iteration completed
# Area distributed after step4: 18298
# 3560539
# Step1
# Crop: Others annual2
# No area will be distributed in step1 (Zero harvested area)
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 100915.346114284
# Step4
# Iteration completed
# Area distributed after step4: 0
# 3560539
# Step1
# Crop: Others annual3
# No area will be distributed in step1 (Zero harvested area)
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 95297.09649871328
# Step4
# Iteration completed
# Area distributed after step4: 0
# unit code: 3560539
# Step5
# Crop: Sugar cane
# Iteration completed
# Area distributed after step5: 10.0
# Step6
# Iteration completed
# Area distributed after step6: 10.0
# Step7
# Iteration completed
# Area distributed after step7 10
# unit code: 3560539
# Step5
# Crop: Cocoa
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 3560539
# Step5
# Crop: Coffee
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 3560539
# Step5
# Crop: Oil palm
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 3560539
# Step5
# Crop: Others perennial
# Iteration completed
# Area distributed after step5: 3089.0
# Step6
# Iteration completed
# Area distributed after step6: 3089.0
# Step7
# Iteration completed
# Area distributed after step7 3089
# unit code: 3560539
# Step5
# Crop: Fodder
# Iteration completed
# Area distributed after step5: 8367.0
# Step6
# Iteration completed
# Area distributed after step6: 8367.0
# Step7
# Iteration completed
# Area distributed after step7 8367
# unit code: 3560539
# Step5
# Crop: Millet
# Iteration completed
# Area distributed after step5: 98616.0
# Step6
# Iteration completed
# Area distributed after step6: 98616.0
# Step7
# Iteration completed
# Area distributed after step7 98616
# unit code: 3560539
# Step5
# Crop: Pulses
# Iteration completed
# Area distributed after step5: 6763.0
# Step6
# Iteration completed
# Area distributed after step6: 6763.0
# Step7
# Iteration completed
# Area distributed after step7 6763
# unit code: 3560539
# Step5
# Crop: Rice1
# Iteration completed
# Area distributed after step5: 6616.0
# Step6
# Iteration completed
# Area distributed after step6: 6616.0
# Step7
# Iteration completed
# Area distributed after step7 6616
# unit code: 3560539
# Step5
# Crop: Rapeseed
# Iteration completed
# Area distributed after step5: 6385.0
# Step6
# Iteration completed
# Area distributed after step6: 6385.0
# Step7
# Iteration completed
# Area distributed after step7 6385
# unit code: 3560539
# Step5
# Crop: Barley
# Iteration completed
# Area distributed after step5: 2700.0
# Step6
# Iteration completed
# Area distributed after step6: 2700.0
# Step7
# Iteration completed
# Area distributed after step7 2700
# unit code: 3560539
# Step5
# Crop: Sorghum
# Iteration completed
# Area distributed after step5: 1576.0
# Step6
# Iteration completed
# Area distributed after step6: 1576.0
# Step7
# Iteration completed
# Area distributed after step7 1576
# unit code: 3560539
# Step5
# Crop: Wheat1
# Iteration completed
# Area distributed after step5: 1035.0
# Step6
# Iteration completed
# Area distributed after step6: 1035.0
# Step7
# Iteration completed
# Area distributed after step7 1035
# unit code: 3560539
# Step5
# Crop: Maize
# Iteration completed
# Area distributed after step5: 163.0
# Step6
# Iteration completed
# Area distributed after step6: 163.0
# Step7
# Iteration completed
# Area distributed after step7 163
# unit code: 3560539
# Step5
# Crop: Wheat2
# Iteration completed
# Area distributed after step5: 115.0
# Step6
# Iteration completed
# Area distributed after step6: 115.0
# Step7
# Iteration completed
# Area distributed after step7 115
# unit code: 3560539
# Step5
# Crop: Potatoes
# Iteration completed
# Area distributed after step5: 67.0
# Step6
# Iteration completed
# Area distributed after step6: 67.0
# Step7
# Iteration completed
# Area distributed after step7 67
# unit code: 3560539
# Step5
# Crop: Cotton
# Iteration completed
# Area distributed after step5: 24.0
# Step6
# Iteration completed
# Area distributed after step6: 24.0
# Step7
# Iteration completed
# Area distributed after step7 24
# unit code: 3560539
# Step5
# Crop: Groundnuts
# Iteration completed
# Area distributed after step5: 20.0
# Step6
# Iteration completed
# Area distributed after step6: 20.0
# Step7
# Iteration completed
# Area distributed after step7 20
# unit code: 3560539
# Step5
# Crop: Sunflower
# Iteration completed
# Area distributed after step5: 1.0
# Step6
# Iteration completed
# Area distributed after step6: 1.0
# Step7
# Iteration completed
# Area distributed after step7 1
# unit code: 3560539
# Step5
# Crop: Cassava
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 3560539
# Step5
# Crop: Rice2
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 3560539
# Step5
# Crop: Soybeans
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 3560539
# Step5
# Crop: Sugar beet
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 3560539
# Step5
# Crop: Others annual1
# Iteration completed
# Area distributed after step5: 3431.0
# Step6
# Iteration completed
# Area distributed after step6: 3431.0
# Step7
# Iteration completed
# Area distributed after step7 3431
# unit code: 3560539
# Step5
# Crop: others annual2
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 3560539
# Step5
# Crop: others annual3
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# 3560540
# Step1
# Crop: Sugar cane
# Error check your code!
# More area available than the growing area
# Iteration completed
# Area distributed in step1: 3519.0
# Step2
# Iteration completed
# Area distributed after step2: 3519.0
# Step3
# Iteration completed
# Area distributed after step3 3519.0
# 313287.92273139954
# Step4
# Iteration completed
# Area distributed after step4: 3519
# 3560540
# Step1
# Crop: Oil palm
# Iteration continues
# Area distributed after step1: 0.0
# Area to be distributed in next step: 13.0
# Step2
# Iteration continues
# Area distributed after step2: 0.0
# Area to be distributed in next step: 13.0
# Step3
# Iteration completed
# Area distributed after step3 13.0
# 313274.92273139954
# Step4
# Iteration completed
# Area distributed after step4: 13
# 3560540
# Step1
# Crop: Cocoa
# Iteration completed
# Area distributed after step1: 0.0
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 313274.92273139954
# Step4
# Iteration completed
# Area distributed after step4: 0
# 3560540
# Step1
# Crop: Coffee
# Iteration completed
# Area distributed after step1: 0.0
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 313274.92273139954
# Step4
# Iteration completed
# Area distributed after step4: 0
# 3560540
# Step1
# Crop: Others perennial
# Error check your code!
# More area available than the growing area
# Iteration completed
# Area distributed in step1: 3784.0
# Step2
# Iteration completed
# Area distributed after step2: 3784.0
# Step3
# Iteration completed
# Area distributed after step3 3784.0
# 309490.92258644104
# Step4
# Iteration completed
# Area distributed after step4: 3784
# 3560540
# Step1
# Crop: Fodder
# Error check your code!
# More area available than the growing area
# Iteration completed
# Area distributed in step1: 22392.0
# Step2
# Iteration completed
# Area distributed after step2: 22392.0
# Step3
# Iteration completed
# Area distributed after step3 22392.0
# 287098.9211063385
# Step4
# Iteration completed
# Area distributed after step4: 22392
# 3560540
# Step1
# Crop: Wheat1
# Iteration continues
# Area distributed after step1: 97779.09
# Area to be distributed in next step: 12630.90625
# Step2
# Iteration continues
# Area distributed after step2: 110409.99
# Area to be distributed in next step: 0.00999999999476131
# Step3
# Iteration completed
# Area distributed after step3 110410.0
# 176688.92160438537
# Step4
# Iteration completed
# Area distributed after step4: 110410
# 3560540
# Step1
# Crop: Wheat2
# Iteration continues
# Area distributed after step1: 97779.09
# Area to be distributed in next step: 12630.90625
# Step2
# Iteration continues
# Area distributed after step2: 110409.99
# Area to be distributed in next step: 0.00999999999476131
# Step3
# Iteration completed
# Area distributed after step3 110410.0
# 176688.92160438537
# Step4
# Iteration completed
# Area distributed after step4: 110410
# 3560540
# Step1
# Crop: Rice1
# Iteration continues
# Area distributed after step1: 13811.04
# Area to be distributed in next step: 25033.9599609375
# Step2
# Iteration continues
# Area distributed after step2: 30600.72
# Area to be distributed in next step: 8244.279999999999
# Step3
# Iteration completed
# Area distributed after step3 38845.0
# 137843.91977210998
# Step4
# Iteration completed
# Area distributed after step4: 38845
# 3560540
# Step1
# Crop: Rice2
# Iteration continues
# Area distributed after step1: 13811.04
# Area to be distributed in next step: 25033.9599609375
# Step2
# Iteration continues
# Area distributed after step2: 30600.72
# Area to be distributed in next step: 8244.279999999999
# Step3
# Iteration completed
# Area distributed after step3 38845.0
# 137843.91977210998
# Step4
# Iteration completed
# Area distributed after step4: 38845
# 3560540
# Step1
# Crop: Maize
# Iteration continues
# Area distributed after step1: 13860.82
# Area to be distributed in next step: 9233.1796875
# Step2
# Iteration continues
# Area distributed after step2: 15442.48
# Area to be distributed in next step: 7651.52
# Step3
# Iteration completed
# Area distributed after step3 23094.0
# 114749.91813606262
# Step4
# Iteration completed
# Area distributed after step4: 23094
# 3560540
# Step1
# Crop: Rapeseed
# Iteration continues
# Area distributed after step1: 7794.97
# Area to be distributed in next step: 9749.02978515625
# Step2
# Iteration continues
# Area distributed after step2: 12244.74
# Area to be distributed in next step: 5299.26
# Step3
# Iteration completed
# Area distributed after step3 17544.0
# 120299.91520900726
# Step4
# Iteration completed
# Area distributed after step4: 17544
# 3560540
# Step1
# Crop: Pulses
# Iteration continues
# Area distributed after step1: 14844.36
# Area to be distributed in next step: 62.6396484375
# Step2
# Iteration completed
# Area distributed after step2: 14907.0
# Step3
# Iteration completed
# Area distributed after step3 14907.0
# 105392.91540737152
# Step4
# Iteration completed
# Area distributed after step4: 14907
# 3560540
# Step1
# Crop: Barley
# Iteration continues
# Area distributed after step1: 9855.35
# Area to be distributed in next step: 2377.650390625
# Step2
# Iteration continues
# Area distributed after step2: 11153.48
# Area to be distributed in next step: 1079.5200000000004
# Step3
# Iteration completed
# Area distributed after step3 12233.0
# 95776.25099117612
# Step4
# Iteration completed
# Area distributed after step4: 12233
# 3560540
# Step1
# Crop: Potatoes
# Iteration continues
# Area distributed after step1: 2580.69
# Area to be distributed in next step: 9108.31005859375
# Step2
# Iteration continues
# Area distributed after step2: 2993.91
# Area to be distributed in next step: 8695.09
# Step3
# Iteration completed
# Area distributed after step3 11689.0
# 84087.24693249082
# Step4
# Iteration completed
# Area distributed after step4: 11689
# 3560540
# Step1
# Crop: Millet
# Iteration continues
# Area distributed after step1: 0.0
# Area to be distributed in next step: 4350.0
# Step2
# Iteration continues
# Area distributed after step2: 0.0
# Area to be distributed in next step: 4350.0
# Step3
# Iteration completed
# Area distributed after step3 4350.0
# 79737.24693249082
# Step4
# Iteration completed
# Area distributed after step4: 4350
# 3560540
# Step1
# Crop: Sorghum
# Iteration continues
# Area distributed after step1: 46.87
# Area to be distributed in next step: 738.1300010681152
# Step2
# Iteration continues
# Area distributed after step2: 51.97
# Area to be distributed in next step: 733.03
# Step3
# Iteration completed
# Area distributed after step3 785.0
# 78952.24676103925
# Step4
# Iteration completed
# Area distributed after step4: 785
# 3560540
# Step1
# Crop: Groundnuts
# Iteration continues
# Area distributed after step1: 37.12
# Area to be distributed in next step: 657.8800010681152
# Step2
# Iteration continues
# Area distributed after step2: 41.08
# Area to be distributed in next step: 653.92
# Step3
# Iteration completed
# Area distributed after step3 695.0
# 78257.2472212932
# Step4
# Iteration completed
# Area distributed after step4: 695
# 3560540
# Step1
# Crop: Cotton
# Iteration continues
# Area distributed after step1: 343.25
# Area to be distributed in next step: 259.75
# Step2
# Iteration continues
# Area distributed after step2: 392.43
# Area to be distributed in next step: 210.57
# Step3
# Iteration completed
# Area distributed after step3 603.0
# 77654.2450095365
# Step4
# Iteration completed
# Area distributed after step4: 603
# 3560540
# Step1
# Crop: Sunflower
# Iteration continues
# Area distributed after step1: 40.81
# Area to be distributed in next step: 58.189998626708984
# Step2
# Iteration continues
# Area distributed after step2: 52.01
# Area to be distributed in next step: 46.99
# Step3
# Iteration completed
# Area distributed after step3 99.0
# 77555.24898379002
# Step4
# Iteration completed
# Area distributed after step4: 99
# 3560540
# Step1
# Crop: Soybeans
# Error check your code!
# More area available than the growing area
# Iteration completed
# Area distributed in step1: 18.0
# Step2
# Iteration completed
# Area distributed after step2: 18.0
# Step3
# Iteration completed
# Area distributed after step3 18.0
# 77537.24898393158
# Step4
# Iteration completed
# Area distributed after step4: 18
# 3560540
# Step1
# Crop: Cassava
# Error check your code!
# More area available than the growing area
# Iteration completed
# Area distributed in step1: 14.0
# Step2
# Iteration completed
# Area distributed after step2: 14.0
# Step3
# Iteration completed
# Area distributed after step3 14.0
# 105378.9154060021
# Step4
# Iteration completed
# Area distributed after step4: 14
# 3560540
# Step1
# Crop: Sugar beet
# Iteration completed
# Area distributed after step1: 0.0
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 77537.24898393158
# Step4
# Iteration completed
# Area distributed after step4: 0
# 3560540
# Step1
# Crop: Others annual1
# Iteration continues
# Area distributed after step1: 9954.83
# Area to be distributed in next step: 584.169921875
# Step2
# Iteration completed
# Area distributed after step2: 10539.0
# Step3
# Iteration completed
# Area distributed after step3 10539.0
# 94839.91299511342
# Step4
# Iteration completed
# Area distributed after step4: 10539
# 3560540
# Step1
# Crop: Others annual2
# No area will be distributed in step1 (Zero harvested area)
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 112315.55827033555
# Step4
# Iteration completed
# Area distributed after step4: 0
# 3560540
# Step1
# Crop: Others annual3
# No area will be distributed in step1 (Zero harvested area)
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 84277.91567151218
# Step4
# Iteration completed
# Area distributed after step4: 0
# unit code: 3560540
# Step5
# Crop: Sugar cane
# Iteration completed
# Area distributed after step5: 169.0
# Step6
# Iteration completed
# Area distributed after step6: 169.0
# Step7
# Iteration completed
# Area distributed after step7 169
# unit code: 3560540
# Step5
# Crop: Cocoa
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 3560540
# Step5
# Crop: Coffee
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 3560540
# Step5
# Crop: Oil palm
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 3560540
# Step5
# Crop: Others perennial
# Iteration continues
# Area distributed after step5: 7279.37
# Area to be distributed in next step: 1816.6299008279475
# Step6
# Iteration completed
# Area distributed after step6: 9096.0
# Step7
# Iteration completed
# Area distributed after step7 9096
# unit code: 3560540
# Step5
# Crop: Fodder
# Iteration completed
# Area distributed after step5: 574.0
# Step6
# Iteration completed
# Area distributed after step6: 574.0
# Step7
# Iteration completed
# Area distributed after step7 574
# unit code: 3560540
# Step5
# Crop: Millet
# Iteration continues
# Area distributed after step5: 50338.15
# Area to be distributed in next step: 15124.85272900296
# Step6
# Iteration completed
# Area distributed after step6: 65463.0
# Step7
# Iteration completed
# Area distributed after step7 65463
# unit code: 3560540
# Step5
# Crop: Barley
# Iteration completed
# Area distributed after step5: 5142.0
# Step6
# Iteration completed
# Area distributed after step6: 5142.0
# Step7
# Iteration completed
# Area distributed after step7 5142
# unit code: 3560540
# Step5
# Crop: Wheat1
# Iteration completed
# Area distributed after step5: 1123.0
# Step6
# Iteration completed
# Area distributed after step6: 1123.0
# Step7
# Iteration completed
# Area distributed after step7 1123
# unit code: 3560540
# Step5
# Crop: Maize
# Iteration completed
# Area distributed after step5: 641.0
# Step6
# Iteration completed
# Area distributed after step6: 641.0
# Step7
# Iteration completed
# Area distributed after step7 641
# unit code: 3560540
# Step5
# Crop: Rice1
# Iteration completed
# Area distributed after step5: 530.0
# Step6
# Iteration completed
# Area distributed after step6: 530.0
# Step7
# Iteration completed
# Area distributed after step7 530
# unit code: 3560540
# Step5
# Crop: Pulses
# Iteration completed
# Area distributed after step5: 452.0
# Step6
# Iteration completed
# Area distributed after step6: 452.0
# Step7
# Iteration completed
# Area distributed after step7 452
# unit code: 3560540
# Step5
# Crop: Sorghum
# Iteration completed
# Area distributed after step5: 339.0
# Step6
# Iteration completed
# Area distributed after step6: 339.0
# Step7
# Iteration completed
# Area distributed after step7 339
# unit code: 3560540
# Step5
# Crop: Wheat2
# Iteration completed
# Area distributed after step5: 125.0
# Step6
# Iteration completed
# Area distributed after step6: 125.0
# Step7
# Iteration completed
# Area distributed after step7 125
# unit code: 3560540
# Step5
# Crop: Potatoes
# Iteration completed
# Area distributed after step5: 36.0
# Step6
# Iteration completed
# Area distributed after step6: 36.0
# Step7
# Iteration completed
# Area distributed after step7 36
# unit code: 3560540
# Step5
# Crop: Rapeseed
# Iteration completed
# Area distributed after step5: 27.0
# Step6
# Iteration completed
# Area distributed after step6: 27.0
# Step7
# Iteration completed
# Area distributed after step7 27
# unit code: 3560540
# Step5
# Crop: Groundnuts
# Iteration completed
# Area distributed after step5: 15.0
# Step6
# Iteration completed
# Area distributed after step6: 15.0
# Step7
# Iteration completed
# Area distributed after step7 15
# unit code: 3560540
# Step5
# Crop: Cotton
# Iteration completed
# Area distributed after step5: 5.0
# Step6
# Iteration completed
# Area distributed after step6: 5.0
# Step7
# Iteration completed
# Area distributed after step7 5
# unit code: 3560540
# Step5
# Crop: Cassava
# Iteration completed
# Area distributed after step5: 1.0
# Step6
# Iteration completed
# Area distributed after step6: 1.0
# Step7
# Iteration completed
# Area distributed after step7 1
# unit code: 3560540
# Step5
# Crop: Rice2
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 3560540
# Step5
# Crop: Soybeans
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 3560540
# Step5
# Crop: Sugar beet
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 3560540
# Step5
# Crop: Sunflower
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 3560540
# Step5
# Crop: Others annual1
# Iteration completed
# Area distributed after step5: 668.0
# Step6
# Iteration completed
# Area distributed after step6: 668.0
# Step7
# Iteration completed
# Area distributed after step7 668
# unit code: 3560540
# Step5
# Crop: others annual2
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 3560540
# Step5
# Crop: others annual3
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# 3560541
# Step1
# Crop: Sugar cane
# Iteration continues
# Area distributed after step1: 1816.5
# Area to be distributed in next step: 1841.5
# Step2
# Iteration continues
# Area distributed after step2: 2992.09
# Area to be distributed in next step: 665.9099999999999
# Step3
# Iteration completed
# Area distributed after step3 3658.0
# 276521.92513619
# Step4
# Iteration completed
# Area distributed after step4: 3658
# 3560541
# Step1
# Crop: Oil palm
# Iteration continues
# Area distributed after step1: 0.0
# Area to be distributed in next step: 47.0
# Step2
# Iteration continues
# Area distributed after step2: 0.0
# Area to be distributed in next step: 47.0
# Step3
# Iteration completed
# Area distributed after step3 47.0
# 276474.92513619
# Step4
# Iteration completed
# Area distributed after step4: 47
# 3560541
# Step1
# Crop: Cocoa
# Iteration completed
# Area distributed after step1: 0.0
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 276474.92513619
# Step4
# Iteration completed
# Area distributed after step4: 0
# 3560541
# Step1
# Crop: Coffee
# Iteration completed
# Area distributed after step1: 0.0
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 276474.92513619
# Step4
# Iteration completed
# Area distributed after step4: 0
# 3560541
# Step1
# Crop: Others perennial
# Error check your code!
# More area available than the growing area
# Iteration completed
# Area distributed in step1: 2622.0
# Step2
# Iteration completed
# Area distributed after step2: 2622.0
# Step3
# Iteration completed
# Area distributed after step3 2622.0
# 273852.92519431945
# Step4
# Iteration completed
# Area distributed after step4: 2622
# 3560541
# Step1
# Crop: Fodder
# Error check your code!
# More area available than the growing area
# Iteration completed
# Area distributed in step1: 1227.0
# Step2
# Iteration completed
# Area distributed after step2: 1227.0
# Step3
# Iteration completed
# Area distributed after step3 1227.0
# 272625.9250874483
# Step4
# Iteration completed
# Area distributed after step4: 1227
# 3560541
# Step1
# Crop: Wheat1
# Iteration continues
# Area distributed after step1: 55352.2
# Area to be distributed in next step: 57398.80078125
# Step2
# Iteration completed
# Area distributed after step2: 112751.0
# Step3
# Iteration completed
# Area distributed after step3 112751.0
# 159874.92735457062
# Step4
# Iteration completed
# Area distributed after step4: 112751
# 3560541
# Step1
# Crop: Wheat2
# Iteration continues
# Area distributed after step1: 55352.2
# Area to be distributed in next step: 57398.80078125
# Step2
# Iteration completed
# Area distributed after step2: 112751.0
# Step3
# Iteration completed
# Area distributed after step3 112751.0
# 159874.92735457062
# Step4
# Iteration completed
# Area distributed after step4: 112751
# 3560541
# Step1
# Crop: Rice1
# Iteration continues
# Area distributed after step1: 36982.98
# Area to be distributed in next step: 72865.01953125
# Step2
# Iteration completed
# Area distributed after step2: 109848.0
# Step3
# Iteration completed
# Area distributed after step3 109848.0
# 60223.49417478126
# Step4
# Iteration completed
# Area distributed after step4: 109848
# 3560541
# Step1
# Crop: Rice2
# Iteration continues
# Area distributed after step1: 36982.98
# Area to be distributed in next step: 72865.01953125
# Step2
# Iteration completed
# Area distributed after step2: 109848.0
# Step3
# Iteration completed
# Area distributed after step3 109848.0
# 4022.079203103679
# Step4
# Iteration completed
# Area distributed after step4: 109848
# 3560541
# Step1
# Crop: Potatoes
# Iteration continues
# Area distributed after step1: 1871.02
# Area to be distributed in next step: 9076.97998046875
# Step2
# Iteration continues
# Area distributed after step2: 4118.5
# Area to be distributed in next step: 6829.5
# Step3
# Iteration continues
# Area distributed after step3: 7713.46
# Area to be distributed in next step: 3234.54
# 0.0
# Step4
# Error Check Your Code! (full area not assigned)
# Area distributed after step4: 7713
# 3560541
# Step1
# Crop: Pulses
# Error check your code!
# More area available than the growing area
# Iteration completed
# Area distributed in step1: 5215.0
# Step2
# Iteration completed
# Area distributed after step2: 5215.0
# Step3
# Iteration completed
# Area distributed after step3 5215.0
# 2698.925315266236
# Step4
# Iteration completed
# Area distributed after step4: 5215
# 3560541
# Step1
# Crop: Millet
# Iteration continues
# Area distributed after step1: 0.0
# Area to be distributed in next step: 546.0
# Step2
# Iteration continues
# Area distributed after step2: 0.0
# Area to be distributed in next step: 546.0
# Step3
# Iteration completed
# Area distributed after step3 546.0
# 0.0
# Step4
# Iteration completed
# Area distributed after step4: 546
# 3560541
# Step1
# Crop: Barley
# Error check your code!
# More area available than the growing area
# Iteration completed
# Area distributed in step1: 385.0
# Step2
# Iteration completed
# Area distributed after step2: 385.0
# Step3
# Iteration completed
# Area distributed after step3 385.0
# 0.0
# Step4
# Iteration completed
# Area distributed after step4: 385
# 3560541
# Step1
# Crop: Sorghum
# Error check your code!
# More area available than the growing area
# Iteration completed
# Area distributed in step1: 321.0
# Step2
# Iteration completed
# Area distributed after step2: 321.0
# Step3
# Iteration completed
# Area distributed after step3 321.0
# 0.0
# Step4
# Iteration completed
# Area distributed after step4: 321
# 3560541
# Step1
# Crop: Maize
# Error check your code!
# More area available than the growing area
# Iteration completed
# Area distributed in step1: 267.0
# Step2
# Iteration completed
# Area distributed after step2: 267.0
# Step3
# Iteration completed
# Area distributed after step3 267.0
# 53163.09610961067
# Step4
# Iteration completed
# Area distributed after step4: 267
# 3560541
# Step1
# Crop: Rapeseed
# Error check your code!
# More area available than the growing area
# Iteration completed
# Area distributed in step1: 149.0
# Step2
# Iteration completed
# Area distributed after step2: 149.0
# Step3
# Iteration completed
# Area distributed after step3 149.0
# 0.0
# Step4
# Iteration completed
# Area distributed after step4: 149
# 3560541
# Step1
# Crop: Groundnuts
# Error check your code!
# More area available than the growing area
# Iteration completed
# Area distributed in step1: 37.0
# Step2
# Iteration completed
# Area distributed after step2: 37.0
# Step3
# Iteration completed
# Area distributed after step3 37.0
# 0.0
# Step4
# Iteration completed
# Area distributed after step4: 37
# 3560541
# Step1
# Crop: Cotton
# Iteration continues
# Area distributed after step1: 31.68
# Area to be distributed in next step: 1.3199996948242188
# Step2
# Iteration completed
# Area distributed after step2: 33.0
# Step3
# Iteration completed
# Area distributed after step3 33.0
# 0.0
# Step4
# Iteration completed
# Area distributed after step4: 33
# 3560541
# Step1
# Crop: Cassava
# Error check your code!
# More area available than the growing area
# Iteration completed
# Area distributed in step1: 7.0
# Step2
# Iteration completed
# Area distributed after step2: 7.0
# Step3
# Iteration completed
# Area distributed after step3 7.0
# 2675.3507976799674
# Step4
# Iteration completed
# Area distributed after step4: 7
# 3560541
# Step1
# Crop: Soybeans
# No area will be distributed in step1 (Zero harvested area)
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 0.0
# Step4
# Iteration completed
# Area distributed after step4: 0
# 3560541
# Step1
# Crop: Sugar beet
# Iteration completed
# Area distributed after step1: 0.0
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 0.0
# Step4
# Iteration completed
# Area distributed after step4: 0
# 3560541
# Step1
# Crop: Sunflower
# No area will be distributed in step1 (Zero harvested area)
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 0.0
# Step4
# Iteration completed
# Area distributed after step4: 0
# 3560541
# Step1
# Crop: Others annual1
# Error check your code!
# More area available than the growing area
# Iteration completed
# Area distributed in step1: 6760.0
# Step2
# Iteration completed
# Area distributed after step2: 6760.0
# Step3
# Iteration completed
# Area distributed after step3 6760.0
# 1463.543899918035
# Step4
# Iteration completed
# Area distributed after step4: 6760
# 3560541
# Step1
# Crop: Others annual2
# No area will be distributed in step1 (Zero harvested area)
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 50720.40684711511
# Step4
# Iteration completed
# Area distributed after step4: 0
# 3560541
# Step1
# Crop: Others annual3
# No area will be distributed in step1 (Zero harvested area)
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 53110.0155090482
# Step4
# Iteration completed
# Area distributed after step4: 0
# unit code: 3560541
# Step5
# Crop: Sugar cane
# Iteration completed
# Area distributed after step5: 3.0
# Step6
# Iteration completed
# Area distributed after step6: 3.0
# Step7
# Iteration completed
# Area distributed after step7 3
# unit code: 3560541
# Step5
# Crop: Oil palm
# Iteration completed
# Area distributed after step5: 2.0
# Step6
# Iteration completed
# Area distributed after step6: 2.0
# Step7
# Iteration completed
# Area distributed after step7 2
# unit code: 3560541
# Step5
# Crop: Cocoa
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 3560541
# Step5
# Crop: Coffee
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 3560541
# Step5
# Crop: Others perennial
# Iteration completed
# Area distributed after step5: 2055.0
# Step6
# Iteration completed
# Area distributed after step6: 2055.0
# Step7
# Iteration completed
# Area distributed after step7 2055
# unit code: 3560541
# Step5
# Crop: Fodder
# Iteration completed
# Area distributed after step5: 1436.0
# Step6
# Iteration completed
# Area distributed after step6: 1436.0
# Step7
# Iteration completed
# Area distributed after step7 1436
# unit code: 3560541
# Step5
# Crop: Pulses
# Iteration completed
# Area distributed after step5: 38336.0
# Step6
# Iteration completed
# Area distributed after step6: 38336.0
# Step7
# Iteration completed
# Area distributed after step7 38336
# unit code: 3560541
# Step5
# Crop: Rice1
# Iteration completed
# Area distributed after step5: 10013.0
# Step6
# Iteration completed
# Area distributed after step6: 10013.0
# Step7
# Iteration completed
# Area distributed after step7 10013
# unit code: 3560541
# Step5
# Crop: Sorghum
# Iteration completed
# Area distributed after step5: 7744.0
# Step6
# Iteration completed
# Area distributed after step6: 7744.0
# Step7
# Iteration completed
# Area distributed after step7 7744
# unit code: 3560541
# Step5
# Crop: Wheat1
# Iteration completed
# Area distributed after step5: 7158.0
# Step6
# Iteration completed
# Area distributed after step6: 7158.0
# Step7
# Iteration completed
# Area distributed after step7 7158
# unit code: 3560541
# Step5
# Crop: Rapeseed
# Iteration completed
# Area distributed after step5: 975.0
# Step6
# Iteration completed
# Area distributed after step6: 975.0
# Step7
# Iteration completed
# Area distributed after step7 975
# unit code: 3560541
# Step5
# Crop: Wheat2
# Iteration completed
# Area distributed after step5: 795.0
# Step6
# Iteration completed
# Area distributed after step6: 795.0
# Step7
# Iteration completed
# Area distributed after step7 795
# unit code: 3560541
# Step5
# Crop: Potatoes
# Iteration completed
# Area distributed after step5: 676.0
# Step6
# Iteration completed
# Area distributed after step6: 676.0
# Step7
# Iteration completed
# Area distributed after step7 676
# unit code: 3560541
# Step5
# Crop: Barley
# Iteration completed
# Area distributed after step5: 162.0
# Step6
# Iteration completed
# Area distributed after step6: 162.0
# Step7
# Iteration completed
# Area distributed after step7 162
# unit code: 3560541
# Step5
# Crop: Millet
# Iteration completed
# Area distributed after step5: 162.0
# Step6
# Iteration completed
# Area distributed after step6: 162.0
# Step7
# Iteration completed
# Area distributed after step7 162
# unit code: 3560541
# Step5
# Crop: Maize
# Iteration completed
# Area distributed after step5: 76.0
# Step6
# Iteration completed
# Area distributed after step6: 76.0
# Step7
# Iteration completed
# Area distributed after step7 76
# unit code: 3560541
# Step5
# Crop: Cassava
# Iteration completed
# Area distributed after step5: 21.0
# Step6
# Iteration completed
# Area distributed after step6: 21.0
# Step7
# Iteration completed
# Area distributed after step7 21
# unit code: 3560541
# Step5
# Crop: Sunflower
# Iteration completed
# Area distributed after step5: 4.0
# Step6
# Iteration completed
# Area distributed after step6: 4.0
# Step7
# Iteration completed
# Area distributed after step7 4
# unit code: 3560541
# Step5
# Crop: Cotton
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 3560541
# Step5
# Crop: Groundnuts
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 3560541
# Step5
# Crop: Rice2
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 3560541
# Step5
# Crop: Soybeans
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 3560541
# Step5
# Crop: Sugar beet
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 3560541
# Step5
# Crop: Others annual1
# Iteration completed
# Area distributed after step5: 3979.0
# Step6
# Iteration completed
# Area distributed after step6: 3979.0
# Step7
# Iteration completed
# Area distributed after step7 3979
# unit code: 3560541
# Step5
# Crop: others annual2
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 3560541
# Step5
# Crop: others annual3
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# 3560542
# Step1
# Crop: Sugar cane
# Error check your code!
# More area available than the growing area
# Iteration completed
# Area distributed in step1: 4811.0
# Step2
# Iteration completed
# Area distributed after step2: 4811.0
# Step3
# Iteration completed
# Area distributed after step3 4811.0
# 184402.52269172668
# Step4
# Iteration completed
# Area distributed after step4: 4811
# 3560542
# Step1
# Crop: Oil palm
# Iteration continues
# Area distributed after step1: 0.0
# Area to be distributed in next step: 18.0
# Step2
# Iteration continues
# Area distributed after step2: 0.0
# Area to be distributed in next step: 18.0
# Step3
# Iteration completed
# Area distributed after step3 18.0
# 184384.52269172668
# Step4
# Iteration completed
# Area distributed after step4: 18
# 3560542
# Step1
# Crop: Cocoa
# Iteration completed
# Area distributed after step1: 0.0
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 184384.52269172668
# Step4
# Iteration completed
# Area distributed after step4: 0
# 3560542
# Step1
# Crop: Coffee
# Iteration completed
# Area distributed after step1: 0.0
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 184384.52269172668
# Step4
# Iteration completed
# Area distributed after step4: 0
# 3560542
# Step1
# Crop: Others perennial
# Error check your code!
# More area available than the growing area
# Iteration completed
# Area distributed in step1: 1047.0
# Step2
# Iteration completed
# Area distributed after step2: 1047.0
# Step3
# Iteration completed
# Area distributed after step3 1047.0
# 183337.52269363403
# Step4
# Iteration completed
# Area distributed after step4: 1047
# 3560542
# Step1
# Crop: Fodder
# Error check your code!
# More area available than the growing area
# Iteration completed
# Area distributed in step1: 1258.0
# Step2
# Iteration completed
# Area distributed after step2: 1258.0
# Step3
# Iteration completed
# Area distributed after step3 1258.0
# 182079.52267551422
# Step4
# Iteration completed
# Area distributed after step4: 1258
# 3560542
# Step1
# Crop: Rice1
# Iteration continues
# Area distributed after step1: 32744.2
# Area to be distributed in next step: 18743.80078125
# Step2
# Error check your code!
# More area available than the growing area (Scaling is needed)
# Iteration completed
# Area distributed in step1: 51488.0
# Step3
# Error check your code!
# More area available than the growing area (Scaling is needed)
# Iteration completed
# Area distributed in step1: 51488.0
# 130591.51733493805
# Step4
# Iteration completed
# Area distributed after step4: 51488
# 3560542
# Step1
# Crop: Rice2
# Iteration continues
# Area distributed after step1: 32744.2
# Area to be distributed in next step: 18743.80078125
# Step2
# Error check your code!
# More area available than the growing area (Scaling is needed)
# Iteration completed
# Area distributed in step1: 51488.0
# Step3
# Error check your code!
# More area available than the growing area (Scaling is needed)
# Iteration completed
# Area distributed in step1: 51488.0
# 79103.51199436188
# Step4
# Iteration completed
# Area distributed after step4: 51488
# 3560542
# Step1
# Crop: Wheat1
# Iteration continues
# Area distributed after step1: 33592.12
# Area to be distributed in next step: 15530.87890625
# Step2
# Iteration completed
# Area distributed after step2: 49123.0
# Step3
# Iteration completed
# Area distributed after step3 49123.0
# 29980.510987281807
# Step4
# Iteration completed
# Area distributed after step4: 49123
# 3560542
# Step1
# Crop: Wheat2
# Iteration continues
# Area distributed after step1: 33592.12
# Area to be distributed in next step: 15530.87890625
# Step2
# Iteration completed
# Area distributed after step2: 49123.0
# Step3
# Iteration completed
# Area distributed after step3 49123.0
# 29980.510987281807
# ...
# Step5
# Crop: Cassava
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 3560640
# Step5
# Crop: Cotton
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 3560640
# Step5
# Crop: Soybeans
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 3560640
# Step5
# Crop: Sugar beet
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 3560640
# Step5
# Crop: Wheat2
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 3560640
# Step5
# Crop: Others annual1
# Iteration completed
# Area distributed after step5: 30358.0
# Step6
# Iteration completed
# Area distributed after step6: 30358.0
# Step7
# Iteration completed
# Area distributed after step7 30358
# unit code: 3560640
# Step5
# Crop: others annual3
# Iteration completed
# Area distributed after step5: 1742.0
# Step6
# Iteration completed
# Area distributed after step6: 1742.0
# Step7
# Iteration completed
# Area distributed after step7 1742
# unit code: 3560640
# Step5
# Crop: others annual2
# Iteration completed
# Area distributed after step5: 1073.0
# Step6
# Iteration completed
# Area distributed after step6: 1073.0
# Step7
# Iteration completed
# Area distributed after step7 1073
# 3560641
# Step1
# Crop: Sugar cane
# Error check your code!
# More area available than the growing area
# Iteration completed
# Area distributed in step1: 6.0
# Step2
# Iteration completed
# Area distributed after step2: 6.0
# Step3
# Iteration completed
# Area distributed after step3 6.0
# 168072.8419191148
# Step4
# Iteration completed
# Area distributed after step4: 6
# 3560641
# Step1
# Crop: Cocoa
# No area will be distributed in step1 (Zero harvested area)
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 168072.8419191148
# Step4
# Iteration completed
# Area distributed after step4: 0
# 3560641
# Step1
# Crop: Coffee
# No area will be distributed in step1 (Zero harvested area)
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 168072.8419191148
# Step4
# Iteration completed
# Area distributed after step4: 0
# 3560641
# Step1
# Crop: Oil palm
# Iteration completed
# Area distributed after step1: 0.0
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 168072.8419191148
# Step4
# Iteration completed
# Area distributed after step4: 0
# 3560641
# Step1
# Crop: Others perennial
# Error check your code!
# More area available than the growing area
# Iteration completed
# Area distributed in step1: 90.0
# Step2
# Iteration completed
# Area distributed after step2: 90.0
# Step3
# Iteration completed
# Area distributed after step3 90.0
# 167982.8419203665
# Step4
# Iteration completed
# Area distributed after step4: 90
# 3560641
# Step1
# Crop: Fodder
# Error check your code!
# More area available than the growing area
# Iteration completed
# Area distributed in step1: 7.0
# Step2
# Iteration completed
# Area distributed after step2: 7.0
# Step3
# Iteration completed
# Area distributed after step3 7.0
# 167975.8419204317
# Step4
# Iteration completed
# Area distributed after step4: 7
# 3560641
# Step1
# Crop: Rice1
# Iteration continues
# Area distributed after step1: 48929.98
# Area to be distributed in next step: 25070.01953125
# Step2
# Iteration completed
# Area distributed after step2: 74000.0
# Step3
# Iteration completed
# Area distributed after step3 74000.0
# 93975.84372096881
# Step4
# Iteration completed
# Area distributed after step4: 74000
# 3560641
# Step1
# Crop: Rice2
# Iteration continues
# Area distributed after step1: 48929.98
# Area to be distributed in next step: 25070.01953125
# Step2
# Iteration completed
# Area distributed after step2: 74000.0
# Step3
# Iteration completed
# Area distributed after step3 74000.0
# 19975.84552150592
# Step4
# Iteration completed
# Area distributed after step4: 74000
# 3560641
# Step1
# Crop: Wheat1
# Iteration continues
# Area distributed after step1: 11612.55
# Area to be distributed in next step: 19219.4501953125
# Step2
# Iteration continues
# Area distributed after step2: 21278.78
# Area to be distributed in next step: 9553.220000000001
# Step3
# Iteration continues
# Area distributed after step3: 23591.3
# Area to be distributed in next step: 7240.700000000001
# 0.0
# Step4
# Error Check Your Code! (full area not assigned)
# Area distributed after step4: 23591
# 3560641
# Step1
# Crop: Rapeseed
# Error check your code!
# More area available than the growing area
# Iteration completed
# Area distributed in step1: 23732.0
# Step2
# Iteration completed
# Area distributed after step2: 23732.0
# Step3
# Iteration completed
# Area distributed after step3 23732.0
# 0.0
# Step4
# Iteration completed
# Area distributed after step4: 23732
# 3560641
# Step1
# Crop: Potatoes
# Iteration continues
# Area distributed after step1: 829.22
# Area to be distributed in next step: 13892.780029296875
# Step2
# Iteration continues
# Area distributed after step2: 1739.78
# Area to be distributed in next step: 12982.22
# Step3
# Iteration continues
# Area distributed after step3: 2114.43
# Area to be distributed in next step: 12607.57
# 0.0
# Step4
# Error Check Your Code! (full area not assigned)
# Area distributed after step4: 2114
# 3560641
# Step1
# Crop: Maize
# Error check your code!
# More area available than the growing area
# Iteration completed
# Area distributed in step1: 1811.0
# Step2
# Iteration completed
# Area distributed after step2: 1811.0
# Step3
# Iteration completed
# Area distributed after step3 1811.0
# 92084.95312787863
# Step4
# Iteration completed
# Area distributed after step4: 1811
# 3560641
# Step1
# Crop: Pulses
# Error check your code!
# More area available than the growing area
# Iteration completed
# Area distributed in step1: 197.0
# Step2
# Iteration completed
# Area distributed after step2: 197.0
# Step3
# Iteration completed
# Area distributed after step3 197.0
# 0.0
# Step4
# Iteration completed
# Area distributed after step4: 197
# 3560641
# Step1
# Crop: Sorghum
# Iteration continues
# Area distributed after step1: 19.3
# Area to be distributed in next step: 12.700000762939453
# Step2
# Iteration completed
# Area distributed after step2: 32.0
# Step3
# Iteration completed
# Area distributed after step3 32.0
# 92052.95081785592
# Step4
# Iteration completed
# Area distributed after step4: 32
# 3560641
# Step1
# Crop: Barley
# Error check your code!
# More area available than the growing area
# Iteration completed
# Area distributed in step1: 12.0
# Step2
# Iteration completed
# Area distributed after step2: 12.0
# Step3
# Iteration completed
# Area distributed after step3 12.0
# 4918.151548775704
# Step4
# Iteration completed
# Area distributed after step4: 12
# 3560641
# Step1
# Crop: Millet
# Error check your code!
# More area available than the growing area
# Iteration completed
# Area distributed in step1: 11.0
# Step2
# Iteration completed
# Area distributed after step2: 11.0
# Step3
# Iteration completed
# Area distributed after step3 11.0
# 4915.163242968591
# Step4
# Iteration completed
# Area distributed after step4: 11
# 3560641
# Step1
# Crop: Sunflower
# Iteration continues
# Area distributed after step1: 0.0
# Area to be distributed in next step: 9.0
# Step2
# Iteration continues
# Area distributed after step2: 0.0
# Area to be distributed in next step: 9.0
# Step3
# Iteration completed
# Area distributed after step3 9.0
# 4906.163242968591
# Step4
# Iteration completed
# Area distributed after step4: 9
# 3560641
# Step1
# Crop: Cassava
# Error check your code!
# More area available than the growing area
# Iteration completed
# Area distributed in step1: 5.0
# Step2
# Iteration completed
# Area distributed after step2: 5.0
# Step3
# Iteration completed
# Area distributed after step3 5.0
# 0.0
# Step4
# Iteration completed
# Area distributed after step4: 5
# 3560641
# Step1
# Crop: Groundnuts
# Error check your code!
# More area available than the growing area
# Iteration completed
# Area distributed in step1: 3.0
# Step2
# Iteration completed
# Area distributed after step2: 3.0
# Step3
# Iteration completed
# Area distributed after step3 3.0
# 0.0
# Step4
# Iteration completed
# Area distributed after step4: 3
# 3560641
# Step1
# Crop: Cotton
# No area will be distributed in step1 (Zero harvested area)
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 0.0
# Step4
# Iteration completed
# Area distributed after step4: 0
# 3560641
# Step1
# Crop: Soybeans
# No area will be distributed in step1 (Zero harvested area)
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 92018.1056762113
# Step4
# Iteration completed
# Area distributed after step4: 0
# 3560641
# Step1
# Crop: Sugar beet
# Iteration completed
# Area distributed after step1: 0.0
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 4904.112408810155
# Step4
# Iteration completed
# Area distributed after step4: 0
# 3560641
# Step1
# Crop: Wheat2
# No area will be distributed in step1 (Zero harvested area)
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 0.0
# Step4
# Iteration completed
# Area distributed after step4: 0
# 3560641
# Step1
# Crop: Others annual1
# No area will be distributed in step1 (Zero harvested area)
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 0.0
# Step4
# Iteration completed
# Area distributed after step4: 0
# 3560641
# Step1
# Crop: Others annual2
# No area will be distributed in step1 (Zero harvested area)
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 68221.03455430178
# Step4
# Iteration completed
# Area distributed after step4: 0
# 3560641
# Step1
# Crop: Others annual3
# No area will be distributed in step1 (Zero harvested area)
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 92097.84139856277
# Step4
# Iteration completed
# Area distributed after step4: 0
# unit code: 3560641
# Step5
# Crop: Sugar cane
# Iteration completed
# Area distributed after step5: 8.0
# Step6
# Iteration completed
# Area distributed after step6: 8.0
# Step7
# Iteration completed
# Area distributed after step7 8
# unit code: 3560641
# Step5
# Crop: Cocoa
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 3560641
# Step5
# Crop: Coffee
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 3560641
# Step5
# Crop: Oil palm
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 3560641
# Step5
# Crop: Others perennial
# Iteration completed
# Area distributed after step5: 284.0
# Step6
# Iteration completed
# Area distributed after step6: 284.0
# Step7
# Iteration completed
# Area distributed after step7 284
# unit code: 3560641
# Step5
# Crop: Fodder
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 3560641
# Step5
# Crop: Rice2
# Iteration completed
# Area distributed after step5: 114426.0
# Step6
# Iteration completed
# Area distributed after step6: 114426.0
# Step7
# Iteration completed
# Area distributed after step7 114426
# unit code: 3560641
# Step5
# Crop: Rice1
# Iteration completed
# Area distributed after step5: 56154.0
# Step6
# Iteration completed
# Area distributed after step6: 56154.0
# Step7
# Iteration completed
# Area distributed after step7 56154
# unit code: 3560641
# Step5
# Crop: Maize
# Iteration completed
# Area distributed after step5: 3691.0
# Step6
# Iteration completed
# Area distributed after step6: 3691.0
# Step7
# Iteration completed
# Area distributed after step7 3691
# unit code: 3560641
# Step5
# Crop: Rapeseed
# Iteration completed
# Area distributed after step5: 2851.0
# Step6
# Iteration completed
# Area distributed after step6: 2851.0
# Step7
# Iteration completed
# Area distributed after step7 2851
# unit code: 3560641
# Step5
# Crop: Potatoes
# Iteration completed
# Area distributed after step5: 2469.0
# Step6
# Iteration completed
# Area distributed after step6: 2469.0
# Step7
# Iteration completed
# Area distributed after step7 2469
# unit code: 3560641
# Step5
# Crop: Pulses
# Iteration completed
# Area distributed after step5: 2051.0
# Step6
# Iteration completed
# Area distributed after step6: 2051.0
# Step7
# Iteration completed
# Area distributed after step7 2051
# unit code: 3560641
# Step5
# Crop: Wheat1
# Iteration completed
# Area distributed after step5: 1237.0
# Step6
# Iteration completed
# Area distributed after step6: 1237.0
# Step7
# Iteration completed
# Area distributed after step7 1237
# unit code: 3560641
# Step5
# Crop: Sorghum
# Iteration completed
# Area distributed after step5: 112.0
# Step6
# Iteration completed
# Area distributed after step6: 112.0
# Step7
# Iteration completed
# Area distributed after step7 112
# unit code: 3560641
# Step5
# Crop: Groundnuts
# Iteration completed
# Area distributed after step5: 9.0
# Step6
# Iteration completed
# Area distributed after step6: 9.0
# Step7
# Iteration completed
# Area distributed after step7 9
# unit code: 3560641
# Step5
# Crop: Barley
# Iteration completed
# Area distributed after step5: 5.0
# Step6
# Iteration completed
# Area distributed after step6: 5.0
# Step7
# Iteration completed
# Area distributed after step7 5
# unit code: 3560641
# Step5
# Crop: Soybeans
# Iteration completed
# Area distributed after step5: 3.0
# Step6
# Iteration completed
# Area distributed after step6: 3.0
# Step7
# Iteration completed
# Area distributed after step7 3
# unit code: 3560641
# Step5
# Crop: Cassava
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 3560641
# Step5
# Crop: Cotton
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 3560641
# Step5
# Crop: Millet
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 3560641
# Step5
# Crop: Sugar beet
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 3560641
# Step5
# Crop: Sunflower
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 3560641
# Step5
# Crop: Wheat2
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 3560641
# Step5
# Crop: Others annual1
# Iteration completed
# Area distributed after step5: 30274.0
# Step6
# Iteration completed
# Area distributed after step6: 30274.0
# Step7
# Iteration completed
# Area distributed after step7 30274
# unit code: 3560641
# Step5
# Crop: others annual3
# Iteration completed
# Area distributed after step5: 1737.0
# Step6
# Iteration completed
# Area distributed after step6: 1737.0
# Step7
# Iteration completed
# Area distributed after step7 1737
# unit code: 3560641
# Step5
# Crop: others annual2
# Iteration completed
# Area distributed after step5: 1070.0
# Step6
# Iteration completed
# Area distributed after step6: 1070.0
# Step7
# Iteration completed
# Area distributed after step7 1070
