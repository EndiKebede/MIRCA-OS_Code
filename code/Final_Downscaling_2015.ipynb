# %%
import os
import numpy as np
import rasterio
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from contextlib import contextmanager
import glob
import sys

# %%
# Load the DataFrame from your CSV file
df_area = pd.read_excel("D:\\PhD_Udel\\MICRA_2015\\DOwnscaling\\NASAOCE\\All countries\\ALL CCC\\2015\\2015_ir_merged_.xlsx")

# Define the type_order
type_order = {'Perennial': 1, 'Other Perennial': 2, 'Fodder': 3, 'Annual': 4, 'Other Annual': 5}

# Define a custom ranking function for a single state (unit_code)
def custom_rank(sub_df):
    sub_df = sub_df.copy()  # Create a copy to avoid SettingWithCopyWarning
    
    # Redirect standard error to suppress warnings
    sys.stderr = open('nul', 'w')
    
    sub_df['Type_Rank'] = sub_df['Type'].map(type_order)
    sub_df = sub_df.sort_values(by=['Type_Rank', 'Growing_area'], ascending=[True, False])
    sub_df['rank'] = range(1, len(sub_df) + 1)
    
    # Reset standard error
    sys.stderr = sys.__stderr__
    
    return sub_df

# Initialize an empty DataFrame to store the ranked results
ranked_df = pd.DataFrame()

# Iterate over unique unit_codes (states) and rank crops for each state
for unit_code in df_area['unit_code'].unique():
    state_subset = df_area[df_area['unit_code'] == unit_code]
    ranked_subset = custom_rank(state_subset)
    ranked_df = ranked_df.append(ranked_subset, ignore_index=True)

# Sort the final DataFrame by 'unit_code' and 'Crop_Rank'
ranked_df = ranked_df.sort_values(by=['unit_code', 'rank']).reset_index(drop=True)

# Display the final DataFrame
ranked_df
# Out:
#        Country     State  unit_code                Crop  Subcrop  \
# 0     Barbados  Barbados     520000               Cocoa        1
# 1     Barbados  Barbados     520000              Coffee        1
# 2     Barbados  Barbados     520000            Oil palm        1
# 3     Barbados  Barbados     520000          Sugar cane        1
# 4     Barbados  Barbados     520000  Others perennial          1
# ...        ...       ...        ...                 ...      ...
# 3948     Samoa     Samoa    8820000           Sunflower        1
# 3949     Samoa     Samoa    8820000              Wheat1        1
# 3950     Samoa     Samoa    8820000              Wheat2        1
# 3951     Samoa     Samoa    8820000      Others annual1        1
# 3952     Samoa     Samoa    8820000      Others annual2        1
#
#                  Type  Growing_area  Planting_Month  Maturity_Month  \
# 0           Perennial             0              11               4
# 1           Perennial             0              11               4
# 2           Perennial             0              11               4
# 3           Perennial             0              11               4
# 4     Other Perennial             0              11               4
# ...               ...           ...             ...             ...
# 3948           Annual             0              12               4
# 3949           Annual             0              12               4
# 3950           Annual             0              12               4
# 3951     Other Annual             0              12               4
# 3952     Other Annual             0              12               4
#
#       Type_Rank  rank
# 0             1     1
# 1             1     2
# 2             1     3
# 3             1     4
# 4             2     5
# ...         ...   ...
# 3948          4    22
# 3949          4    23
# 3950          4    24
# 3951          5    25
# 3952          5    26
#
# [3953 rows x 11 columns]

# %%
# Load the DataFrame from your CSV file
df_rainfed =pd.read_excel("D:\\PhD_Udel\\MICRA_2015\\DOwnscaling\\NASAOCE\\All countries\\ALL CCC\\2015\\2015_rf_merged_.xlsx")

# Define the type_order
type_order = {'Perennial': 1, 'Other Perennial': 2, 'Fodder': 3, 'Annual': 4, 'Other Annual': 5}

# Define a custom ranking function for a single state (unit_code)
def custom_rank(sub_df):
    sub_df = sub_df.copy()  # Create a copy to avoid SettingWithCopyWarning
    
    # Redirect standard error to suppress warnings
    sys.stderr = open('nul', 'w')
    
    sub_df['Type_Rank'] = sub_df['Type'].map(type_order)
    sub_df = sub_df.sort_values(by=['Type_Rank', 'Growing_area'], ascending=[True, False])
    sub_df['rank'] = range(1, len(sub_df) + 1)
    
    # Reset standard error
    sys.stderr = sys.__stderr__
    
    return sub_df

# Initialize an empty DataFrame to store the ranked results
ranked_df_rf = pd.DataFrame()

# Iterate over unique unit_codes (states) and rank crops for each state
for unit_code in df_rainfed['unit_code'].unique():
#     print(unit_code)
    state_subset_rf = df_rainfed[df_rainfed['unit_code'] == unit_code]
    ranked_subset_rf = custom_rank(state_subset_rf)
    ranked_df_rf = ranked_df_rf.append(ranked_subset_rf, ignore_index=True)

# Sort the final DataFrame by 'unit_code' and 'Crop_Rank'
ranked_df_rf = ranked_df_rf.sort_values(by=['unit_code', 'rank']).reset_index(drop=True)

ranked_df_rf
# Out:
#                                  Country                               State  \
# 0                               Barbados                            Barbados
# 1                               Barbados                            Barbados
# 2                               Barbados                            Barbados
# 3                               Barbados                            Barbados
# 4                               Barbados                            Barbados
# ...                                  ...                                 ...
# 3976                               Samoa                               Samoa
# 3977                               Samoa                               Samoa
# 3978                               Samoa                               Samoa
# 3979  Venezuela (Bolivarian Republic of)  Venezuela (Bolivarian Republic of)
# 3980                               Samoa                               Samoa
#
#       unit_code                Crop  Subcrop             Type  Growing_area  \
# 0        520000          Sugar cane        1        Perennial          3116
# 1        520000               Cocoa        1        Perennial             0
# 2        520000              Coffee        1        Perennial             0
# 3        520000            Oil palm        1        Perennial             0
# 4        520000  Others perennial          1  Other Perennial           526
# ...         ...                 ...      ...              ...           ...
# 3976    8820000              Wheat1        1           Annual             0
# 3977    8820000              Wheat2        1           Annual             0
# 3978    8820000      Others annual1        1     Other Annual         11023
# 3979    8820000      Others annual3        1     Other Annual          6807
# 3980    8820000      Others annual2        1     Other Annual             0
#
#       Planting_Month  Maturity_Month  Type_Rank  rank
# 0                 11               4          1     1
# 1                 11               4          1     2
# 2                 11               4          1     3
# 3                 11               4          1     4
# 4                 11               4          2     5
# ...              ...             ...        ...   ...
# 3976              12               4          4    23
# 3977              12               4          4    24
# 3978              12               4          5    25
# 3979               3               7          5    26
# 3980              12               4          5    27
#
# [3981 rows x 11 columns]

# %%
# Define Annual and Pernnial crops
Annual=("Barley","Cassava","Groundnuts","Maize","Millet","Potatoes","Pulses","Rapeseed","Rice1","Rice2", "Sorghum","Soybeans","Sunflower","Wheat1","Wheat2","Cotton", "Fodder", "Others annual", "Rye", "Sugar beet")
Perennial=("Sugarcane", "Citrus", "Grape",  "Cocoa", "Coffee","Oil palm", "Others perennial")

# %%
@contextmanager
def open_tiff_file(filepath):
    with rasterio.open(filepath) as src:
        array = src.read(1)
        no_data_value = src.nodata
        if no_data_value is not None:
            array = np.where(array == no_data_value, 0, array)
        yield array

def get_unit_codes(root_folder):
    unit_codes = [int(tiff_file[:-4]) for subfolder in os.listdir(root_folder)
                   if os.path.isdir(os.path.join(root_folder, subfolder))
                   for tiff_file in os.listdir(os.path.join(root_folder, subfolder))
                   if tiff_file.endswith('.tif')]
    return sorted(unit_codes)
def read_tiff_file(subfolder_path, unit_code):
    tiff_file_path = os.path.join(subfolder_path, f"{unit_code}.tif")
    if os.path.exists(tiff_file_path):
        with open_tiff_file(tiff_file_path) as array:
            return np.nan_to_num(array, nan=0, posinf=0, neginf=0)  # Directly use np.nan_to_num
    return None

df_accumulator1 = pd.DataFrame({'Month': np.arange(1, 13), 'Total_st1': np.zeros(12)})
root_folder =  r"E:\\NASAOCE\\DOwnscaling\\Clipped_2015"
def getListcom(p, m):
    if p < m:
        return np.arange(p, m + 1)
    else:
        return np.concatenate((np.arange(p, 13), np.arange(1, m + 1)))
import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning) 

sub_dirs = [x[0] for x in os.walk(root_folder)]
tiff_files = sorted(glob.glob(os.path.join(root_folder, "*/*.tif")))
dist_array_aei = None
dist_array_area = None
dist_array_cle = None
dist_array_bar = None
dist_array_cas = None
# dist_array_cit = None
dist_array_coc = None
dist_array_cof = None
dist_array_cot = None
# dist_array_dat = None
dist_array_for = None
# dist_array_gra = None
dist_array_gro = None
dist_array_maz = None
dist_array_mil = None
dist_array_oil = None
dist_array_pot = None
dist_array_otha = None
dist_array_othp = None
dist_array_pul = None
dist_array_rap = None
dist_array_ric1 = None
dist_array_ric2 = None
# dist_array_rye = None
dist_array_sor = None
dist_array_soy = None
dist_array_sun = None
dist_array_sugc = None
dist_array_sugb = None
dist_array_whe = None
irri_totals = {}
aei_free = {}
cle_free = {}
area = {}
tot_st1 = []
tot_st2 = []
tot_st3 = []
tot_st4 = []
tot_st5 = []
tot_st6 = []
tot_st7 = []
# Pre-compute unique unit codes to minimize redundant operations
unique_unit_codes = ranked_df['unit_code'].unique()

for unit_code in unique_unit_codes:
    df_cumulative_st1 = pd.DataFrame()
    df_cumulative_st2 = pd.DataFrame()
    df_cumulative_st3 = pd.DataFrame()
    df_cumulative_st4 = pd.DataFrame()
    df_cumulative_st5 = pd.DataFrame()
    df_cumulative_st6 = pd.DataFrame()
    df_cumulative_st7 = pd.DataFrame()
    TAD_14_dict = {}
    # Filter DataFrame once per unit_code
    unit_specific_df = ranked_df[ranked_df['unit_code'] == unit_code]

    for j in range(1, int(np.max(ranked_df['rank'])+1)):
        rows_ir = ranked_df.loc[(ranked_df['unit_code'] == unit_code) & (ranked_df['rank'] == j)]
        for i, row in rows_ir.iterrows():
#             if ranked_df.Growing_area[i]>0:
            p = ranked_df.Planting_Month[i]
            m = ranked_df.Maturity_Month[i]
            listcom = getListcom(p, m)
#                         print(unit_code)
              # Filter and extract TIFF files that correspond to the selected unit_code

            for tiff_file in tiff_files:
#                 print(tiff_file)
                for subfolder_path in sub_dirs[1:]:
                    subfolder_name = os.path.basename(subfolder_path)
#                     print(subfolder_name)
#                     print(os.path.basename(tiff_file)[:-4])
                    if os.path.basename(tiff_file)[:-4] == str(unit_code):
                        array = read_tiff_file(subfolder_path, unit_code)
                        array =  np.where(np.logical_or(np.isnan(array), np.isinf(array)), 0, array)

                        if subfolder_name == "AEI_15":
                            tiff_ir=tiff_file

                            dist_array_aei = array
                            dist_array_aei = np.where(np.logical_or(np.isnan(dist_array_aei), np.isinf(dist_array_aei)), 0, dist_array_aei)
                        elif subfolder_name == "Ara_15":
                            dist_array_area = array
                            dist_array_area = np.where(np.logical_or(np.isnan(dist_array_area), np.isinf(dist_array_area)), 0, dist_array_area)
                        elif subfolder_name == "CLE_15":
                            dist_array_cle = array
                            dist_array_cle = np.where(np.logical_or(np.isnan(dist_array_cle), np.isinf(dist_array_cle)), 0, dist_array_cle)

                        else:
                            # Extract array data for crop type and assign to corresponding variable in crop_dict
                            crop_name = ranked_df.Crop[i]
                            if crop_name:
                                crop_array = read_tiff_file(subfolder_path, unit_code)
                                if isinstance(crop_array, np.ndarray):
                                    crop_array = np.where(np.logical_or(np.isnan(crop_array), np.isinf(crop_array)), 0, crop_array)
        #                                     
                                else:
                                    print(f"Warning: crop_array for {crop_name} is not a numpy array.")
                                n=ranked_df.Subcrop[i]

                                if crop_name == 'Barley' and subfolder_name == "Bar_15":
                                    dist_array_bar = crop_array
                                    AH_array=dist_array_bar
                                    AD_step1 = np.where(dist_array_area > 0, ((AH_array * dist_array_aei) / dist_array_area), 0)
                                elif crop_name == 'Cassava'and subfolder_name == "Cas_15":
                                    dist_array_cas = crop_array
                                    AH_array=dist_array_cas
                                    AD_step1 = np.where(dist_array_area > 0, ((AH_array * dist_array_aei) / dist_array_area), 0)
                                elif crop_name == 'Cocoa'and subfolder_name == "Stm_15":
                                    dist_array_cof = crop_array
                                    AH_array=dist_array_cof
                                    AD_step1 = np.where(dist_array_area > 0, ((AH_array * dist_array_aei) / dist_array_area), 0)
                                elif crop_name == 'Coffee'and subfolder_name == "Stm_15":
                                    dist_array_cof = crop_array
                                    AH_array=dist_array_cof
                                    AD_step1 = np.where(dist_array_area > 0, ((AH_array * dist_array_aei) / dist_array_area), 0)
                                elif crop_name == 'Cotton'and subfolder_name == "Cot_15":
                                    dist_array_cot = crop_array
                                    AH_array=dist_array_cot
                                    AD_step1 = np.where(dist_array_area > 0, ((AH_array * dist_array_aei) / dist_array_area), 0)
                                elif crop_name == 'Fodder'and subfolder_name == "Fod_15":
                                    dist_array_for = crop_array
                                    AH_array=dist_array_for
                                    AD_step1 = np.where(dist_array_area > 0, ((AH_array * dist_array_aei) / dist_array_area), 0)
                                elif crop_name == 'Groundnuts'and subfolder_name == "Gro_15":
                                    dist_array_gro = crop_array
                                    AH_array=dist_array_gro
                                    AD_step1 = np.where(dist_array_area > 0, ((AH_array * dist_array_aei) / dist_array_area), 0)
                                elif crop_name == 'Maize'and subfolder_name == "Maz_15":
                                    dist_array_maz = crop_array
                                    AH_array=dist_array_maz
                                    AD_step1 = np.where(dist_array_area > 0, ((AH_array * dist_array_aei) / dist_array_area), 0)
                                elif crop_name == 'Millet'and subfolder_name == "Mil_15":
                                    dist_array_mil = crop_array
                                    AH_array=dist_array_mil
                                    AD_step1 = np.where(dist_array_area > 0, ((AH_array * dist_array_aei) / dist_array_area), 0)
                                elif crop_name == 'Oil palm'and subfolder_name == "Olp_15":
                                    dist_array_oil = crop_array
                                    AH_array=dist_array_oil
                                    AD_step1 = np.where(dist_array_area > 0, ((AH_array * dist_array_aei) / dist_array_area), 0)
                                elif crop_name == 'Others perennial'and subfolder_name == "Othp_15":
                                    dist_array_othp = crop_array
                                    AH_array=dist_array_othp
                                    AD_step1 = np.where(dist_array_area > 0, ((AH_array * dist_array_aei) / dist_array_area), 0)
                                elif crop_name == 'Others annual1'and subfolder_name == "Otha_15":
                                    dist_array_otha1 = crop_array
                                    AH_array=dist_array_otha1
                                    AD_step1 = np.where(dist_array_area > 0,(((AH_array/n)* dist_array_aei) / dist_array_area),0)
                                elif crop_name == 'Others annual2'and subfolder_name == "Otha_15":
                                    dist_array_otha2 = crop_array
                                    AH_array=dist_array_otha2
                                    AD_step1 = np.where(dist_array_area > 0,(((AH_array/n)* dist_array_aei) / dist_array_area),0)
                                elif crop_name == 'Others annual3'and subfolder_name == "Otha_15":
                                    dist_array_otha3 = crop_array
                                    AH_array=dist_array_otha3
                                    AD_step1 = np.where(dist_array_area > 0,(((AH_array/n)* dist_array_aei) / dist_array_area),0)
                                elif crop_name == 'Others annual4'and subfolder_name == "Otha_15":
                                    dist_array_otha4 = crop_array
                                    AH_array=dist_array_otha4
                                    AD_step1 = np.where(dist_array_area > 0,(((AH_array/n)* dist_array_aei) / dist_array_area),0)
                                elif crop_name == 'Potatoes'and subfolder_name == "Pot_15":
                                    dist_array_pot = crop_array
                                    AH_array=dist_array_pot
                                    AD_step1 = np.where(dist_array_area > 0, ((AH_array * dist_array_aei) / dist_array_area), 0)
                                elif crop_name == 'Pulses'and subfolder_name == "Pul_15":
                                    dist_array_pul = crop_array
                                    AH_array=dist_array_pul
                                    AD_step1 = np.where(dist_array_area > 0, ((AH_array * dist_array_aei) / dist_array_area), 0)
                                elif crop_name == 'Rapeseed'and subfolder_name == "Rap_15":
                                    dist_array_rap = crop_array
                                    AH_array=dist_array_rap
                                    AD_step1 = np.where(dist_array_area > 0, ((AH_array * dist_array_aei) / dist_array_area), 0)
                                elif crop_name == 'Rice1'and subfolder_name == "Ric_15":
                                    dist_array_ric1 = crop_array
                                    AH_array=dist_array_ric1
                                    AD_step1 = np.where(dist_array_area > 0,(((AH_array/n)* dist_array_aei) / dist_array_area),0)

                                elif crop_name == 'Rice2'and subfolder_name == "Ric_15":
                                    dist_array_ric2 = crop_array
                                    AH_array=dist_array_ric2
                                    AD_step1 = np.where(dist_array_area > 0,(((AH_array/n)* dist_array_aei) / dist_array_area),0)
                                elif crop_name == 'Rye'and subfolder_name == "Rye_15":
                                    dist_array_rye = crop_array
                                    AH_array=dist_array_rye
                                    AD_step1 = np.where(dist_array_area > 0, ((AH_array * dist_array_aei) / dist_array_area), 0)
                                elif crop_name == 'Sorghum'and subfolder_name == "Sor_15":
                                    dist_array_sor = crop_array
                                    AH_array=dist_array_sor
                                    AD_step1 = np.where(dist_array_area > 0, ((AH_array * dist_array_aei) / dist_array_area), 0)
                                elif crop_name == 'Soybeans'and subfolder_name == "Soy_15":
                                    dist_array_soy = crop_array
                                    AH_array=dist_array_soy
                                    AD_step1 = np.where(dist_array_area > 0, ((AH_array * dist_array_aei) / dist_array_area), 0)
                                elif crop_name == 'Sugar beet'and subfolder_name == "Sub_15":
                                    dist_array_sugb = crop_array
                                    AH_array=dist_array_sugb
                                    AD_step1 = np.where(dist_array_area > 0, ((AH_array * dist_array_aei) / dist_array_area), 0)
                                elif crop_name == 'Sugar cane'and subfolder_name == "Sug_15":
                                    dist_array_sugc = crop_array
                                    AH_array=dist_array_sugc
                                    AD_step1 = np.where(dist_array_area > 0, ((AH_array * dist_array_aei) / dist_array_area), 0)
                                elif crop_name == 'Sunflower'and subfolder_name == "Sun_15":
                                    dist_array_sun = crop_array
                                    AH_array=dist_array_sun
                                    AD_step1 = np.where(dist_array_area > 0, ((AH_array * dist_array_aei) / dist_array_area), 0)
                                elif crop_name == 'Wheat1'and subfolder_name == "Whe_15":
                                    dist_array_whe1= crop_array
                                    AH_array=dist_array_whe1
                                    AD_step1 = np.where(dist_array_area > 0,(((AH_array/n)* dist_array_aei) / dist_array_area),0)
                                elif crop_name == 'Wheat2'and subfolder_name == "Whe_15":
                                    dist_array_whe2= crop_array
                                    AH_array=dist_array_whe2
                                    AD_step1 = np.where(dist_array_area > 0,(((AH_array/n)* dist_array_aei) / dist_array_area),0)

# for row in range(AD_step1.shape[0]):
#                 for col in range(AD_step1.shape[1]):
#                     if AD_step1[row, col] <= dist_array_aei[row, col]:
#                         AD_step1[row, col] = AD_step1[row, col]
#                     else:
#                         ratio = dist_array_area[row, col] / AD_step1[row, col]
#                         AD_step1[row, col] *= ratio
#             
            print(ranked_df.unit_code[i])
            print("Step1")
            print("Crop:", ranked_df.Crop[i])
            if round(np.sum(AD_step1),2) < (ranked_df.Growing_area[i]):
                ATS_2= (ranked_df.Growing_area[i])-round(np.sum(AD_step1),2)
                AD_area1=AD_step1
                print("Iteration continues")
                print("Area distributed after step1:", round(np.sum(AD_step1),2))
                print("Area to be distributed in next step:", ATS_2)
            elif round(np.sum(AD_step1),2)==(ranked_df.Growing_area[i]):
                ATS_2= (ranked_df.Growing_area[i])-round(np.sum(AD_step1),2)
                AD_area1=AD_step1
                print("Iteration completed ")
                print("Area distributed after step1:", round(np.sum(AD_step1),2))
            else:
                
                if ranked_df.Growing_area[i] >0:
                    print("Error check your code!")
                    print("More area available than the growing area")
                    ratio=ranked_df.Growing_area[i]/np.sum(AD_step1)
    #                             print(ratio)
                    AD_area1=AD_step1*ratio
                    ATS_2= 0
                    print("Iteration completed")
                    print("Area distributed in step1:",round( np.sum(AD_area1),2))
                if ranked_df.Growing_area[i]== 0:
                    AD_area1=AD_step1*0
                    ATS_2= 0
                    print("No area will be distributed in step1 (Zero harvested area)")
#             AD_area1 = np.minimum(AD_area1, dist_array_aei)
            # Assign the area to be distributed in this step for each month according to crop calendar
            df_list = []
            # Call the array to be distributed in step1 and convert it to dataframe
            array_name = "Array_" + ranked_df.Crop[i][:3] + ranked_df.Crop[i][-1] + "1"
            # Call the array (area) to be distributed monthly
            arr1 = AD_area1
            arr1_re = np.repeat(arr1, 12)
            c_s = len(arr1[0])
            r_s = len(arr1)
            # Create a new dataframe in which we will iterate each cell value for each month according to the crop calendar
#             crop_sum = 0
            df_month = pd.DataFrame(np.arange(1, 13), columns=['Month'])
            df_mon = pd.concat([df_month] * c_s * r_s, ignore_index=True)
            # Change the array to dataframe
            df_1 = pd.DataFrame(arr1_re, index=np.arange(len(df_mon)), columns=[array_name])
            # Merge the month and array dataframe
            df_area1 = pd.concat([df_mon, df_1], axis=1)
            # Filter the month in which the crop grows according to the crop calendar
            crop_1 = df_area1[(df_area1["Month"].isin(listcom))]
            # Filter the month in which the crop didn't grow according to the crop calendar
            crop_not = df_area1[(~df_area1["Month"].isin(listcom))]
            # Set the value of the array to 0 for months when the crop doesn't grow
            crop_not[array_name].values[:] = 0
            # Merge the two dataframes and sort it based on index
            df_name = ranked_df.Crop[i][:3] + ranked_df.Crop[i][-1] + "_step1"
            df_name = pd.concat([crop_1, crop_not])
            df_name = df_name.sort_index()
#             df_name = np.minimum(df_name, dist_array_aei)
            df_list.append(df_name[array_name])

            Step_1 = pd.concat(df_list, axis=1).sum(axis=1)
    
            if 'df_cumulative_st1' not in locals() or df_cumulative_st1.empty:
   
                 df_cumulative_st1 = pd.Series(np.zeros(len(Step_1)), index=Step_1.index)
#             if 'df_cumulative_st1' not in locals() or df_cumulative_st1.empty:
#                 df_cumulative_st1 = Step_1.copy()  
#             else:
            df_cumulative_st1 += Step_1
            
            df_tot_st1 = pd.concat([df_mon, df_cumulative_st1], axis=1)
            df_tot_st1.columns = ['Month', 'Total_st1']
            


#           Step2
                # Filter the total dataframe for a month in which crop grow
            df_max_filt = df_tot_st1[df_tot_st1["Month"].isin(listcom)]

            # Group the cell values
            n = len(df_max_filt) // (r_s * c_s)

            # Select the maximum total area assigned for the month in which this crop grow
            df_max = df_max_filt.groupby(np.arange(len(df_max_filt)) // n).max()

            # Change it to array
            max_step2 = np.array(df_max["Total_st1"]).reshape(r_s, c_s)
#             print("Max:", np.max(max_step2))
#             print(np.shape(max_step2))
#             print(np.shape(dist_array_aei))
#            Determine the free AEI cell
            AEI_fr_ce_2 = np.where(dist_array_aei > max_step2, (dist_array_aei-max_step2), 0)
            

            # Determine the AH_free_cell
            AH_fr_ce_2 = np.maximum(AH_array - AD_area1, 0)

            # Potential area to be distributed in this step
            Pot_ATS2 = np.minimum(AEI_fr_ce_2, AH_fr_ce_2)

            # Determine the distribution ratio as the ratio of ATS and Pot_ATS
            with np.errstate(divide='ignore'):
                AD_ra2 = np.where(ATS_2<np.sum(Pot_ATS2),(ATS_2/np.sum(Pot_ATS2)), 1)

    #                 Exact area to be distributed at this step
            if ATS_2>0:
                AD_area2=Pot_ATS2*AD_ra2
                #Area to be distributed in step 1 and 2
                
            else:
                AD_area2=Pot_ATS2*0
                #Area to be distributed in step 1 and 2
#                 TAD_12=AD_area1
            TAD_12=AD_area1 + AD_area2
            
#             for row in range(TAD_12.shape[0]):
#                 for col in range(TAD_12.shape[1]):
#                     if TAD_12[row, col] <= dist_array_area[row, col]:
#                         TAD_12[row, col] = TAD_12[row, col]
#                     else:
#                         ratio = dist_array_area[row, col] / TAD_12[row, col]
#                         TAD_12[row, col] *= ratio
            print("Step2")
#             print("Crop:", ranked_df.Crop[i])
            if round(np.sum(TAD_12),2) < (ranked_df.Growing_area[i]):
                ATS_3= (ranked_df.Growing_area[i])-round(np.sum(TAD_12),2)
                AD_step2=TAD_12
                print("Iteration continues")
                print("Area distributed after step2:", round(np.sum(TAD_12),2))
                print("Area to be distributed in next step:", ATS_3)
            elif round(np.sum(TAD_12),2)==(ranked_df.Growing_area[i]):
                ATS_3= (ranked_df.Growing_area[i])-round(np.sum(TAD_12),2)  
                AD_step2=TAD_12
                print("Iteration completed ")
                print("Area distributed after step2:", round(np.sum(TAD_12),2)) 
            # Create a list to store arrays
            else:
                
                if ranked_df.Growing_area[i] >0:
                    print("Error check your code!")
                    print("More area available than the growing area (Scaling is needed)")
                    ratio=ranked_df.Growing_area[i]/np.sum(TAD_12)
    #                             print(ratio)
                    AD_step2=TAD_12*ratio
                    ATS_3= 0
                    print("Iteration completed")
                    print("Area distributed in step1:", round(np.sum(AD_step2),2))
                if ranked_df.Growing_area[i]== 0:
                    AD_step2=TAD_12*0
                    ATS_3= 0
                    print("No area will be distributed in step2 (Zero harvested area)")

            df_list = []

            # Create array for step 2
            
            array_name2 = "Array_" + ranked_df.Crop[i][:3] + ranked_df.Crop[i][-1] + "2"
            arr2 = TAD_12

            # Repeat array for 12 months
            arr2_re = np.repeat(arr2, 12)

            # Convert array to dataframe
            df_2 = pd.DataFrame(arr2_re, index=np.arange(len(df_mon)), columns=[array_name2])

            # Merge month and array dataframes
            df_area2 = pd.concat([df_mon, df_2], axis=1)

            # Filter the months when the crop grows
            crop_1 = df_area2[(df_area2["Month"].isin(listcom))]

            # Filter the months when the crop doesn't grow
            crop_not = df_area2[(~df_area2["Month"].isin(listcom))]

            # Set the value of the array to 0 for months when the crop doesn't grow
            crop_not[array_name2].values[:] = 0

            # Concatenate the two dataframes and sort by index
            df_name2 = ranked_df.Crop[i][:3] + ranked_df.Crop[i][-1] + "_step2"
            df_name2 = pd.concat([crop_1, crop_not])
            df_name2 = df_name2.sort_index()
#             df_name2 = np.minimum(df_name2, dist_array_aei)
            # Add the dataframe to the list
            df_list.append(df_name2[array_name2])

            # Concatenate all the dataframes in the list into a single array
            Step_2 = pd.concat(df_list, axis=1).sum(axis=1)
           
            if 'df_cumulative_st2' not in locals() or df_cumulative_st2.empty:
   
                 df_cumulative_st2 = pd.Series(np.zeros(len(Step_2)), index=Step_2.index)
#             if 'df_cumulative_st1' not in locals() or df_cumulative_st1.empty:
#                 df_cumulative_st1 = Step_1.copy()  
#             else:
            df_cumulative_st2 += Step_2
            df_tot_st2 = pd.concat([df_mon, df_cumulative_st2], axis=1)
            df_tot_st2.columns = ['Month', 'Total_st2']
#             print("Total Step2:", df_tot_st2.head(24))


#            #Step3
    #        Select the total dataframe for a month in which crop grow
            df_max_filt3 = df_tot_st2[df_tot_st2["Month"].isin(listcom)]
            #group the cell values
            n = len(df_max_filt3) // (r_s * c_s)
            #Select the maximum total area assigned for the month in which this crop grow
            df_max3 = df_max_filt3.groupby(np.arange(len(df_max_filt3)) // n).max()
            max_step3 = np.array(df_max3["Total_st2"]).reshape(r_s, c_s)
    #                                     Detrmine the free AEI cell
            AEI_fr_ce_3 = np.where(dist_array_aei > max_step3, (dist_array_aei-max_step3), 0)
#             AEI_fr_ce_3 = np.maximum(dist_array_aei - max_step3, 0)
            Pot_ATS3 = np.where(dist_array_cle>0,(AEI_fr_ce_3), 0)
            with np.errstate(divide='ignore'):
                AD_ra3 = np.where((ATS_3<np.sum(Pot_ATS3)),(ATS_3/np.sum(Pot_ATS3)), 1)
            if ATS_3>0:
                AD_area3=Pot_ATS3*AD_ra3
                
            else:
                AD_area3=Pot_ATS3*0
#                 TAD_13=AD_area1+AD_area2
            TAD_13=AD_area1+AD_area2+AD_area3
            
            print("Step3")
#             print("Crop:", ranked_df.Crop[i])
            if round (np.sum(TAD_13),2) < (ranked_df.Growing_area[i]):
                AD_step3=TAD_13
                ATS_4=ranked_df.Growing_area[i]-round(np.sum(TAD_13),2)
                print("Iteration continues")
                print("Area distributed after step3:", round (np.sum(TAD_13),2))
                print("Area to be distributed in next step:", ATS_4)
            elif round(np.sum(TAD_13),2)==(ranked_df.Growing_area[i]):
                AD_step3=TAD_13
                ATS_4=ranked_df.Growing_area[i]-round(np.sum(TAD_13),2)
                print("Iteration completed ")
                print("Area distributed after step3", round (np.sum(TAD_13),2))
            else:
                
                if ranked_df.Growing_area[i] >0:
                    print("Error check your code!")
                    print("More area available than the growing area (Scaling is needed)")
                    ratio=ranked_df.Growing_area[i]/np.sum(TAD_13)
    #                             print(ratio)
                    AD_step3=TAD_13*ratio
                    ATS_4= 0
                    print("Iteration completed")
                    print("Area distributed in step1:",round(np.sum(AD_step3),2))
                if ranked_df.Growing_area[i]== 0:
                    AD_step3=TAD_13*0
                    ATS_4= 0
                    print("No area will be distributed in step3 (Zero harvested area)")
#             for row in range(TAD_13.shape[0]):
#                 for col in range(TAD_13.shape[1]):
#                     if TAD_13[row, col] <= dist_array_area[row, col]:
#                         TAD_13[row, col] = TAD_13[row, col]
#                     else:
#                         ratio = dist_array_area[row, col] / TAD_13[row, col]
#                         TAD_13[row, col] *= ratio
            # Call the array to be distributed in step1 and convert it to dataframe

            df_list = []
            array_name3 = "Array_" + ranked_df.Crop[i][:3] + ranked_df.Crop[i][-1] + "3"
            arr3 = TAD_13
            # repeat it for every twelve months
            arr_re3 = np.repeat(arr3, 12)
            # Change the array to dataframe
            df_3 = pd.DataFrame(arr_re3, index=np.arange(len(df_mon)), columns=[array_name3])
            # Merge the month and array dataframe
            df_area3 = pd.concat([df_mon, df_3], axis=1)
            # Filter the month in which the crop grows according to the crop calendar
            crop_1 = df_area3[(df_area3["Month"].isin(listcom))]
            # Filter the month in which the crop didn't grow according to the crop calendar
            crop_not = df_area3[(~df_area3["Month"].isin(listcom))]
            crop_not[array_name3].values[:] = 0
            # Merge the two dataframes and sort it based on index
            df_name3 = ranked_df.Crop[i][:3] + ranked_df.Crop[i][-1] + "_step3"
            df_name3 = pd.concat([crop_1, crop_not])
            df_name3 = df_name3.sort_index()

            # Add the dataframe to the list
            df_list.append(df_name3[array_name3])

            # Concatenate all the dataframes in the list into a single array
            Step_3 = pd.concat(df_list, axis=1).sum(axis=1)

            # Create a dataframe from the final array

            if 'df_cumulative_st3' not in locals() or df_cumulative_st3.empty:
   
                 df_cumulative_st3 = pd.Series(np.zeros(len(Step_3)), index=Step_3.index)

            df_cumulative_st3 += Step_3
            df_tot_st3 = pd.concat([df_mon, df_cumulative_st3], axis=1)
            df_tot_st3.columns = ['Month', 'Total_st3']
#             print("Total Step3:", df_tot_st3.tail(24))


            



            #Step4
            # #             #Select the total dataframe for a month in which crop grow
            df_max_filt4 = df_tot_st3[df_tot_st3["Month"].isin(listcom)]

            #group the cell values
            n = len(df_max_filt4)//(r_s*c_s)

            #Select the maximum total area assigned for the month in which this crop grow
            df_max4 = df_max_filt4.groupby(np.arange(len(df_max_filt4))//n).max()

            #Change it to array
            max_step4 = np.array(df_max4["Total_st3"]).reshape(r_s, c_s)

            #Determine the free AEI cell
            AEI_fr_ce_4 = np.where(dist_array_aei > max_step4, (dist_array_aei-max_step4), 0)
#             AEI_fr_ce_4 = np.maximum(dist_array_aei - max_step4, 0)
            print(np.sum(AEI_fr_ce_4))

            Pot_ATS4 = np.where(dist_array_cle == 0, AEI_fr_ce_4, 0)
            with np.errstate(divide='ignore'):
                AD_ra4 =np.where((ATS_4<np.sum(Pot_ATS4)),(ATS_4/np.sum(Pot_ATS4)), 1)
              

            if ATS_4>0:
                AD_area4=Pot_ATS4*AD_ra4
                
            else:
                AD_area4=Pot_ATS4*0
#                 TAD_14=AD_area1+AD_area2+AD_area3
            TAD_14=AD_area1+AD_area2+AD_area3+AD_area4
            
#             for row in range(TAD_14.shape[0]):
#                 for col in range(TAD_14.shape[1]):
#                     if TAD_14[row, col] <= dist_array_area[row, col]:
#                         TAD_14[row, col] = TAD_14[row, col]
#                     else:
#                         ratio = dist_array_area[row, col] / TAD_14[row, col]
#                         TAD_14[row, col] *= ratio


            # Create a list of dataframes to store the result for each crop
            df_list = []

            # Call the array to be distributed in step4 and convert it to dataframe
            array_name4 = "Array_" + ranked_df.Crop[i][:3] + ranked_df.Crop[i][-1] + "4"

            arr = TAD_14
            TAD_14_dict[unit_code] = TAD_14
#             print(arr)
            # Repeat it for every twelve months
            arr_re = np.repeat(arr, 12)
            # Change the array to dataframe
            df = pd.DataFrame(arr_re, index=np.arange(len(df_mon)), columns=[array_name4])
            # Merge the month and array dataframe
            df_area4 = pd.concat([df_mon, df], axis=1)
            # Filter the month in which the crop grows according to the crop calendar
            crop_1 = df_area4[(df_area4["Month"].isin(listcom))]
            # Filter the month in which the crop didn't grow according to the crop calendar
            crop_not = df_area4[(~df_area4["Month"].isin(listcom))]
            crop_not[array_name4].values[:] = 0
            # Merge the two dataframes and sort it based on index
            df_name4 = ranked_df.Crop[i][:3] + ranked_df.Crop[i][-1] + "_step4"
            df_name4 = pd.concat([crop_1, crop_not])
            df_name4 = df_name4.sort_index()

#             # Add the dataframe to the list
            df_list.append(df_name4[array_name4])
#             print(df_list)

            # Concatenate all the dataframes in the list into a single array
            Step_4 = pd.concat(df_list, axis=1).sum(axis=1)

#             for crop_ir in ranked_df['Crop'].unique():
#                 df_crop_ir = ranked_df[ranked_df['Crop'] == crop_ir]
            
            if 'df_cumulative_st4' not in locals() or df_cumulative_st4.empty:
   
                 df_cumulative_st4 = pd.Series(np.zeros(len(Step_4)), index=Step_4.index)

            df_cumulative_st4 += Step_4
            df_irrigaed=pd.concat([df_mon, Step_4], axis=1)
            df_irrigaed.columns = ['Month', 'Total_st4']
#             print(ranked_df["Crop"][i])
#             print(ranked_df["unit_code"][i])
#             print("Sum of Step_4:", df_irrigaed.max())

            df_tot_st4 = pd.concat([df_mon, df_cumulative_st4], axis=1)
            df_tot_st4.columns = ['Month', 'Total_st4']
          
#             print(ranked_df["Crop"][i])
#             print(ranked_df["unit_code"][i])
#             first_month_data = df_tot_st4[df_tot_st4['Month'] == 3]
#             first_month_sum = first_month_data['Total_st4'].sum()
#             print("First month cumulative sum across all crops:", first_month_sum)
            df_max_filt5 = df_tot_st4[df_tot_st4["Month"].isin(listcom)]
            n = len(df_max_filt5) // (r_s * c_s)
            df_max5 = df_max_filt5.groupby(np.arange(len(df_max_filt5)) // n).max()
            max_step5 = np.array(df_max5["Total_st4"]).reshape(r_s, c_s)
            
            aei_free[unit_code] = dist_array_aei
            cle_free[unit_code] = np.where(dist_array_cle > max_step5, (dist_array_cle - max_step5), 0)
            area[unit_code] = dist_array_area
            print("Step4")
            if round(np.sum(TAD_14)) < (ranked_df.Growing_area[i]):
                print("Error Check Your Code! (full area not assigned)")
                print("Area distributed after step4:", round(np.sum(TAD_14)))
            elif round(np.sum(TAD_14))==(ranked_df.Growing_area[i]):
                print("Iteration completed ")
                print("Area distributed after step4:", round(np.sum(TAD_14)))
            else:
                if (round(np.sum(TAD_14)) - (ranked_df_rf.Growing_area[i]))<1:
                    print("Iteration completed ")
                    print("Area distributed after step4", round(np.sum(TAD_14)))
            if ranked_df.Growing_area[i] > 0:
                with rasterio.open(tiff_ir) as src:
                    xmin, ymin, xmax, ymax = src.bounds
                    xres, yres = src.res
                    pixel_width, pixel_height = src.res
                    crs = src.crs

                    for k in listcom:
                        file_name = ranked_df.Crop[i][:3] + ranked_df.Crop[i][-1] + str(unit_code)+"_tot"
                        df_max_filt4 = df_irrigaed[(df_irrigaed["Month"] == int(k))]
                        arr_filenam = np.array(df_max_filt4["Total_st4"]).reshape(r_s, c_s)
                        mask = np.logical_or(np.isnan(arr_filenam), np.logical_or(np.isinf(arr_filenam), arr_filenam == np.NINF))
                        arr_filenam = np.where(mask, 0, arr_filenam)
                        arr_filenam = arr_filenam.astype(rasterio.float32)
                        Ras_filena = ranked_df.Crop[i][:3] + ranked_df.Crop[i][-1]+ "_"+ str(unit_code)+"_" +"ir" +"_"+str(k)
                        transform = rasterio.transform.from_origin(xmin, ymax, pixel_width, pixel_height)
                        profile = {
                            'driver': 'GTiff',
                            'dtype': arr_filenam.dtype,
                            'count': 1,
                            'height': arr_filenam.shape[0],
                            'width': arr_filenam.shape[1],
                            'transform': transform,
                            'crs': crs,
                            'nodata': 0
                        }
                        output_folder = r"D:\\PhD_Udel\\MICRA_2015\\DOwnscaling\\NASAOCE\\Maps 2015\\District\\Irrigated"
                        with rasterio.open(os.path.join(output_folder, Ras_filena + '.tif'), 'w', **profile) as dst:
                            dst.write(arr_filenam, 1)
    for unit_code_rf in ranked_df_rf['unit_code'].unique():
#         for unit_code in ranked_df['unit_code'].unique():
        for k in range(1, int(np.max(ranked_df_rf['rank']) + 1)):
            rows = ranked_df_rf.loc[(ranked_df_rf['unit_code'] == unit_code_rf) & (ranked_df_rf['rank'] == k)]
            for i_rf, row in rows.iterrows():
                if unit_code_rf == unit_code:
                    # Use aei_free[unit_code] in the calculations
                    TAD_14_for_unit = TAD_14_dict.get(unit_code)
                    dist_array_area = area.get(unit_code)
                    dist_array_aei = aei_free.get(unit_code)
                    dist_array_cle = cle_free.get(unit_code)
                    if dist_array_area is not None and dist_array_aei is not None and dist_array_cle is not None:
                        p = ranked_df_rf.Planting_Month[i_rf]
                        m = ranked_df_rf.Maturity_Month[i_rf]
                        listcomrf = getListcom(p, m)
                        for tiff_file in tiff_files:
        #                     print(tiff_file)
                            for subfolder_path in sub_dirs[1:]:
                                subfolder_name = os.path.basename(subfolder_path)
            #                     print(subfolder_name)
            #                     print(os.path.basename(tiff_file)[:-4])
                                if os.path.basename(tiff_file)[:-4] == str(unit_code_rf):
                                    if subfolder_name == "AEI_15":
                                        tiff_rf=tiff_file     
            #                 Perform calculations using the retrieved aei_free[unit_code]

                        ATS_5 = ranked_df_rf.Growing_area[i_rf]
                        if ranked_df_rf.Crop[i_rf] in Annual:
                            Pot_ATS5 = dist_array_cle
                        else:
                            Pot_ATS5 = np.where(dist_array_cle > dist_array_aei, dist_array_cle, 0)
                        with np.errstate(divide='ignore'):
                            AD_ra5=np.where(ATS_5<np.sum(Pot_ATS5),(ATS_5/np.sum(Pot_ATS5)), 1)
                        AD_area5=Pot_ATS5*AD_ra5
                        TAD_5=AD_area5
#     #                         for row in range(TAD_5.shape[0]):
#     #                             for col in range(TAD_5.shape[1]):
#     #                                 if TAD_5[row, col] <= dist_array_area[row, col]:
#     #                                     TAD_5[row, col] = TAD_5[row, col]
#     #                                 else:
#     #                                     ratio = dist_array_area[row, col] / TAD_5[row, col]
#     #                                     TAD_5[row, col] *= ratio
#                                     #             print(TAD_5)
                        #Call the array to be distributed in step4 and convert it to dataframe
                        df_list = []
                        array_name5="Array_"+ranked_df_rf.Crop[i][:3]+ranked_df_rf.Crop[i][-1]+"5"
            #                         print(array_name)
                        arr=TAD_5
                        #repaeat it for every tweleve month
                        arr_re5=np.repeat(arr, 12)
                        #Change the array to dataframe
                        c_s = len(arr[0])
                        r_s = len(arr)
                        df_month = pd.DataFrame(np.arange(1, 13), columns=['Month'])
                        df_mon = pd.concat([df_month] * c_s * r_s, ignore_index=True)
                        # Change the array to dataframe
                        df_5 = pd.DataFrame(arr_re5, index=np.arange(len(df_mon)), columns=[array_name5])
                        # Merge the month and array dataframe
                        df_area5 = pd.concat([df_mon, df_5], axis=1)
                        #Filter the month in which the crop grows accporidng to the crop calendar
                        crop_1=df_area5[(df_area5["Month"].isin(listcomrf))]
                        #Filter the month in which the crop didn't grows accporidng to the crop calendar
                        crop_not=df_area5[(~df_area5["Month"].isin(listcomrf))]
                        for col in crop_not.columns:
                            crop_not[array_name5].values[:] = 0 
                        # Merge the two dataframes and sort it based on index
                        df_name5 = ranked_df_rf.Crop[i][:3] + ranked_df_rf.Crop[i][-1] + "_step5"
                        df_name5 = pd.concat([crop_1, crop_not])
                        df_name5 = df_name5.sort_index()
            #             d_tot=df_name4+df_name3=df_name2+df_name1
            #                         print(df_name5)
            #             # Add the dataframe to the list
                        df_list.append(df_name5[array_name5])
            #             print(df_list)

                        # Concatenate all the dataframes in the list into a single array
                        Step_5 = pd.concat(df_list, axis=1).sum(axis=1)
            #             print(Step_4)
                        # Create a dataframe from the final array
                        if 'df_cumulative_st5' not in locals() or df_cumulative_st5.empty:

                             df_cumulative_st5 = pd.Series(np.zeros(len(Step_5)), index=Step_5.index)

                        df_cumulative_st5 += Step_5
                        df_tot_st5 = pd.concat([df_mon, df_cumulative_st5], axis=1)
                        df_tot_st5.columns = ['Month', 'Total_st5']
            #                         print("step5:", np.shape(df_tot_st5))
            #             print("AEI:", np.shape(dist_array_aei))
                        print("unit code:", ranked_df_rf.unit_code[i_rf])
                        print("Step5")
                        print("Crop:", ranked_df_rf.Crop[i_rf])
                        if round(np.sum(TAD_5),2) < (ranked_df_rf.Growing_area[i_rf]):
                            print("Iteration continues")
                            AD_step5=AD_area5
                            ATS_6= (ranked_df_rf.Growing_area[i_rf])-np.sum(TAD_5)
                            print("Area distributed after step5:", round(np.sum(TAD_5),2))
                            print("Area to be distributed in next step:", ATS_6)
                        elif round(np.sum(TAD_5),2)==(ranked_df_rf.Growing_area[i_rf]):
                            print("Iteration completed ")
                            AD_step5=AD_area5
                            ATS_6= 0
                            print("Area distributed after step5:",round(np.sum(TAD_5),2))
                        else:
                            if ranked_df_rf.Growing_area[i_rf]== 0:
                                AD_step5=AD_area5*0
                                ATS_6= 0
                                print("No area will be distributed in step5 (zero harvested area)")
                            elif ranked_df_rf.Growing_area[i_rf] >0:
                                print("Error check your code!")
                                print("More area available than the growing area")
                                ratio=ranked_df_rf.Growing_area[i_rf]/np.sum(TAD_5)
                                AD_step5=AD_area5*ratio
                                ATS_6= 0
                                print("Iteration completed")
                                print("Area distributed after step5:", round(np.sum(AD_step5),2))


                        #Step6
                        #Select the total dataframe for a month in which crop grow
                        df_max_filt6=df_tot_st5[(df_tot_st5["Month"].isin(listcomrf))]
                        #group the cell values
                        n=len(df_max_filt6)/(r_s*c_s)
                        #Select the maximum total area assigned for the month in which this crop grow
                        df_max6= df_max_filt6.groupby(np.arange(len(df_max_filt6))//n).max()
                        #Change it to array
                        max_step6=np.array(df_max6["Total_st5"]).reshape(r_s, c_s)
                        ##Detrmine the free AEI cell
                        AEI_fr_ce_6 = np.where(dist_array_aei > max_step6, (dist_array_aei-max_step6), 0)
                        CLE_free_6=np.where(dist_array_cle > max_step6, (dist_array_cle-max_step6), 0)
                        area_95_=0.95*dist_array_area
                        free_area_95_6=np.where(area_95_> max_step6, (area_95_-max_step6), 0)
                        if ranked_df_rf.Crop[i_rf] in Annual:

                            Pot_ATS6=np.where(dist_array_cle>0,(AEI_fr_ce_6), 0)
                        else:

                            Pot_ATS6=np.where(dist_array_cle>dist_array_aei,(free_area_95_6), 0)
                        with np.errstate(divide='ignore'):
                            AD_ra6=np.where(ATS_6<np.sum(Pot_ATS6),(ATS_6/np.sum(Pot_ATS6)), 1)
                        if ATS_6>0:
                            AD_area6=Pot_ATS6*AD_ra6

                        else:
                            AD_area6=(Pot_ATS6*AD_ra6)*0
                        TAD_56=AD_area5+AD_area6

            #             print(TAD_5)
                        #Call the array to be distributed in step4 and convert it to dataframe
                        df_list = []
                        array_name6="Array_"+ranked_df_rf.Crop[i_rf][:3]+ranked_df_rf.Crop[i_rf][-1]+"6"
            #             print(array_name)
                        arr=TAD_56
                        #repaeat it for every tweleve month
                        arr_re6=np.repeat(arr, 12)
                        #Change the array to dataframe
                        df_6=pd.DataFrame(arr_re6,index=np.arange(len(df_mon)),columns = [array_name6])
                        #Merge the month and array datarame
                        df_area6 = pd.concat([df_mon, df_6], axis=1)
                        #Filter the month in which the crop grows accporidng to the crop calendar
                        crop_1=df_area6[(df_area6["Month"].isin(listcomrf))]
                        #Filter the month in which the crop didn't grows accporidng to the crop calendar
                        crop_not=df_area6[(~df_area6["Month"].isin(listcomrf))]
                        for col in crop_not.columns:
                            crop_not[array_name6].values[:] = 0
                        #Merge the two datafra'mes and sort it based on index
                        df_name6 = ranked_df_rf.Crop[i_rf][:3] + ranked_df_rf.Crop[i_rf][-1] + "_step6"
                        df_name6 = pd.concat([crop_1, crop_not])
                        df_name6 = df_name6.sort_index()
            #             d_tot=df_name4+df_name3=df_name2+df_name1
            #             print(Ric1_step4)
            #             # Add the dataframe to the list
                        df_list.append(df_name6[array_name6])
            #             print(df_list)

                        # Concatenate all the dataframes in the list into a single array
                        Step_6 = pd.concat(df_list, axis=1).sum(axis=1)
                        if 'df_cumulative_st6' not in locals() or df_cumulative_st6.empty:

                             df_cumulative_st6 = pd.Series(np.zeros(len(Step_6)), index=Step_6.index)

                        df_cumulative_st6 += Step_6
            #             print(Step_4)
                        # Create a dataframe from the final array
                        df_tot_st6 = pd.concat([df_mon, df_cumulative_st6], axis=1)
                        df_tot_st6.columns = ['Month', 'Total_st6']
                        print("Step6")
#                         print("Crop:", ranked_df_rf.Crop[i_rf])
                        if round(np.sum(TAD_56),2) < (ranked_df_rf.Growing_area[i_rf]):
                            print("Iteration continues")
                            AD_step6=TAD_56
                            ATS_7= (ranked_df_rf.Growing_area[i_rf])-np.sum(TAD_56)
                            print("Area distributed after step6:", round(np.sum(TAD_56),2))
                            print("Area to be distributed in next step:", ATS_7)
                        elif round(np.sum(TAD_56),2)==(ranked_df_rf.Growing_area[i_rf]):
                            print("Iteration completed ")
                            AD_step6=TAD_56
                            ATS_7= 0
                            print("Area distributed after step6:", round(np.sum(TAD_56),2))

                        else:
                            if ranked_df_rf.Growing_area[i_rf]== 0:
                                AD_step6=TAD_56*0
                                ATS_7= 0
                                print("No area will be distributed in step6 (zero harvested area)")
                            elif ranked_df_rf.Growing_area[i_rf] >0:
                                print("Error check your code!")
                                print("More area available than the growing area")
                                ratio=ranked_df_rf.Growing_area[i_rf]/np.sum(TAD_56)
                                AD_step6=TAD_56*ratio
                                ATS_7= 0
                                print("Iteration completed ")
                                print("Area distributed after step6:", round(np.sum(AD_step6),2)) 

                        #Step7
                        #Select the total dataframe for a month in which crop grow
                        df_list = []
                        df_max_filt7=df_tot_st6[(df_tot_st6["Month"].isin(listcomrf))]
                        #group the cell values
                        n=len(df_max_filt7)/(r_s*c_s)
                        #Select the maximum total area assigned for the month in which this crop grow
                        df_max7= df_max_filt7.groupby(np.arange(len(df_max_filt7))//n).max()
                        #Change it to array
                        max_step7=np.array(df_max7["Total_st6"]).reshape(r_s, c_s)
                        ##Detrmine the 95% of cell area
                        AEI_fr_ce_7 = np.where(dist_array_aei > max_step7, (dist_array_aei-max_step7), 0)
                        CLE_free_7=np.where(dist_array_cle > max_step7, (dist_array_cle-max_step7), 0)
                        area_95_=0.95*dist_array_area
                        free_area_95_7=np.where(area_95_> max_step7, (area_95_-max_step7), 0)

            #             print("ATS",ATS_3)
                        Pot_ATS7=np.where(((dist_array_cle>0)|(dist_array_aei>0)) ,(free_area_95_7), 0)
            #             print("POTS",Pot_ATS7)
                        with np.errstate(divide='ignore'):
                            AD_ra7=np.where(ATS_7<np.sum(Pot_ATS7),(ATS_7/np.sum(Pot_ATS7)), 1)
                        if ATS_7>0:
                            AD_area7=Pot_ATS7*AD_ra7

                        else:
                            AD_area7=(Pot_ATS7*AD_ra7)*0
#                             TAD_57=AD_area5+AD_area6
                        TAD_57=AD_area5+AD_area6+AD_area7

#                       
                        #Call the array to be distributed in step4 and convert it to dataframe
                        array_name7="Array_"+ranked_df_rf.Crop[i][:3]+ranked_df_rf.Crop[i][-1]+"7"
            #             print(array_name)
                        arr=TAD_57
                        #repaeat it for every tweleve month
                        arr_re7=np.repeat(arr, 12)
                        #Change the array to dataframe
                        df_7=pd.DataFrame(arr_re7,index=np.arange(len(df_mon)),columns = [array_name7])
                        #Merge the month and array datarame
                        df_area7 = pd.concat([df_mon, df_7], axis=1)
                        #Filter the month in which the crop grows accporidng to the crop calendar
                        crop_1=df_area7[(df_area7["Month"].isin(listcomrf))]
                        #Filter the month in which the crop didn't grows accporidng to the crop calendar
                        crop_not=df_area7[(~df_area7["Month"].isin(listcomrf))]
                        for col in crop_not.columns:
                            crop_not[array_name7].values[:] = 0
                        #Merge the two datafra'mes and sort it based on index
            #Merge the two datafra'mes and sort it based on index
                        #Merge the two datafra'mes and sort it based on index
                        df_name7 = ranked_df_rf.Crop[i_rf][:3] + ranked_df_rf.Crop[i_rf][-1] + "_step7"
                        df_name7 = pd.concat([crop_1, crop_not])
                        df_name7 = df_name7.sort_index()
            #             d_tot=df_name4+df_name3=df_name2+df_name1
            #             print(Ric1_step4)
            #             # Add the dataframe to the list
                        df_list.append(df_name7[array_name7])
            #             print(df_list)

                        # Concatenate all the dataframes in the list into a single array
                        Step_7 = pd.concat(df_list, axis=1).sum(axis=1)
                        if 'df_cumulative_st7' not in locals() or df_cumulative_st7.empty:

                             df_cumulative_st7 = pd.Series(np.zeros(len(Step_7)), index=Step_7.index)

                        df_cumulative_st7 += Step_7
            #             print(Step_4)
                        # Create a dataframe from the final array
                        df_rainfed=pd.concat([df_mon, Step_7], axis=1)
                        df_rainfed.columns = ['Month', 'Total_st7']
                        df_tot_st7 = pd.concat([df_mon, df_cumulative_st7], axis=1)
                        df_tot_st7.columns = ['Month', 'Total_st7']
            #                         print("Step 7 rainfed total:",df_tot_st7.head() )
            #                         Define the spatial extent and resolution of the output raster
                        print("Step7")
#                         print("Crop:", ranked_df_rf.Crop[i_rf])
                        if round(np.sum(TAD_57)) < (ranked_df_rf.Growing_area[i_rf]):
                            print("Error Check Your Code!")
                            print("Area distributed after step7:", round(np.sum(TAD_57)))
                        elif round(np.sum(TAD_57))==(ranked_df.Growing_area[i_rf]):
                            print("Iteration completed ")
                            print("Area distributed after step7", round(np.sum(TAD_57)))
                        else:
                            if (round(np.sum(TAD_57)) - (ranked_df_rf.Growing_area[i_rf]))<1:
                                print("Iteration completed ")
                                print("Area distributed after step7", round(np.sum(TAD_57)))

                        if ranked_df_rf.Growing_area[i_rf]>0:
                            with rasterio.open(tiff_rf) as src:
                                xmin, ymin, xmax, ymax = src.bounds
                                xres, yres = src.res
                                pixel_width, pixel_height = src.res
                                crs = src.crs

                                for k in listcomrf:
                                    file_name = ranked_df_rf.Crop[i_rf][:3] + ranked_df_rf.Crop[i_rf][-1] + str(unit_code)+"_tot"
                                    df_max_filt7 = df_rainfed[(df_rainfed["Month"] == int(k))]
                                    arr_filenam = np.array(df_max_filt7["Total_st7"]).reshape(r_s, c_s)
                                    mask = np.logical_or(np.isnan(arr_filenam), np.logical_or(np.isinf(arr_filenam), arr_filenam == np.NINF))
                                    arr_filenam = np.where(mask, 0, arr_filenam)
                                    arr_filenam = arr_filenam.astype(rasterio.float32)
                                    Ras_filena = ranked_df_rf.Crop[i_rf][:3] +ranked_df_rf.Crop[i_rf][-1]+ "_"+ str(unit_code)+"_" +"rf" +"_"+str(k)
                                    transform = rasterio.transform.from_origin(xmin, ymax, pixel_width, pixel_height)
                                    profile = {
                                        'driver': 'GTiff',
                                        'dtype': arr_filenam.dtype,
                                        'count': 1,
                                        'height': arr_filenam.shape[0],
                                        'width': arr_filenam.shape[1],
                                        'transform': transform,
                                        'crs': crs,
                                        'nodata': 0
                                    }
                                    output_folder =   r"D:\\PhD_Udel\\MICRA_2015\\DOwnscaling\\NASAOCE\\Maps 2015\\District\\Rainfed"
                                    with rasterio.open(os.path.join(output_folder, Ras_filena + '.tif'), 'w', **profile) as dst:
                                        dst.write(arr_filenam, 1)
# Out:
# 520000
# Step1
# Crop: Cocoa
# Iteration completed
# Area distributed after step1: 0.0
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 5400.000305175781
# Step4
# Iteration completed
# Area distributed after step4: 0
# 520000
# Step1
# Crop: Coffee
# Iteration completed
# Area distributed after step1: 0.0
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 5400.000305175781
# Step4
# Iteration completed
# Area distributed after step4: 0
# 520000
# Step1
# Crop: Oil palm
# Iteration completed
# Area distributed after step1: 0.0
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 5400.000305175781
# Step4
# Iteration completed
# Area distributed after step4: 0
# 520000
# Step1
# Crop: Sugar cane
# Iteration completed
# Area distributed after step1: 0.0
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 5400.000305175781
# Step4
# Iteration completed
# Area distributed after step4: 0
# 520000
# Step1
# Crop: Others perennial
# Iteration completed
# Area distributed after step1: 0.0
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 5400.000305175781
# Step4
# Iteration completed
# Area distributed after step4: 0
# 520000
# Step1
# Crop: Fodder
# Iteration completed
# Area distributed after step1: 0.0
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 5400.000305175781
# Step4
# Iteration completed
# Area distributed after step4: 0
# 520000
# Step1
# Crop: Barley
# Iteration completed
# Area distributed after step1: 0.0
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 5400.000305175781
# Step4
# Iteration completed
# Area distributed after step4: 0
# 520000
# Step1
# Crop: Cassava
# Iteration completed
# Area distributed after step1: 0.0
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 5400.000305175781
# Step4
# Iteration completed
# Area distributed after step4: 0
# 520000
# Step1
# Crop: Cotton
# Iteration completed
# Area distributed after step1: 0.0
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 5400.000305175781
# Step4
# Iteration completed
# Area distributed after step4: 0
# 520000
# Step1
# Crop: Groundnuts
# Iteration completed
# Area distributed after step1: 0.0
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 5400.000305175781
# Step4
# Iteration completed
# Area distributed after step4: 0
# 520000
# Step1
# Crop: Maize
# Iteration completed
# Area distributed after step1: 0.0
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 5400.000305175781
# Step4
# Iteration completed
# Area distributed after step4: 0
# 520000
# Step1
# Crop: Millet
# Iteration completed
# Area distributed after step1: 0.0
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 5400.000305175781
# Step4
# Iteration completed
# Area distributed after step4: 0
# 520000
# Step1
# Crop: Potatoes
# Iteration completed
# Area distributed after step1: 0.0
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 5400.000305175781
# Step4
# Iteration completed
# Area distributed after step4: 0
# 520000
# Step1
# Crop: Pulses
# Iteration completed
# Area distributed after step1: 0.0
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 5400.000305175781
# Step4
# Iteration completed
# Area distributed after step4: 0
# 520000
# Step1
# Crop: Rapeseed
# Iteration completed
# Area distributed after step1: 0.0
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 5400.000305175781
# Step4
# Iteration completed
# Area distributed after step4: 0
# 520000
# Step1
# Crop: Rice1
# Iteration completed
# Area distributed after step1: 0.0
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 5400.000305175781
# Step4
# Iteration completed
# Area distributed after step4: 0
# 520000
# Step1
# Crop: Rice2
# Iteration completed
# Area distributed after step1: 0.0
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 5400.000305175781
# Step4
# Iteration completed
# Area distributed after step4: 0
# 520000
# Step1
# Crop: Rye
# Iteration completed
# Area distributed after step1: 0.0
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 5400.000305175781
# Step4
# Iteration completed
# Area distributed after step4: 0
# 520000
# Step1
# Crop: Sorghum
# Iteration completed
# Area distributed after step1: 0.0
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 5400.000305175781
# Step4
# Iteration completed
# Area distributed after step4: 0
# 520000
# Step1
# Crop: Soybeans
# Iteration completed
# Area distributed after step1: 0.0
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 5400.000305175781
# Step4
# Iteration completed
# Area distributed after step4: 0
# 520000
# Step1
# Crop: Sugar beet
# Iteration completed
# Area distributed after step1: 0.0
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 5400.000305175781
# Step4
# Iteration completed
# Area distributed after step4: 0
# 520000
# Step1
# Crop: Sunflower
# Iteration completed
# Area distributed after step1: 0.0
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 5400.000305175781
# Step4
# Iteration completed
# Area distributed after step4: 0
# 520000
# Step1
# Crop: Wheat1
# Iteration completed
# Area distributed after step1: 0.0
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 5400.000305175781
# Step4
# Iteration completed
# Area distributed after step4: 0
# 520000
# Step1
# Crop: Wheat2
# Iteration completed
# Area distributed after step1: 0.0
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 5400.000305175781
# Step4
# Iteration completed
# Area distributed after step4: 0
# 520000
# Step1
# Crop: Others annual1
# Iteration continues
# Area distributed after step1: 0.0
# Area to be distributed in next step: 100.0
# Step2
# Iteration continues
# Area distributed after step2: 0.0
# Area to be distributed in next step: 100.0
# Step3
# Iteration completed
# Area distributed after step3 100.0
# 5300.000305175781
# Step4
# Iteration completed
# Area distributed after step4: 100
# 520000
# Step1
# Crop: Others annual2
# Iteration completed
# Area distributed after step1: 0.0
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 5300.000305175781
# Step4
# Iteration completed
# Area distributed after step4: 0
# unit code: 520000
# Step5
# Crop: Sugar cane
# Iteration completed
# Area distributed after step5: 3116.0
# Step6
# Iteration completed
# Area distributed after step6: 3116.0
# Step7
# Iteration completed
# Area distributed after step7 3116
# unit code: 520000
# Step5
# Crop: Cocoa
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 520000
# Step5
# Crop: Coffee
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 520000
# Step5
# Crop: Oil palm
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 520000
# Step5
# Crop: Others perennial
# Iteration completed
# Area distributed after step5: 526.0
# Step6
# Iteration completed
# Area distributed after step6: 526.0
# Step7
# Iteration completed
# Area distributed after step7 526
# unit code: 520000
# Step5
# Crop: Fodder
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 520000
# Step5
# Crop: Pulses
# Iteration completed
# Area distributed after step5: 696.0
# Step6
# Iteration completed
# Area distributed after step6: 696.0
# Step7
# Iteration completed
# Area distributed after step7 696
# unit code: 520000
# Step5
# Crop: Maize
# Iteration completed
# Area distributed after step5: 213.0
# Step6
# Iteration completed
# Area distributed after step6: 213.0
# Step7
# Iteration completed
# Area distributed after step7 213
# unit code: 520000
# Step5
# Crop: Cassava
# Iteration completed
# Area distributed after step5: 19.0
# Step6
# Iteration completed
# Area distributed after step6: 19.0
# Step7
# Iteration completed
# Area distributed after step7 19
# unit code: 520000
# Step5
# Crop: Groundnuts
# Iteration completed
# Area distributed after step5: 8.0
# Step6
# Iteration completed
# Area distributed after step6: 8.0
# Step7
# Iteration completed
# Area distributed after step7 8
# unit code: 520000
# Step5
# Crop: Barley
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 520000
# Step5
# Crop: Cotton
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 520000
# Step5
# Crop: Millet
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 520000
# Step5
# Crop: Potatoes
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 520000
# Step5
# Crop: Rapeseed
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 520000
# Step5
# Crop: Rice1
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 520000
# Step5
# Crop: Rice2
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 520000
# Step5
# Crop: Rye
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 520000
# Step5
# Crop: Sorghum
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 520000
# Step5
# Crop: Soybeans
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 520000
# Step5
# Crop: Sugar beet
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 520000
# Step5
# Crop: Sunflower
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 520000
# Step5
# Crop: Wheat1
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 520000
# Step5
# Crop: Wheat2
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 520000
# Step5
# Crop: Others annual1
# Iteration completed
# Area distributed after step5: 668.0
# Step6
# Iteration completed
# Area distributed after step6: 668.0
# Step7
# Iteration completed
# Area distributed after step7 668
# unit code: 520000
# Step5
# Crop: Others annual2
# Iteration completed
# Area distributed after step5: 486.0
# Step6
# Iteration completed
# Area distributed after step6: 486.0
# Step7
# Iteration completed
# Area distributed after step7 486
# unit code: 520000
# Step5
# Crop: Others annual3
# Iteration completed
# Area distributed after step5: 61.0
# Step6
# Iteration completed
# Area distributed after step6: 61.0
# Step7
# Iteration completed
# Area distributed after step7 61
# 520001
# Step1
# Crop: Others annual3
# Iteration completed
# Area distributed after step1: 0.0
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 5400.000305175781
# Step4
# Iteration completed
# Area distributed after step4: 0
# 680001
# Step1
# Crop: Cocoa
# Iteration continues
# Area distributed after step1: 10.0
# Area to be distributed in next step: 115.0
# Step2
# Iteration completed
# Area distributed after step2: 125.0
# Step3
# Iteration completed
# Area distributed after step3 125.0
# 23443.407156868
# Step4
# Iteration completed
# Area distributed after step4: 125
# 680001
# Step1
# Crop: Coffee
# Iteration continues
# Area distributed after step1: 10.0
# Area to be distributed in next step: 10.0
# Step2
# Iteration completed
# Area distributed after step2: 20.0
# Step3
# Iteration completed
# Area distributed after step3 20.0
# 23423.402349612865
# Step4
# Iteration completed
# Area distributed after step4: 20
# 680001
# Step1
# Crop: Sugar cane
# Iteration continues
# Area distributed after step1: 3.71
# Area to be distributed in next step: 9.289999961853027
# Step2
# Iteration completed
# Area distributed after step2: 13.0
# Step3
# Iteration completed
# Area distributed after step3 13.0
# 23410.399645779296
# Step4
# Iteration completed
# Area distributed after step4: 13
# 680001
# Step1
# Crop: Oil palm
# Iteration completed
# Area distributed after step1: 0.0
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 23410.399645779296
# Step4
# Iteration completed
# Area distributed after step4: 0
# 680001
# Step1
# Crop: Others perennial
# Iteration continues
# Area distributed after step1: 0.0
# Area to be distributed in next step: 1035.0
# Step2
# Iteration continues
# Area distributed after step2: 0.0
# Area to be distributed in next step: 1035.0
# Step3
# Iteration completed
# Area distributed after step3 1035.0
# 22375.399645779304
# Step4
# Iteration completed
# Area distributed after step4: 1035
# 680001
# Step1
# Crop: Fodder
# No area will be distributed in step1 (Zero harvested area)
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 22375.399645779304
# Step4
# Iteration completed
# Area distributed after step4: 0
# 680001
# Step1
# Crop: Rice1
# Iteration continues
# Area distributed after step1: 39.96
# Area to be distributed in next step: 4575.040000915527
# Step2
# Iteration continues
# Area distributed after step2: 2019.27
# Area to be distributed in next step: 2595.73
# Step3
# Iteration completed
# Area distributed after step3 4615.0
# 17785.94523099115
# Step4
# Iteration completed
# Area distributed after step4: 4615
# 680001
# Step1
# Crop: Maize
# Iteration continues
# Area distributed after step1: 172.04
# Area to be distributed in next step: 1153.9600067138672
# Step2
# Iteration completed
# Area distributed after step2: 1326.0
# Step3
# Iteration completed
# Area distributed after step3 1326.0
# 16531.920128524704
# Step4
# Iteration completed
# Area distributed after step4: 1326
# 680001
# Step1
# Crop: Cassava
# Iteration continues
# Area distributed after step1: 18.64
# Area to be distributed in next step: 165.36000061035156
# Step2
# Iteration completed
# Area distributed after step2: 184.0
# Step3
# Iteration completed
# Area distributed after step3 184.0
# 16405.474177469856
# Step4
# Iteration completed
# Area distributed after step4: 184
# 680001
# Step1
# Crop: Groundnuts
# Iteration continues
# Area distributed after step1: 4.81
# Area to be distributed in next step: 14.190000057220459
# Step2
# Iteration completed
# Area distributed after step2: 19.0
# Step3
# Iteration completed
# Area distributed after step3 19.0
# 16386.705591501053
# Step4
# Iteration completed
# Area distributed after step4: 19
# 680001
# Step1
# Crop: Sorghum
# Error check your code!
# More area available than the growing area
# Iteration completed
# Area distributed in step1: 3.0
# Step2
# Iteration completed
# Area distributed after step2: 3.0
# Step3
# Iteration completed
# Area distributed after step3 3.0
# 16383.706345845183
# Step4
# Iteration completed
# Area distributed after step4: 3
# 680001
# Step1
# Crop: Pulses
# Error check your code!
# More area available than the growing area
# Iteration completed
# Area distributed in step1: 2.0
# Step2
# Iteration completed
# Area distributed after step2: 2.0
# Step3
# Iteration completed
# Area distributed after step3 2.0
# 16381.873217180055
# Step4
# Iteration completed
# Area distributed after step4: 2
# 680001
# Step1
# Crop: Potatoes
# Error check your code!
# More area available than the growing area
# Iteration completed
# Area distributed in step1: 1.0
# Step2
# Iteration completed
# Area distributed after step2: 1.0
# Step3
# Iteration completed
# Area distributed after step3 1.0
# 16380.98556695318
# Step4
# Iteration completed
# Area distributed after step4: 1
# 680001
# Step1
# Crop: Wheat1
# Iteration continues
# Area distributed after step1: 0.77
# Area to be distributed in next step: 0.23000001907348633
# Step2
# Iteration completed
# Area distributed after step2: 1.0
# Step3
# Iteration completed
# Area distributed after step3 1.0
# 16380.651305352429
# Step4
# Iteration completed
# Area distributed after step4: 1
# 680001
# Step1
# Crop: Barley
# No area will be distributed in step1 (Zero harvested area)
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 16380.651305352429
# Step4
# Iteration completed
# Area distributed after step4: 0
# 680001
# Step1
# Crop: Cotton
# No area will be distributed in step1 (Zero harvested area)
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 16380.651305352429
# Step4
# Iteration completed
# Area distributed after step4: 0
# 680001
# Step1
# Crop: Millet
# Iteration completed
# Area distributed after step1: 0.0
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 16380.651305352429
# Step4
# Iteration completed
# Area distributed after step4: 0
# 680001
# Step1
# Crop: Rapeseed
# Iteration completed
# Area distributed after step1: 0.0
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 16380.651305352429
# Step4
# Iteration completed
# Area distributed after step4: 0
# 680001
# Step1
# Crop: Rice2
# No area will be distributed in step1 (Zero harvested area)
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 16380.651305352429
# Step4
# Iteration completed
# Area distributed after step4: 0
# 680001
# Step1
# Crop: Rye
# No area will be distributed in step1 (Zero harvested area)
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 16380.651305352429
# Step4
# Iteration completed
# Area distributed after step4: 0
# 680001
# Step1
# Crop: Soybeans
# No area will be distributed in step1 (Zero harvested area)
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 16380.651305352429
# Step4
# Iteration completed
# Area distributed after step4: 0
# 680001
# Step1
# Crop: Sugar beet
# Iteration completed
# Area distributed after step1: 0.0
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 16380.651305352429
# Step4
# Iteration completed
# Area distributed after step4: 0
# 680001
# Step1
# Crop: Sunflower
# No area will be distributed in step1 (Zero harvested area)
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 16380.651305352429
# Step4
# Iteration completed
# Area distributed after step4: 0
# 680001
# Step1
# Crop: Wheat2
# No area will be distributed in step1 (Zero harvested area)
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 16380.651305352429
# Step4
# Iteration completed
# Area distributed after step4: 0
# 680001
# Step1
# Crop: Others annual1
# Iteration continues
# Area distributed after step1: 94.9
# Area to be distributed in next step: 167.0999984741211
# Step2
# Iteration completed
# Area distributed after step2: 262.0
# Step3
# Iteration completed
# Area distributed after step3 262.0
# 16155.221644361809
# Step4
# Iteration completed
# Area distributed after step4: 262
# 680001
# Step1
# Crop: Others annual2
# No area will be distributed in step1 (Zero harvested area)
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 16155.221644361809
# Step4
# Iteration completed
# Area distributed after step4: 0
# unit code: 680001
# Step5
# Crop: Sugar cane
# Iteration completed
# Area distributed after step5: 1016.0
# Step6
# Iteration completed
# Area distributed after step6: 1016.0
# Step7
# Iteration completed
# Area distributed after step7 1016
# unit code: 680001
# Step5
# Crop: Cocoa
# Iteration completed
# Area distributed after step5: 765.0
# Step6
# Iteration completed
# Area distributed after step6: 765.0
# Step7
# Iteration completed
# Area distributed after step7 765
# unit code: 680001
# Step5
# Crop: Coffee
# Iteration completed
# Area distributed after step5: 169.0
# Step6
# Iteration completed
# Area distributed after step6: 169.0
# Step7
# Iteration completed
# Area distributed after step7 169
# unit code: 680001
# Step5
# Crop: Oil palm
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 680001
# Step5
# Crop: Others perennial
# Iteration completed
# Area distributed after step5: 8873.0
# Step6
# Iteration completed
# Area distributed after step6: 8873.0
# Step7
# Iteration completed
# Area distributed after step7 8873
# unit code: 680001
# Step5
# Crop: Fodder
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 680001
# Step5
# Crop: Rice1
# Iteration completed
# Area distributed after step5: 16722.0
# Step6
# Iteration completed
# Area distributed after step6: 16722.0
# Step7
# Iteration completed
# Area distributed after step7 16722
# unit code: 680001
# Step5
# Crop: Maize
# Iteration completed
# Area distributed after step5: 7925.0
# Step6
# Iteration completed
# Area distributed after step6: 7925.0
# Step7
# Iteration completed
# Area distributed after step7 7925
# unit code: 680001
# Step5
# Crop: Cassava
# Iteration completed
# Area distributed after step5: 5779.0
# Step6
# Iteration completed
# Area distributed after step6: 5779.0
# Step7
# Iteration completed
# Area distributed after step7 5779
# unit code: 680001
# Step5
# Crop: Soybeans
# Iteration completed
# Area distributed after step5: 4390.0
# Step6
# Iteration completed
# Area distributed after step6: 4390.0
# Step7
# Iteration completed
# Area distributed after step7 4390
# unit code: 680001
# Step5
# Crop: Sorghum
# Iteration completed
# Area distributed after step5: 738.0
# Step6
# Iteration completed
# Area distributed after step6: 738.0
# Step7
# Iteration completed
# Area distributed after step7 738
# unit code: 680001
# Step5
# Crop: Sunflower
# Iteration completed
# Area distributed after step5: 327.0
# Step6
# Iteration completed
# Area distributed after step6: 327.0
# Step7
# Iteration completed
# Area distributed after step7 327
# unit code: 680001
# Step5
# Crop: Groundnuts
# Iteration completed
# Area distributed after step5: 236.0
# Step6
# Iteration completed
# Area distributed after step6: 236.0
# Step7
# Iteration completed
# Area distributed after step7 236
# unit code: 680001
# Step5
# Crop: Wheat1
# Iteration completed
# Area distributed after step5: 21.0
# Step6
# Iteration completed
# Area distributed after step6: 21.0
# Step7
# Iteration completed
# Area distributed after step7 21
# unit code: 680001
# Step5
# Crop: Pulses
# Iteration completed
# Area distributed after step5: 7.0
# Step6
# Iteration completed
# Area distributed after step6: 7.0
# Step7
# Iteration completed
# Area distributed after step7 7
# unit code: 680001
# Step5
# Crop: Potatoes
# Iteration completed
# Area distributed after step5: 3.0
# Step6
# Iteration completed
# Area distributed after step6: 3.0
# Step7
# Iteration completed
# Area distributed after step7 3
# unit code: 680001
# Step5
# Crop: Barley
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 680001
# Step5
# Crop: Cotton
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 680001
# Step5
# Crop: Millet
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 680001
# Step5
# Crop: Rapeseed
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 680001
# Step5
# Crop: Rice2
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 680001
# Step5
# Crop: Rye
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 680001
# Step5
# Crop: Sugar beet
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 680001
# Step5
# Crop: Wheat2
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 680001
# Step5
# Crop: Others annual1
# Iteration completed
# Area distributed after step5: 1094.0
# Step6
# Iteration completed
# Area distributed after step6: 1094.0
# Step7
# Iteration completed
# Area distributed after step7 1094
# unit code: 680001
# Step5
# Crop: Others annual2
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# 680002
# Step1
# Crop: Sugar cane
# Iteration continues
# Area distributed after step1: 0.91
# Area to be distributed in next step: 2.0899999737739563
# Step2
# Iteration completed
# Area distributed after step2: 3.0
# Step3
# Iteration completed
# Area distributed after step3 3.0
# 29537.88342678547
# Step4
# Iteration completed
# Area distributed after step4: 3
# 680002
# Step1
# Crop: Coffee
# Iteration continues
# Area distributed after step1: 0.0
# Area to be distributed in next step: 1.0
# Step2
# Iteration continues
# Area distributed after step2: 0.0
# Area to be distributed in next step: 1.0
# Step3
# Iteration completed
# Area distributed after step3 1.0
# 29536.88342678547
# Step4
# Iteration completed
# Area distributed after step4: 1
# 680002
# Step1
# Crop: Cocoa
# Iteration completed
# Area distributed after step1: 0.0
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 29536.88342678547
# Step4
# Iteration completed
# Area distributed after step4: 0
# 680002
# Step1
# Crop: Oil palm
# Iteration completed
# Area distributed after step1: 0.0
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 29536.88342678547
# Step4
# Iteration completed
# Area distributed after step4: 0
# 680002
# Step1
# Crop: Others perennial
# Iteration continues
# Area distributed after step1: 0.0
# Area to be distributed in next step: 430.0
# Step2
# Iteration continues
# Area distributed after step2: 0.0
# Area to be distributed in next step: 430.0
# Step3
# Iteration completed
# Area distributed after step3 430.0
# 29106.88342678547
# Step4
# Iteration completed
# Area distributed after step4: 430
# 680002
# Step1
# Crop: Fodder
# Iteration continues
# Area distributed after step1: 52.43
# Area to be distributed in next step: 562.5699996948242
# Step2
# Iteration completed
# Area distributed after step2: 615.0
# Step3
# Iteration completed
# Area distributed after step3 615.0
# 28491.883545613506
# Step4
# Iteration completed
# Area distributed after step4: 615
# 680002
# Step1
# Crop: Maize
# Iteration continues
# Area distributed after step1: 358.6
# Area to be distributed in next step: 8374.399993896484
# Step2
# Iteration completed
# Area distributed after step2: 8733.0
# Step3
# Iteration completed
# Area distributed after step3 8733.0
# 19775.881294032915
# Step4
# Iteration completed
# Area distributed after step4: 8733
# 680002
# Step1
# Crop: Potatoes
# Iteration continues
# Area distributed after step1: 691.59
# Area to be distributed in next step: 6836.409973144531
# Step2
# Iteration continues
# Area distributed after step2: 4454.19
# Area to be distributed in next step: 3073.8100000000004
# Step3
# Iteration completed
# Area distributed after step3 7528.0
# 13319.233627660435
# Step4
# Iteration completed
# Area distributed after step4: 7528
# 680002
# Step1
# Crop: Pulses
# Iteration continues
# Area distributed after step1: 52.19
# Area to be distributed in next step: 2327.810001373291
# Step2
# Iteration completed
# Area distributed after step2: 2380.0
# Step3
# Iteration completed
# Area distributed after step3 2380.0
# 12464.29434381726
# Step4
# Iteration completed
# Area distributed after step4: 2380
# 680002
# Step1
# Crop: Barley
# Iteration continues
# Area distributed after step1: 16.66
# Area to be distributed in next step: 1179.340000152588
# Step2
# Iteration continues
# Area distributed after step2: 987.84
# Area to be distributed in next step: 208.15999999999997
# Step3
# Iteration completed
# Area distributed after step3 1196.0
# 11983.17344636398
# Step4
# Iteration completed
# Area distributed after step4: 1196
# 680002
# Step1
# Crop: Wheat1
# Iteration continues
# Area distributed after step1: 9.94
# Area to be distributed in next step: 922.0600004196167
# Step2
# Iteration continues
# Area distributed after step2: 356.07
# Area to be distributed in next step: 575.9300000000001
# Step3
# Iteration completed
# Area distributed after step3 932.0
# 11314.015957691307
# Step4
# Iteration completed
# Area distributed after step4: 932
# 680002
# Step1
# Crop: Groundnuts
# Iteration continues
# Area distributed after step1: 22.68
# Area to be distributed in next step: 275.3199996948242
# Step2
# Iteration completed
# Area distributed after step2: 298.0
# Step3
# Iteration completed
# Area distributed after step3 298.0
# 11308.87007435818
# Step4
# Iteration completed
# Area distributed after step4: 298
# 680002
# Step1
# Crop: Rice1
# Iteration continues
# Area distributed after step1: 38.99
# Area to be distributed in next step: 11.009998321533203
# Step2
# Iteration completed
# Area distributed after step2: 50.0
# Step3
# Iteration completed
# Area distributed after step3 50.0
# 11307.419599679786
# Step4
# Iteration completed
# Area distributed after step4: 50
# 680002
# Step1
# Crop: Cassava
# Iteration continues
# Area distributed after step1: 1.54
# Area to be distributed in next step: 7.460000038146973
# Step2
# Iteration completed
# Area distributed after step2: 9.0
# Step3
# Iteration completed
# Area distributed after step3 9.0
# 11307.245514581104
# Step4
# Iteration completed
# Area distributed after step4: 9
# 680002
# Step1
# Crop: Cotton
# No area will be distributed in step1 (Zero harvested area)
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 11307.245514581104
# Step4
# Iteration completed
# Area distributed after step4: 0
# 680002
# Step1
# Crop: Millet
# Iteration completed
# Area distributed after step1: 0.0
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 11307.245514581104
# Step4
# Iteration completed
# Area distributed after step4: 0
# 680002
# Step1
# Crop: Rapeseed
# Iteration completed
# Area distributed after step1: 0.0
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 11307.245514581104
# Step4
# Iteration completed
# Area distributed after step4: 0
# 680002
# Step1
# Crop: Rice2
# No area will be distributed in step1 (Zero harvested area)
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 11307.245514581104
# Step4
# Iteration completed
# Area distributed after step4: 0
# 680002
# Step1
# Crop: Rye
# No area will be distributed in step1 (Zero harvested area)
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 11307.245514581104
# Step4
# Iteration completed
# Area distributed after step4: 0
# 680002
# Step1
# Crop: Sorghum
# No area will be distributed in step1 (Zero harvested area)
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 11307.245514581104
# Step4
# Iteration completed
# Area distributed after step4: 0
# 680002
# Step1
# Crop: Soybeans
# No area will be distributed in step1 (Zero harvested area)
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 11307.245514581104
# Step4
# Iteration completed
# Area distributed after step4: 0
# 680002
# Step1
# Crop: Sugar beet
# Iteration completed
# Area distributed after step1: 0.0
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 11307.245514581104
# Step4
# Iteration completed
# Area distributed after step4: 0
# 680002
# Step1
# Crop: Sunflower
# No area will be distributed in step1 (Zero harvested area)
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 11307.245514581104
# Step4
# Iteration completed
# Area distributed after step4: 0
# 680002
# Step1
# Crop: Wheat2
# No area will be distributed in step1 (Zero harvested area)
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 11307.245514581104
# Step4
# Iteration completed
# Area distributed after step4: 0
# 680002
# Step1
# Crop: Others annual1
# Iteration continues
# Area distributed after step1: 76.91
# Area to be distributed in next step: 1398.0899963378906
# Step2
# Iteration completed
# Area distributed after step2: 1475.0
# Step3
# Iteration completed
# Area distributed after step3 1475.0
# 10996.561062101227
# Step4
# Iteration completed
# Area distributed after step4: 1475
# 680002
# Step1
# Crop: Others annual2
# No area will be distributed in step1 (Zero harvested area)
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 10996.561062101227
# Step4
# Iteration completed
# Area distributed after step4: 0
# unit code: 680002
# Step5
# Crop: Sugar cane
# Iteration completed
# Area distributed after step5: 258.0
# Step6
# Iteration completed
# Area distributed after step6: 258.0
# Step7
# Iteration completed
# Area distributed after step7 258
# unit code: 680002
# Step5
# Crop: Coffee
# Iteration completed
# Area distributed after step5: 4.0
# Step6
# Iteration completed
# Area distributed after step6: 4.0
# Step7
# Iteration completed
# Area distributed after step7 4
# unit code: 680002
# Step5
# Crop: Cocoa
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 680002
# Step5
# Crop: Oil palm
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 680002
# Step5
# Crop: Others perennial
# Iteration completed
# Area distributed after step5: 3688.0
# Step6
# Iteration completed
# Area distributed after step6: 3688.0
# Step7
# Iteration completed
# Area distributed after step7 3688
# unit code: 680002
# Step5
# Crop: Fodder
# Iteration completed
# Area distributed after step5: 2877.0
# Step6
# Iteration completed
# Area distributed after step6: 2877.0
# Step7
# Iteration completed
# Area distributed after step7 2877
# unit code: 680002
# Step5
# Crop: Maize
# Iteration completed
# Area distributed after step5: 52189.0
# Step6
# Iteration completed
# Area distributed after step6: 52189.0
# Step7
# Iteration completed
# Area distributed after step7 52189
# unit code: 680002
# Step5
# Crop: Wheat1
# Iteration completed
# Area distributed after step5: 18286.0
# Step6
# Iteration completed
# Area distributed after step6: 18286.0
# Step7
# Iteration completed
# Area distributed after step7 18286
# unit code: 680002
# Step5
# Crop: Potatoes
# Iteration completed
# Area distributed after step5: 16157.0
# Step6
# Iteration completed
# Area distributed after step6: 16157.0
# Step7
# Iteration completed
# Area distributed after step7 16157
# unit code: 680002
# Step5
# Crop: Pulses
# Iteration completed
# Area distributed after step5: 8055.0
# Step6
# Iteration completed
# Area distributed after step6: 8055.0
# Step7
# Iteration completed
# Area distributed after step7 8055
# unit code: 680002
# Step5
# Crop: Barley
# Iteration completed
# Area distributed after step5: 6459.0
# Step6
# Iteration completed
# Area distributed after step6: 6459.0
# Step7
# Iteration completed
# Area distributed after step7 6459
# unit code: 680002
# Step5
# Crop: Groundnuts
# Iteration completed
# Area distributed after step5: 3730.0
# Step6
# Iteration completed
# Area distributed after step6: 3730.0
# Step7
# Iteration completed
# Area distributed after step7 3730
# unit code: 680002
# Step5
# Crop: Cassava
# Iteration completed
# Area distributed after step5: 286.0
# Step6
# Iteration completed
# Area distributed after step6: 286.0
# Step7
# Iteration completed
# Area distributed after step7 286
# unit code: 680002
# Step5
# Crop: Rice1
# Iteration completed
# Area distributed after step5: 181.0
# Step6
# Iteration completed
# Area distributed after step6: 181.0
# Step7
# Iteration completed
# Area distributed after step7 181
# unit code: 680002
# Step5
# Crop: Soybeans
# Iteration completed
# Area distributed after step5: 109.0
# Step6
# Iteration completed
# Area distributed after step6: 109.0
# Step7
# Iteration completed
# Area distributed after step7 109
# unit code: 680002
# Step5
# Crop: Sorghum
# Iteration completed
# Area distributed after step5: 58.0
# Step6
# Iteration completed
# Area distributed after step6: 58.0
# Step7
# Iteration completed
# Area distributed after step7 58
# unit code: 680002
# Step5
# Crop: Sunflower
# Iteration completed
# Area distributed after step5: 1.0
# Step6
# Iteration completed
# Area distributed after step6: 1.0
# Step7
# Iteration completed
# Area distributed after step7 1
# unit code: 680002
# Step5
# Crop: Cotton
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 680002
# Step5
# Crop: Millet
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 680002
# Step5
# Crop: Rapeseed
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 680002
# Step5
# Crop: Rice2
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 680002
# Step5
# Crop: Rye
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 680002
# Step5
# Crop: Sugar beet
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 680002
# Step5
# Crop: Wheat2
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 680002
# Step5
# Crop: Others annual1
# Iteration completed
# Area distributed after step5: 6155.0
# Step6
# Iteration completed
# Area distributed after step6: 6155.0
# Step7
# Iteration completed
# Area distributed after step7 6155
# unit code: 680002
# Step5
# Crop: Others annual2
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# 680003
# Step1
# Crop: Cocoa
# Iteration continues
# Area distributed after step1: 0.0
# Area to be distributed in next step: 133.0
# Step2
# Iteration continues
# Area distributed after step2: 2.23
# Area to be distributed in next step: 130.77
# Step3
# Iteration completed
# Area distributed after step3 133.0
# 57890.90428646866
# Step4
# Iteration completed
# Area distributed after step4: 133
# 680003
# Step1
# Crop: Coffee
# Iteration continues
# Area distributed after step1: 0.0
# Area to be distributed in next step: 20.0
# Step2
# Iteration continues
# Area distributed after step2: 2.23
# Area to be distributed in next step: 17.77
# Step3
# Iteration completed
# Area distributed after step3 20.0
# 57870.90079571729
# Step4
# Iteration completed
# Area distributed after step4: 20
# 680003
# Step1
# Crop: Sugar cane
# Error check your code!
# More area available than the growing area
# Iteration completed
# Area distributed in step1: 2.0
# Step2
# Iteration completed
# Area distributed after step2: 2.0
# Step3
# Iteration completed
# Area distributed after step3 2.0
# 57868.9007957128
# Step4
# Iteration completed
# Area distributed after step4: 2
# 680003
# Step1
# Crop: Oil palm
# Iteration completed
# Area distributed after step1: 0.0
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 57868.9007957128
# Step4
# Iteration completed
# Area distributed after step4: 0
# 680003
# Step1
# Crop: Others perennial
# Iteration continues
# Area distributed after step1: 0.0
# Area to be distributed in next step: 5581.0
# Step2
# Iteration continues
# Area distributed after step2: 0.0
# Area to be distributed in next step: 5581.0
# Step3
# Iteration completed
# Area distributed after step3 5581.0
# 52287.9007957128
# Step4
# Iteration completed
# Area distributed after step4: 5581
# 680003
# Step1
# Crop: Fodder
# Iteration continues
# Area distributed after step1: 227.07
# Area to be distributed in next step: 13452.929992675781
# Step2
# Iteration continues
# Area distributed after step2: 2462.99
# Area to be distributed in next step: 11217.01
# Step3
# Iteration completed
# Area distributed after step3 13680.0
# 38643.55888515832
# Step4
# Iteration completed
# Area distributed after step4: 13680
# 680003
# Step1
# Crop: Potatoes
# Iteration continues
# Area distributed after step1: 4870.05
# Area to be distributed in next step: 25077.9501953125
# Step2
# Iteration continues
# Area distributed after step2: 14961.31
# Area to be distributed in next step: 14986.69
# Step3
# Iteration completed
# Area distributed after step3 29948.0
# 13381.824303525103
# Step4
# Iteration completed
# Area distributed after step4: 29948
# 680003
# Step1
# Crop: Maize
# Iteration continues
# Area distributed after step1: 870.14
# Area to be distributed in next step: 4008.8599853515625
# Step2
# Iteration completed
# Area distributed after step2: 4879.0
# Step3
# Iteration completed
# Area distributed after step3 4879.0
# 10513.530405795924
# Step4
# Iteration completed
# Area distributed after step4: 4879
# 680003
# Step1
# Crop: Pulses
# Iteration continues
# Area distributed after step1: 321.71
# Area to be distributed in next step: 2066.290008544922
# Step2
# Iteration continues
# Area distributed after step2: 2183.02
# Area to be distributed in next step: 204.98000000000002
# Step3
# Iteration completed
# Area distributed after step3 2388.0
# 9401.493277367474
# Step4
# Iteration completed
# Area distributed after step4: 2388
# 680003
# Step1
# Crop: Rice1
# Error check your code!
# More area available than the growing area
# Iteration completed
# Area distributed in step1: 1442.0
# Step2
# Iteration completed
# Area distributed after step2: 1442.0
# Step3
# Iteration completed
# Area distributed after step3 1442.0
# 8364.821679907991
# Step4
# Iteration completed
# Area distributed after step4: 1442
# 680003
# Step1
# Crop: Wheat1
# Error check your code!
# More area available than the growing area
# Iteration completed
# Area distributed in step1: 909.0
# Step2
# Iteration completed
# Area distributed after step2: 909.0
# Step3
# Iteration completed
# Area distributed after step3 909.0
# 8105.239198875171
# Step4
# Iteration completed
# Area distributed after step4: 909
# 680003
# Step1
# Crop: Barley
# Iteration continues
# Area distributed after step1: 72.73
# Area to be distributed in next step: 443.2699966430664
# Step2
# Iteration completed
# Area distributed after step2: 516.0
# Step3
# Iteration completed
# Area distributed after step3 516.0
# 8031.0091927483145
# Step4
# Iteration completed
# Area distributed after step4: 516
# 680003
# Step1
# Crop: Cassava
# Iteration continues
# Area distributed after step1: 3.27
# Area to be distributed in next step: 193.7300000190735
# Step2
# Iteration continues
# Area distributed after step2: 53.64
# Area to be distributed in next step: 143.36
# Step3
# Iteration completed
# Area distributed after step3 197.0
# 7926.846705058452
# Step4
# Iteration completed
# Area distributed after step4: 197
# 680003
# Step1
# Crop: Groundnuts
# Error check your code!
# More area available than the growing area
# Iteration completed
# Area distributed in step1: 46.0
# Step2
# Iteration completed
# Area distributed after step2: 46.0
# Step3
# Iteration completed
# Area distributed after step3 46.0
# 7887.174753764506
# Step4
# Iteration completed
# Area distributed after step4: 46
# 680003
# Step1
# Crop: Cotton
# No area will be distributed in step1 (Zero harvested area)
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 7887.174753764506
# Step4
# Iteration completed
# Area distributed after step4: 0
# 680003
# Step1
# Crop: Millet
# Iteration completed
# Area distributed after step1: 0.0
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 7887.174753764506
# Step4
# Iteration completed
# Area distributed after step4: 0
# 680003
# Step1
# Crop: Rapeseed
# Iteration completed
# Area distributed after step1: 0.0
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 7887.174753764506
# Step4
# Iteration completed
# Area distributed after step4: 0
# 680003
# Step1
# Crop: Rice2
# No area will be distributed in step1 (Zero harvested area)
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 7887.174753764506
# Step4
# Iteration completed
# Area distributed after step4: 0
# 680003
# Step1
# Crop: Rye
# No area will be distributed in step1 (Zero harvested area)
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 7887.174753764506
# Step4
# Iteration completed
# Area distributed after step4: 0
# 680003
# Step1
# Crop: Sorghum
# No area will be distributed in step1 (Zero harvested area)
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 7887.174753764506
# ...
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 154895.9992730522
# Step4
# Iteration completed
# Area distributed after step4: 0
# 760011
# Step1
# Crop: Oil palm
# No area will be distributed in step1 (Zero harvested area)
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 154895.9992730522
# Step4
# Iteration completed
# Area distributed after step4: 0
# 760011
# Step1
# Crop: Others perennial
# Iteration continues
# Area distributed after step1: 1.13
# Area to be distributed in next step: 467.8700000047684
# Step2
# Iteration continues
# Area distributed after step2: 349.81
# Area to be distributed in next step: 119.19
# Step3
# Iteration completed
# Area distributed after step3 469.0
# 154426.99688096502
# Step4
# Iteration completed
# Area distributed after step4: 469
# 760011
# Step1
# Crop: Fodder
# Iteration continues
# Area distributed after step1: 0.0
# Area to be distributed in next step: 428.0
# Step2
# Iteration continues
# Area distributed after step2: 1.36
# Area to be distributed in next step: 426.64
# Step3
# Iteration completed
# Area distributed after step3 428.0
# 153998.9991729877
# Step4
# Iteration completed
# Area distributed after step4: 428
# 760011
# Step1
# Crop: Soybeans
# Iteration continues
# Area distributed after step1: 40740.78
# Area to be distributed in next step: 64949.21875
# Step2
# Iteration completed
# Area distributed after step2: 105690.0
# Step3
# Iteration completed
# Area distributed after step3 105690.0
# 48309.2231054112
# Step4
# Iteration completed
# Area distributed after step4: 105690
# 760011
# Step1
# Crop: Cotton
# Iteration continues
# Area distributed after step1: 830.87
# Area to be distributed in next step: 12912.130004882812
# Step2
# Iteration completed
# Area distributed after step2: 13743.0
# Step3
# Iteration completed
# Area distributed after step3 13743.0
# 39291.05553657624
# Step4
# Iteration completed
# Area distributed after step4: 13743
# 760011
# Step1
# Crop: Maize
# Iteration continues
# Area distributed after step1: 1514.81
# Area to be distributed in next step: 137.18994140625
# Step2
# Iteration completed
# Area distributed after step2: 1652.0
# Step3
# Iteration completed
# Area distributed after step3 1652.0
# 37818.19236986768
# Step4
# Iteration completed
# Area distributed after step4: 1652
# 760011
# Step1
# Crop: Pulses
# Iteration continues
# Area distributed after step1: 320.07
# Area to be distributed in next step: 862.9299926757812
# Step2
# Iteration completed
# Area distributed after step2: 1183.0
# Step3
# Iteration completed
# Area distributed after step3 1183.0
# 36929.494442564246
# Step4
# Iteration completed
# Area distributed after step4: 1183
# 760011
# Step1
# Crop: Rice1
# Iteration continues
# Area distributed after step1: 715.76
# Area to be distributed in next step: 467.239990234375
# Step2
# Iteration completed
# Area distributed after step2: 1183.0
# Step3
# Iteration completed
# Area distributed after step3 1183.0
# 35829.07890343318
# Step4
# Iteration completed
# Area distributed after step4: 1183
# 760011
# Step1
# Crop: Cassava
# Error check your code!
# More area available than the growing area
# Iteration completed
# Area distributed in step1: 22.0
# Step2
# Iteration completed
# Area distributed after step2: 22.0
# Step3
# Iteration completed
# Area distributed after step3 22.0
# 35811.458077826785
# Step4
# Iteration completed
# Area distributed after step4: 22
# 760011
# Step1
# Crop: Barley
# Iteration completed
# Area distributed after step1: 0.0
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 35811.458077826785
# Step4
# Iteration completed
# Area distributed after step4: 0
# 760011
# Step1
# Crop: Groundnuts
# No area will be distributed in step1 (Zero harvested area)
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 35811.458077826785
# Step4
# Iteration completed
# Area distributed after step4: 0
# 760011
# Step1
# Crop: Millet
# Iteration completed
# Area distributed after step1: 0.0
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 35811.458077826785
# Step4
# Iteration completed
# Area distributed after step4: 0
# 760011
# Step1
# Crop: Potatoes
# No area will be distributed in step1 (Zero harvested area)
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 35811.458077826785
# Step4
# Iteration completed
# Area distributed after step4: 0
# 760011
# Step1
# Crop: Rapeseed
# Iteration completed
# Area distributed after step1: 0.0
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 35811.458077826785
# Step4
# Iteration completed
# Area distributed after step4: 0
# 760011
# Step1
# Crop: Rice2
# No area will be distributed in step1 (Zero harvested area)
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 35811.458077826785
# Step4
# Iteration completed
# Area distributed after step4: 0
# 760011
# Step1
# Crop: Rye
# No area will be distributed in step1 (Zero harvested area)
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 35811.458077826785
# Step4
# Iteration completed
# Area distributed after step4: 0
# 760011
# Step1
# Crop: Sorghum
# No area will be distributed in step1 (Zero harvested area)
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 35811.458077826785
# Step4
# Iteration completed
# Area distributed after step4: 0
# 760011
# Step1
# Crop: Sugar beet
# Iteration completed
# Area distributed after step1: 0.0
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 35811.458077826785
# Step4
# Iteration completed
# Area distributed after step4: 0
# 760011
# Step1
# Crop: Sunflower
# Iteration completed
# Area distributed after step1: 0.0
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 35811.458077826785
# Step4
# Iteration completed
# Area distributed after step4: 0
# 760011
# Step1
# Crop: Wheat1
# No area will be distributed in step1 (Zero harvested area)
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 35811.458077826785
# Step4
# Iteration completed
# Area distributed after step4: 0
# 760011
# Step1
# Crop: Wheat2
# No area will be distributed in step1 (Zero harvested area)
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 35811.458077826785
# Step4
# Iteration completed
# Area distributed after step4: 0
# 760011
# Step1
# Crop: Others annual1
# Error check your code!
# More area available than the growing area
# Iteration completed
# Area distributed in step1: 185.0
# Step2
# Iteration completed
# Area distributed after step2: 185.0
# Step3
# Iteration completed
# Area distributed after step3 185.0
# 35657.48648886354
# Step4
# Iteration completed
# Area distributed after step4: 185
# 760011
# Step1
# Crop: Others annual2
# No area will be distributed in step1 (Zero harvested area)
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 35657.48648886354
# Step4
# Iteration completed
# Area distributed after step4: 0
# 760011
# Step1
# Crop: Others annual3
# No area will be distributed in step1 (Zero harvested area)
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 35657.48648886354
# Step4
# Iteration completed
# Area distributed after step4: 0
# unit code: 760011
# Step5
# Crop: Sugar cane
# Iteration completed
# Area distributed after step5: 286491.0
# Step6
# Iteration completed
# Area distributed after step6: 286491.0
# Step7
# Iteration completed
# Area distributed after step7 286491
# unit code: 760011
# Step5
# Crop: Coffee
# Iteration completed
# Area distributed after step5: 20140.0
# Step6
# Iteration completed
# Area distributed after step6: 20140.0
# Step7
# Iteration completed
# Area distributed after step7 20140
# unit code: 760011
# Step5
# Crop: Cocoa
# Iteration completed
# Area distributed after step5: 853.0
# Step6
# Iteration completed
# Area distributed after step6: 853.0
# Step7
# Iteration completed
# Area distributed after step7 853
# unit code: 760011
# Step5
# Crop: Oil palm
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 760011
# Step5
# Crop: Others perennial
# Iteration completed
# Area distributed after step5: 107072.0
# Step6
# Iteration completed
# Area distributed after step6: 107072.0
# Step7
# Iteration completed
# Area distributed after step7 107072
# unit code: 760011
# Step5
# Crop: Fodder
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 760011
# Step5
# Crop: Soybeans
# Iteration completed
# Area distributed after step5: 8860989.0
# Step6
# Iteration completed
# Area distributed after step6: 8860989.0
# Step7
# Iteration completed
# Area distributed after step7 8860989
# unit code: 760011
# Step5
# Crop: Maize
# Iteration completed
# Area distributed after step5: 3568954.0
# Step6
# Iteration completed
# Area distributed after step6: 3568954.0
# Step7
# Iteration completed
# Area distributed after step7 3568954
# unit code: 760011
# Step5
# Crop: Cotton
# Iteration completed
# Area distributed after step5: 560402.0
# Step6
# Iteration completed
# Area distributed after step6: 560402.0
# Step7
# Iteration completed
# Area distributed after step7 560402
# unit code: 760011
# Step5
# Crop: Pulses
# Iteration completed
# Area distributed after step5: 238658.0
# Step6
# Iteration completed
# Area distributed after step6: 238658.0
# Step7
# Iteration completed
# Area distributed after step7 238658
# unit code: 760011
# Step5
# Crop: Rice1
# Iteration completed
# Area distributed after step5: 236271.0
# Step6
# Iteration completed
# Area distributed after step6: 236271.0
# Step7
# Iteration completed
# Area distributed after step7 236271
# unit code: 760011
# Step5
# Crop: Sorghum
# Iteration completed
# Area distributed after step5: 124505.0
# Step6
# Iteration completed
# Area distributed after step6: 124505.0
# Step7
# Iteration completed
# Area distributed after step7 124505
# unit code: 760011
# Step5
# Crop: Cassava
# Iteration completed
# Area distributed after step5: 19533.0
# Step6
# Iteration completed
# Area distributed after step6: 19533.0
# Step7
# Iteration completed
# Area distributed after step7 19533
# unit code: 760011
# Step5
# Crop: Sunflower
# Iteration completed
# Area distributed after step5: 15923.0
# Step6
# Iteration completed
# Area distributed after step6: 15923.0
# Step7
# Iteration completed
# Area distributed after step7 15923
# unit code: 760011
# Step5
# Crop: Rapeseed
# Iteration completed
# Area distributed after step5: 3133.0
# Step6
# Iteration completed
# Area distributed after step6: 3133.0
# Step7
# Iteration completed
# Area distributed after step7 3133
# unit code: 760011
# Step5
# Crop: Rice2
# Iteration completed
# Area distributed after step5: 2387.0
# Step6
# Iteration completed
# Area distributed after step6: 2387.0
# Step7
# Iteration completed
# Area distributed after step7 2387
# unit code: 760011
# Step5
# Crop: Groundnuts
# Iteration completed
# Area distributed after step5: 165.0
# Step6
# Iteration completed
# Area distributed after step6: 165.0
# Step7
# Iteration completed
# Area distributed after step7 165
# unit code: 760011
# Step5
# Crop: Wheat1
# Iteration completed
# Area distributed after step5: 140.0
# Step6
# Iteration completed
# Area distributed after step6: 140.0
# Step7
# Iteration completed
# Area distributed after step7 140
# unit code: 760011
# Step5
# Crop: Wheat2
# Iteration completed
# Area distributed after step5: 140.0
# Step6
# Iteration completed
# Area distributed after step6: 140.0
# Step7
# Iteration completed
# Area distributed after step7 140
# unit code: 760011
# Step5
# Crop: Barley
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 760011
# Step5
# Crop: Millet
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 760011
# Step5
# Crop: Potatoes
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 760011
# Step5
# Crop: Rye
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 760011
# Step5
# Crop: Sugar beet
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# unit code: 760011
# Step5
# Crop: Others annual1
# Iteration completed
# Area distributed after step5: 35282.0
# Step6
# Iteration completed
# Area distributed after step6: 35282.0
# Step7
# Iteration completed
# Area distributed after step7 35282
# unit code: 760011
# Step5
# Crop: Others annual2
# Iteration completed
# Area distributed after step5: 8820.0
# Step6
# Iteration completed
# Area distributed after step6: 8820.0
# Step7
# Iteration completed
# Area distributed after step7 8820
# unit code: 760011
# Step5
# Crop: Others annual3
# Iteration completed
# Area distributed after step5: 0.0
# Step6
# Iteration completed
# Area distributed after step6: 0.0
# Step7
# Iteration completed
# Area distributed after step7 0
# 760012
# Step1
# Crop: Sugar cane
# Iteration continues
# Area distributed after step1: 2726.04
# Area to be distributed in next step: 112361.9599609375
# Step2
# Iteration continues
# Area distributed after step2: 32942.1
# Area to be distributed in next step: 82145.9
# Step3
# Iteration continues
# Area distributed after step3: 54730.81
# Area to be distributed in next step: 60357.19
# 1.9026740791741759
# Step4
# Error Check Your Code! (full area not assigned)
# Area distributed after step4: 54733
# 760012
# Step1
# Crop: Coffee
# Error check your code!
# More area available than the growing area
# Iteration completed
# Area distributed in step1: 4.0
# Step2
# Iteration completed
# Area distributed after step2: 4.0
# Step3
# Iteration completed
# Area distributed after step3 4.0
# 1.9023195109179483
# Step4
# Iteration completed
# Area distributed after step4: 4
# 760012
# Step1
# Crop: Cocoa
# No area will be distributed in step1 (Zero harvested area)
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 1.9023195109179483
# Step4
# Iteration completed
# Area distributed after step4: 0
# 760012
# Step1
# Crop: Oil palm
# No area will be distributed in step1 (Zero harvested area)
# Step2
# Iteration completed
# Area distributed after step2: 0.0
# Step3
# Iteration completed
# Area distributed after step3 0.0
# 1.9023195109179483
# Step4
# Iteration completed
# Area distributed after step4: 0
# 760012
# Step1
# Crop: Others perennial
# Iteration continues
# Area distributed after step1: 0.02
# Area to be distributed in next step: 11927.980000000447
# Step2
# Iteration continues
# Area distributed after step2: 26.04
# Area to be distributed in next step: 11901.96
# Step3
# Iteration completed
# Area distributed after step3 11928.0
# 1.9023195109179483
# Step4
# Iteration completed
# Area distributed after step4: 11928
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 109
#     107 if os.path.basename(tiff_file)[:-4] == str(unit_code):
#     108     array = read_tiff_file(subfolder_path, unit_code)
# --> 109     array =  np.where(np.logical_or(np.isnan(array), np.isinf(array)), 0, array)
#     111     if subfolder_name == "AEI_15":
#     112         tiff_ir=tiff_file
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
